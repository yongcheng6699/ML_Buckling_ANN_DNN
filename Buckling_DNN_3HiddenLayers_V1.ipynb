# %% [markdown]
# ##  A 3-Hidden Layers Architecture (Broad Search - Parametric Study)
# What is happening here?
#     [1] A deep DNN model
#     [2] Contains two lines of code to find the rsquare
#     [3] Includes lines of code on cross validation
#     [4] Include the plot of the history curves
#
# The lower value of MAE, MSE, and RMSE implies higher accuracy of a regression model. However, a higher value of R square is considered desirable.

# %%
import pandas as pd 
import numpy as np                                             
from sklearn.model_selection import train_test_split
from keras.models import Sequential
from keras.layers import Dense, Input
from keras.optimizers import Adam
from sklearn.metrics import r2_score
import math

# Load the data
bucklingdata = pd.read_csv("CBL_SimulationResults.csv", encoding='cp1252')
input_data = bucklingdata.drop(['Critical Buckling Load (N)', 'Critical Buckling Load (kN)'], axis=1)
output_data = bucklingdata['Critical Buckling Load (kN)']

# Split the data
np.random.seed(0)
X_train, X_test, y_train, y_test = train_test_split(input_data, output_data,
                                                    test_size=0.3,
                                                    shuffle=False,
                                                    stratify=None,
                                                    random_state=42)

# Validation data
val_no = round(0.2 * y_train.size)
x_val = X_train[:val_no]
y_val = y_train[:val_no]

def create_model3H(hp_layer_1, hp_layer_2, hp_layer_3):
    model = Sequential()
    model.add(Input(shape=(11,)))
    hp_activation = 'selu'
    hp_learning_rate = 0.001
    model.add(Dense(hp_layer_1, activation=hp_activation))
    model.add(Dense(hp_layer_2, activation=hp_activation))
    model.add(Dense(hp_layer_3, activation=hp_activation))
    model.add(Dense(1, activation="linear"))
    model.compile(loss='mse',
                  optimizer=Adam(learning_rate = hp_learning_rate),
                  metrics=["mae"])
    return model

# Specify the range for neurons in the three hidden layers
min_neurons = 20
max_neurons = 100
step = 10

neuron_configs = []

# Generate configurations with increasing neurons in all three layers
for neurons1 in range(min_neurons, max_neurons + 1, step):
    for neurons2 in range(min_neurons, max_neurons + 1, step):
        for neurons3 in range(min_neurons, max_neurons + 1, step):
            neuron_configs.append((neurons1, neurons2, neurons3))
            
results = []

## Train your model for a number of epochs, with the .fit()
## Get the performance metrics for the network and the learning curves
# Iterate over each configuration of neurons
for i, (p1, p2, p3) in enumerate(neuron_configs):
    print(f"Training model with configuration {i+1}: Hidden Layer 1={p1}, Hidden Layer 2={p2}, Hidden Layer 3={p3}")
    
    # Create the model for the current configuration
    model = create_model3H(p1, p2, p3)
    
    # Fit the model
    history = model.fit(X_train, y_train, epochs=150,
                        validation_data=(x_val, y_val), batch_size=32,
                        verbose=0)
    
    # Evaluate the model on training, validation, and test sets
    trainmse, trainmae = model.evaluate(X_train, y_train, verbose=0)
    valmse, valmae = model.evaluate(x_val, y_val, verbose=0)
    testmse, testmae = model.evaluate(X_test, y_test, verbose=0)
    
    # Predictions for R-squared calculation
    train_pred = model.predict(X_train)
    val_pred = model.predict(x_val)
    test_pred = model.predict(X_test)
    
    # Calculate R-squared scores
    train_r2 = r2_score(y_train, train_pred)
    val_r2 = r2_score(y_val, val_pred)
    test_r2 = r2_score(y_test, test_pred)
    
    # Store the evaluation metrics in a DataFrame
    result_df = pd.DataFrame({
        'Configuration': i + 1,
        'Hidden Layer 1 Neurons': p1,
        'Hidden Layer 2 Neurons': p2,
        'Hidden Layer 3 Neurons': p3,
        'Train R2': train_r2,
        'Val R2': val_r2,
        'Test R2': test_r2,
        'Train RMSE': math.sqrt(trainmse),
        'Val RMSE': math.sqrt(valmse),
        'Test RMSE': math.sqrt(testmse),
        'Train MAE': trainmae,
        'Val MAE': valmae,
        'Test MAE': testmae
    }, index=[0])
    
    results.append(result_df)

# Concatenate all results into a single DataFrame
final_results = pd.concat(results, ignore_index=True)

# Save the results to an Excel file
final_results.to_excel('3HiddenLayers_VariousNeurons_Results_1stRun.xlsx', index=False)

print(f"Results saved to 3HiddenLayers_VariousNeurons_Results.xlsx")
# Out:
# Training model with configuration 1: Hidden Layer 1=20, Hidden Layer 2=20, Hidden Layer 3=20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Training model with configuration 2: Hidden Layer 1=20, Hidden Layer 2=20, Hidden Layer 3=30
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 798us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 745us/step
# Training model with configuration 3: Hidden Layer 1=20, Hidden Layer 2=20, Hidden Layer 3=40
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 990us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 834us/step
# Training model with configuration 4: Hidden Layer 1=20, Hidden Layer 2=20, Hidden Layer 3=50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Training model with configuration 5: Hidden Layer 1=20, Hidden Layer 2=20, Hidden Layer 3=60
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Training model with configuration 6: Hidden Layer 1=20, Hidden Layer 2=20, Hidden Layer 3=70
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 745us/step
# Training model with configuration 7: Hidden Layer 1=20, Hidden Layer 2=20, Hidden Layer 3=80
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 798us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 965us/step
# Training model with configuration 8: Hidden Layer 1=20, Hidden Layer 2=20, Hidden Layer 3=90
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 852us/step
# Training model with configuration 9: Hidden Layer 1=20, Hidden Layer 2=20, Hidden Layer 3=100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 833us/step
# Training model with configuration 10: Hidden Layer 1=20, Hidden Layer 2=30, Hidden Layer 3=20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 997us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 831us/step
# Training model with configuration 11: Hidden Layer 1=20, Hidden Layer 2=30, Hidden Layer 3=30
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 788us/step
# Training model with configuration 12: Hidden Layer 1=20, Hidden Layer 2=30, Hidden Layer 3=40
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 970us/step
# Training model with configuration 13: Hidden Layer 1=20, Hidden Layer 2=30, Hidden Layer 3=50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Training model with configuration 14: Hidden Layer 1=20, Hidden Layer 2=30, Hidden Layer 3=60
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 807us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 997us/step
# Training model with configuration 15: Hidden Layer 1=20, Hidden Layer 2=30, Hidden Layer 3=70
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Training model with configuration 16: Hidden Layer 1=20, Hidden Layer 2=30, Hidden Layer 3=80
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Training model with configuration 17: Hidden Layer 1=20, Hidden Layer 2=30, Hidden Layer 3=90
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Training model with configuration 18: Hidden Layer 1=20, Hidden Layer 2=30, Hidden Layer 3=100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 999us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 728us/step
# Training model with configuration 19: Hidden Layer 1=20, Hidden Layer 2=40, Hidden Layer 3=20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 798us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 751us/step
# Training model with configuration 20: Hidden Layer 1=20, Hidden Layer 2=40, Hidden Layer 3=30
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 759us/step
# Training model with configuration 21: Hidden Layer 1=20, Hidden Layer 2=40, Hidden Layer 3=40
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 768us/step
# Training model with configuration 22: Hidden Layer 1=20, Hidden Layer 2=40, Hidden Layer 3=50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 901us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 665us/step
# Training model with configuration 23: Hidden Layer 1=20, Hidden Layer 2=40, Hidden Layer 3=60
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 790us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 721us/step
# Training model with configuration 24: Hidden Layer 1=20, Hidden Layer 2=40, Hidden Layer 3=70
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 997us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 745us/step
# Training model with configuration 25: Hidden Layer 1=20, Hidden Layer 2=40, Hidden Layer 3=80
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 868us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 771us/step
# Training model with configuration 26: Hidden Layer 1=20, Hidden Layer 2=40, Hidden Layer 3=90
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 976us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 718us/step
# Training model with configuration 27: Hidden Layer 1=20, Hidden Layer 2=40, Hidden Layer 3=100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 798us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 831us/step
# Training model with configuration 28: Hidden Layer 1=20, Hidden Layer 2=50, Hidden Layer 3=20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 798us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 831us/step
# Training model with configuration 29: Hidden Layer 1=20, Hidden Layer 2=50, Hidden Layer 3=30
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 997us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 831us/step
# Training model with configuration 30: Hidden Layer 1=20, Hidden Layer 2=50, Hidden Layer 3=40
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 799us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 748us/step
# Training model with configuration 31: Hidden Layer 1=20, Hidden Layer 2=50, Hidden Layer 3=50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 997us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 831us/step
# Training model with configuration 32: Hidden Layer 1=20, Hidden Layer 2=50, Hidden Layer 3=60
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 889us/step
# Training model with configuration 33: Hidden Layer 1=20, Hidden Layer 2=50, Hidden Layer 3=70
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 798us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 792us/step
# Training model with configuration 34: Hidden Layer 1=20, Hidden Layer 2=50, Hidden Layer 3=80
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 998us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 715us/step
# Training model with configuration 35: Hidden Layer 1=20, Hidden Layer 2=50, Hidden Layer 3=90
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 799us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 662us/step
# Training model with configuration 36: Hidden Layer 1=20, Hidden Layer 2=50, Hidden Layer 3=100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 797us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 750us/step
# Training model with configuration 37: Hidden Layer 1=20, Hidden Layer 2=60, Hidden Layer 3=20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 998us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 748us/step
# Training model with configuration 38: Hidden Layer 1=20, Hidden Layer 2=60, Hidden Layer 3=30
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 937us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 721us/step
# Training model with configuration 39: Hidden Layer 1=20, Hidden Layer 2=60, Hidden Layer 3=40
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 824us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 831us/step
# Training model with configuration 40: Hidden Layer 1=20, Hidden Layer 2=60, Hidden Layer 3=50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 893us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 792us/step
# Training model with configuration 41: Hidden Layer 1=20, Hidden Layer 2=60, Hidden Layer 3=60
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 798us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 728us/step
# Training model with configuration 42: Hidden Layer 1=20, Hidden Layer 2=60, Hidden Layer 3=70
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 983us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 806us/step
# Training model with configuration 43: Hidden Layer 1=20, Hidden Layer 2=60, Hidden Layer 3=80
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 748us/step
# Training model with configuration 44: Hidden Layer 1=20, Hidden Layer 2=60, Hidden Layer 3=90
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 799us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 805us/step
# Training model with configuration 45: Hidden Layer 1=20, Hidden Layer 2=60, Hidden Layer 3=100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 997us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Training model with configuration 46: Hidden Layer 1=20, Hidden Layer 2=70, Hidden Layer 3=20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 998us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Training model with configuration 47: Hidden Layer 1=20, Hidden Layer 2=70, Hidden Layer 3=30
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Training model with configuration 48: Hidden Layer 1=20, Hidden Layer 2=70, Hidden Layer 3=40
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 799us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1000us/step
# Training model with configuration 49: Hidden Layer 1=20, Hidden Layer 2=70, Hidden Layer 3=50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Training model with configuration 50: Hidden Layer 1=20, Hidden Layer 2=70, Hidden Layer 3=60
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 997us/step
# Training model with configuration 51: Hidden Layer 1=20, Hidden Layer 2=70, Hidden Layer 3=70
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 998us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 997us/step
# Training model with configuration 52: Hidden Layer 1=20, Hidden Layer 2=70, Hidden Layer 3=80
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 726us/step
# Training model with configuration 53: Hidden Layer 1=20, Hidden Layer 2=70, Hidden Layer 3=90
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 863us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 729us/step
# Training model with configuration 54: Hidden Layer 1=20, Hidden Layer 2=70, Hidden Layer 3=100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Training model with configuration 55: Hidden Layer 1=20, Hidden Layer 2=80, Hidden Layer 3=20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 701us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 820us/step
# Training model with configuration 56: Hidden Layer 1=20, Hidden Layer 2=80, Hidden Layer 3=30
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 804us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 743us/step
# Training model with configuration 57: Hidden Layer 1=20, Hidden Layer 2=80, Hidden Layer 3=40
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 802us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 755us/step
# Training model with configuration 58: Hidden Layer 1=20, Hidden Layer 2=80, Hidden Layer 3=50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 892us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 865us/step
# Training model with configuration 59: Hidden Layer 1=20, Hidden Layer 2=80, Hidden Layer 3=60
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 776us/step
# Training model with configuration 60: Hidden Layer 1=20, Hidden Layer 2=80, Hidden Layer 3=70
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 998us/step
# Training model with configuration 61: Hidden Layer 1=20, Hidden Layer 2=80, Hidden Layer 3=80
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 960us/step
# Training model with configuration 62: Hidden Layer 1=20, Hidden Layer 2=80, Hidden Layer 3=90
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 997us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 971us/step
# Training model with configuration 63: Hidden Layer 1=20, Hidden Layer 2=80, Hidden Layer 3=100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Training model with configuration 64: Hidden Layer 1=20, Hidden Layer 2=90, Hidden Layer 3=20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 912us/step
# Training model with configuration 65: Hidden Layer 1=20, Hidden Layer 2=90, Hidden Layer 3=30
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 998us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 836us/step
# Training model with configuration 66: Hidden Layer 1=20, Hidden Layer 2=90, Hidden Layer 3=40
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Training model with configuration 67: Hidden Layer 1=20, Hidden Layer 2=90, Hidden Layer 3=50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 799us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 915us/step
# Training model with configuration 68: Hidden Layer 1=20, Hidden Layer 2=90, Hidden Layer 3=60
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Training model with configuration 69: Hidden Layer 1=20, Hidden Layer 2=90, Hidden Layer 3=70
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 998us/step
# Training model with configuration 70: Hidden Layer 1=20, Hidden Layer 2=90, Hidden Layer 3=80
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Training model with configuration 71: Hidden Layer 1=20, Hidden Layer 2=90, Hidden Layer 3=90
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 997us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 915us/step
# Training model with configuration 72: Hidden Layer 1=20, Hidden Layer 2=90, Hidden Layer 3=100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Training model with configuration 73: Hidden Layer 1=20, Hidden Layer 2=100, Hidden Layer 3=20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Training model with configuration 74: Hidden Layer 1=20, Hidden Layer 2=100, Hidden Layer 3=30
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 799us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 994us/step
# Training model with configuration 75: Hidden Layer 1=20, Hidden Layer 2=100, Hidden Layer 3=40
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 831us/step
# Training model with configuration 76: Hidden Layer 1=20, Hidden Layer 2=100, Hidden Layer 3=50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 831us/step
# Training model with configuration 77: Hidden Layer 1=20, Hidden Layer 2=100, Hidden Layer 3=60
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 997us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 897us/step
# Training model with configuration 78: Hidden Layer 1=20, Hidden Layer 2=100, Hidden Layer 3=70
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 832us/step
# Training model with configuration 79: Hidden Layer 1=20, Hidden Layer 2=100, Hidden Layer 3=80
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 998us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Training model with configuration 80: Hidden Layer 1=20, Hidden Layer 2=100, Hidden Layer 3=90
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 831us/step
# Training model with configuration 81: Hidden Layer 1=20, Hidden Layer 2=100, Hidden Layer 3=100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 914us/step
# Training model with configuration 82: Hidden Layer 1=30, Hidden Layer 2=20, Hidden Layer 3=20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 998us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 998us/step
# Training model with configuration 83: Hidden Layer 1=30, Hidden Layer 2=20, Hidden Layer 3=30
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 997us/step
# Training model with configuration 84: Hidden Layer 1=30, Hidden Layer 2=20, Hidden Layer 3=40
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 876us/step
# Training model with configuration 85: Hidden Layer 1=30, Hidden Layer 2=20, Hidden Layer 3=50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 915us/step
# Training model with configuration 86: Hidden Layer 1=30, Hidden Layer 2=20, Hidden Layer 3=60
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 914us/step
# Training model with configuration 87: Hidden Layer 1=30, Hidden Layer 2=20, Hidden Layer 3=70
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 917us/step
# Training model with configuration 88: Hidden Layer 1=30, Hidden Layer 2=20, Hidden Layer 3=80
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 915us/step
# Training model with configuration 89: Hidden Layer 1=30, Hidden Layer 2=20, Hidden Layer 3=90
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 998us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Training model with configuration 90: Hidden Layer 1=30, Hidden Layer 2=20, Hidden Layer 3=100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 997us/step
# Training model with configuration 91: Hidden Layer 1=30, Hidden Layer 2=30, Hidden Layer 3=20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 998us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 914us/step
# Training model with configuration 92: Hidden Layer 1=30, Hidden Layer 2=30, Hidden Layer 3=30
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Training model with configuration 93: Hidden Layer 1=30, Hidden Layer 2=30, Hidden Layer 3=40
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Training model with configuration 94: Hidden Layer 1=30, Hidden Layer 2=30, Hidden Layer 3=50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 791us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 916us/step
# Training model with configuration 95: Hidden Layer 1=30, Hidden Layer 2=30, Hidden Layer 3=60
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 798us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 796us/step
# Training model with configuration 96: Hidden Layer 1=30, Hidden Layer 2=30, Hidden Layer 3=70
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 729us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 828us/step
# Training model with configuration 97: Hidden Layer 1=30, Hidden Layer 2=30, Hidden Layer 3=80
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 750us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 838us/step
# Training model with configuration 98: Hidden Layer 1=30, Hidden Layer 2=30, Hidden Layer 3=90
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 938us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 832us/step
# Training model with configuration 99: Hidden Layer 1=30, Hidden Layer 2=30, Hidden Layer 3=100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 792us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Training model with configuration 100: Hidden Layer 1=30, Hidden Layer 2=40, Hidden Layer 3=20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 798us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 819us/step
# Training model with configuration 101: Hidden Layer 1=30, Hidden Layer 2=40, Hidden Layer 3=30
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 798us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 831us/step
# Training model with configuration 102: Hidden Layer 1=30, Hidden Layer 2=40, Hidden Layer 3=40
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 812us/step
# Training model with configuration 103: Hidden Layer 1=30, Hidden Layer 2=40, Hidden Layer 3=50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 896us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 748us/step
# Training model with configuration 104: Hidden Layer 1=30, Hidden Layer 2=40, Hidden Layer 3=60
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 831us/step
# Training model with configuration 105: Hidden Layer 1=30, Hidden Layer 2=40, Hidden Layer 3=70
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 775us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 832us/step
# Training model with configuration 106: Hidden Layer 1=30, Hidden Layer 2=40, Hidden Layer 3=80
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 997us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 832us/step
# Training model with configuration 107: Hidden Layer 1=30, Hidden Layer 2=40, Hidden Layer 3=90
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 748us/step
# Training model with configuration 108: Hidden Layer 1=30, Hidden Layer 2=40, Hidden Layer 3=100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 799us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 750us/step
# Training model with configuration 109: Hidden Layer 1=30, Hidden Layer 2=50, Hidden Layer 3=20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 914us/step
# Training model with configuration 110: Hidden Layer 1=30, Hidden Layer 2=50, Hidden Layer 3=30
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 998us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 758us/step
# Training model with configuration 111: Hidden Layer 1=30, Hidden Layer 2=50, Hidden Layer 3=40
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Training model with configuration 112: Hidden Layer 1=30, Hidden Layer 2=50, Hidden Layer 3=50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 791us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 748us/step
# Training model with configuration 113: Hidden Layer 1=30, Hidden Layer 2=50, Hidden Layer 3=60
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 991us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step
# Training model with configuration 114: Hidden Layer 1=30, Hidden Layer 2=50, Hidden Layer 3=70
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 998us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 770us/step
# Training model with configuration 115: Hidden Layer 1=30, Hidden Layer 2=50, Hidden Layer 3=80
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 973us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 699us/step
# Training model with configuration 116: Hidden Layer 1=30, Hidden Layer 2=50, Hidden Layer 3=90
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 751us/step
# Training model with configuration 117: Hidden Layer 1=30, Hidden Layer 2=50, Hidden Layer 3=100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 998us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 893us/step
# Training model with configuration 118: Hidden Layer 1=30, Hidden Layer 2=60, Hidden Layer 3=20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 791us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 757us/step
# Training model with configuration 119: Hidden Layer 1=30, Hidden Layer 2=60, Hidden Layer 3=30
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 997us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 831us/step
# Training model with configuration 120: Hidden Layer 1=30, Hidden Layer 2=60, Hidden Layer 3=40
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 999us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 752us/step
# Training model with configuration 121: Hidden Layer 1=30, Hidden Layer 2=60, Hidden Layer 3=50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 997us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 831us/step
# Training model with configuration 122: Hidden Layer 1=30, Hidden Layer 2=60, Hidden Layer 3=60
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 997us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 831us/step
# Training model with configuration 123: Hidden Layer 1=30, Hidden Layer 2=60, Hidden Layer 3=70
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Training model with configuration 124: Hidden Layer 1=30, Hidden Layer 2=60, Hidden Layer 3=80
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 997us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 914us/step
# Training model with configuration 125: Hidden Layer 1=30, Hidden Layer 2=60, Hidden Layer 3=90
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 798us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 705us/step
# Training model with configuration 126: Hidden Layer 1=30, Hidden Layer 2=60, Hidden Layer 3=100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 822us/step
# Training model with configuration 127: Hidden Layer 1=30, Hidden Layer 2=70, Hidden Layer 3=20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 669us/step
# Training model with configuration 128: Hidden Layer 1=30, Hidden Layer 2=70, Hidden Layer 3=30
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 765us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 770us/step
# Training model with configuration 129: Hidden Layer 1=30, Hidden Layer 2=70, Hidden Layer 3=40
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 998us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 721us/step
# Training model with configuration 130: Hidden Layer 1=30, Hidden Layer 2=70, Hidden Layer 3=50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 998us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 736us/step
# Training model with configuration 131: Hidden Layer 1=30, Hidden Layer 2=70, Hidden Layer 3=60
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 888us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 676us/step
# Training model with configuration 132: Hidden Layer 1=30, Hidden Layer 2=70, Hidden Layer 3=70
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 798us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 748us/step
# Training model with configuration 133: Hidden Layer 1=30, Hidden Layer 2=70, Hidden Layer 3=80
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 805us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 696us/step
# Training model with configuration 134: Hidden Layer 1=30, Hidden Layer 2=70, Hidden Layer 3=90
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 928us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 698us/step
# Training model with configuration 135: Hidden Layer 1=30, Hidden Layer 2=70, Hidden Layer 3=100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 681us/step
# Training model with configuration 136: Hidden Layer 1=30, Hidden Layer 2=80, Hidden Layer 3=20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 799us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 748us/step
# Training model with configuration 137: Hidden Layer 1=30, Hidden Layer 2=80, Hidden Layer 3=30
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 997us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 831us/step
# Training model with configuration 138: Hidden Layer 1=30, Hidden Layer 2=80, Hidden Layer 3=40
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 913us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 776us/step
# Training model with configuration 139: Hidden Layer 1=30, Hidden Layer 2=80, Hidden Layer 3=50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 997us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Training model with configuration 140: Hidden Layer 1=30, Hidden Layer 2=80, Hidden Layer 3=60
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 798us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 829us/step
# Training model with configuration 141: Hidden Layer 1=30, Hidden Layer 2=80, Hidden Layer 3=70
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 949us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 733us/step
# Training model with configuration 142: Hidden Layer 1=30, Hidden Layer 2=80, Hidden Layer 3=80
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 799us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 810us/step
# Training model with configuration 143: Hidden Layer 1=30, Hidden Layer 2=80, Hidden Layer 3=90
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 737us/step
# Training model with configuration 144: Hidden Layer 1=30, Hidden Layer 2=80, Hidden Layer 3=100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 799us/step
# Training model with configuration 145: Hidden Layer 1=30, Hidden Layer 2=90, Hidden Layer 3=20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 999us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Training model with configuration 146: Hidden Layer 1=30, Hidden Layer 2=90, Hidden Layer 3=30
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 953us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 782us/step
# Training model with configuration 147: Hidden Layer 1=30, Hidden Layer 2=90, Hidden Layer 3=40
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 900us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 826us/step
# Training model with configuration 148: Hidden Layer 1=30, Hidden Layer 2=90, Hidden Layer 3=50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Training model with configuration 149: Hidden Layer 1=30, Hidden Layer 2=90, Hidden Layer 3=60
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Training model with configuration 150: Hidden Layer 1=30, Hidden Layer 2=90, Hidden Layer 3=70
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 993us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 874us/step
# Training model with configuration 151: Hidden Layer 1=30, Hidden Layer 2=90, Hidden Layer 3=80
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 798us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 758us/step
# Training model with configuration 152: Hidden Layer 1=30, Hidden Layer 2=90, Hidden Layer 3=90
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 991us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 819us/step
# Training model with configuration 153: Hidden Layer 1=30, Hidden Layer 2=90, Hidden Layer 3=100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 799us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 748us/step
# Training model with configuration 154: Hidden Layer 1=30, Hidden Layer 2=100, Hidden Layer 3=20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 803us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 751us/step
# Training model with configuration 155: Hidden Layer 1=30, Hidden Layer 2=100, Hidden Layer 3=30
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 998us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 730us/step
# Training model with configuration 156: Hidden Layer 1=30, Hidden Layer 2=100, Hidden Layer 3=40
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 877us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 831us/step
# Training model with configuration 157: Hidden Layer 1=30, Hidden Layer 2=100, Hidden Layer 3=50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 748us/step
# Training model with configuration 158: Hidden Layer 1=30, Hidden Layer 2=100, Hidden Layer 3=60
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 998us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 759us/step
# Training model with configuration 159: Hidden Layer 1=30, Hidden Layer 2=100, Hidden Layer 3=70
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 865us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 725us/step
# Training model with configuration 160: Hidden Layer 1=30, Hidden Layer 2=100, Hidden Layer 3=80
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 798us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 741us/step
# Training model with configuration 161: Hidden Layer 1=30, Hidden Layer 2=100, Hidden Layer 3=90
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 824us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 745us/step
# Training model with configuration 162: Hidden Layer 1=30, Hidden Layer 2=100, Hidden Layer 3=100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 997us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 666us/step
# Training model with configuration 163: Hidden Layer 1=40, Hidden Layer 2=20, Hidden Layer 3=20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 871us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 703us/step
# Training model with configuration 164: Hidden Layer 1=40, Hidden Layer 2=20, Hidden Layer 3=30
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 822us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 748us/step
# Training model with configuration 165: Hidden Layer 1=40, Hidden Layer 2=20, Hidden Layer 3=40
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 997us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 745us/step
# Training model with configuration 166: Hidden Layer 1=40, Hidden Layer 2=20, Hidden Layer 3=50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 806us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 746us/step
# Training model with configuration 167: Hidden Layer 1=40, Hidden Layer 2=20, Hidden Layer 3=60
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 858us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 727us/step
# Training model with configuration 168: Hidden Layer 1=40, Hidden Layer 2=20, Hidden Layer 3=70
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 998us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 914us/step
# Training model with configuration 169: Hidden Layer 1=40, Hidden Layer 2=20, Hidden Layer 3=80
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 998us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 769us/step
# Training model with configuration 170: Hidden Layer 1=40, Hidden Layer 2=20, Hidden Layer 3=90
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 835us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 798us/step
# Training model with configuration 171: Hidden Layer 1=40, Hidden Layer 2=20, Hidden Layer 3=100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 898us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 876us/step
# Training model with configuration 172: Hidden Layer 1=40, Hidden Layer 2=30, Hidden Layer 3=20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 904us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 755us/step
# Training model with configuration 173: Hidden Layer 1=40, Hidden Layer 2=30, Hidden Layer 3=30
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 998us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 715us/step
# Training model with configuration 174: Hidden Layer 1=40, Hidden Layer 2=30, Hidden Layer 3=40
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 775us/step
# Training model with configuration 175: Hidden Layer 1=40, Hidden Layer 2=30, Hidden Layer 3=50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 943us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 914us/step
# Training model with configuration 176: Hidden Layer 1=40, Hidden Layer 2=30, Hidden Layer 3=60
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 719us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 704us/step
# Training model with configuration 177: Hidden Layer 1=40, Hidden Layer 2=30, Hidden Layer 3=70
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 834us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 863us/step
# Training model with configuration 178: Hidden Layer 1=40, Hidden Layer 2=30, Hidden Layer 3=80
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 997us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Training model with configuration 179: Hidden Layer 1=40, Hidden Layer 2=30, Hidden Layer 3=90
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 997us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 831us/step
# Training model with configuration 180: Hidden Layer 1=40, Hidden Layer 2=30, Hidden Layer 3=100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 799us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Training model with configuration 181: Hidden Layer 1=40, Hidden Layer 2=40, Hidden Layer 3=20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 901us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 805us/step
# Training model with configuration 182: Hidden Layer 1=40, Hidden Layer 2=40, Hidden Layer 3=30
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 998us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 770us/step
# Training model with configuration 183: Hidden Layer 1=40, Hidden Layer 2=40, Hidden Layer 3=40
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 820us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 710us/step
# Training model with configuration 184: Hidden Layer 1=40, Hidden Layer 2=40, Hidden Layer 3=50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Training model with configuration 185: Hidden Layer 1=40, Hidden Layer 2=40, Hidden Layer 3=60
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 802us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 723us/step
# Training model with configuration 186: Hidden Layer 1=40, Hidden Layer 2=40, Hidden Layer 3=70
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 797us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 738us/step
# Training model with configuration 187: Hidden Layer 1=40, Hidden Layer 2=40, Hidden Layer 3=80
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Training model with configuration 188: Hidden Layer 1=40, Hidden Layer 2=40, Hidden Layer 3=90
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 997us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 748us/step
# Training model with configuration 189: Hidden Layer 1=40, Hidden Layer 2=40, Hidden Layer 3=100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 804us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 779us/step
# Training model with configuration 190: Hidden Layer 1=40, Hidden Layer 2=50, Hidden Layer 3=20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 870us/step
# Training model with configuration 191: Hidden Layer 1=40, Hidden Layer 2=50, Hidden Layer 3=30
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 749us/step
# Training model with configuration 192: Hidden Layer 1=40, Hidden Layer 2=50, Hidden Layer 3=40
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 831us/step
# Training model with configuration 193: Hidden Layer 1=40, Hidden Layer 2=50, Hidden Layer 3=50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 798us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 752us/step
# Training model with configuration 194: Hidden Layer 1=40, Hidden Layer 2=50, Hidden Layer 3=60
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 796us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 747us/step
# Training model with configuration 195: Hidden Layer 1=40, Hidden Layer 2=50, Hidden Layer 3=70
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 826us/step
# Training model with configuration 196: Hidden Layer 1=40, Hidden Layer 2=50, Hidden Layer 3=80
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 866us/step
# Training model with configuration 197: Hidden Layer 1=40, Hidden Layer 2=50, Hidden Layer 3=90
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 994us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 830us/step
# Training model with configuration 198: Hidden Layer 1=40, Hidden Layer 2=50, Hidden Layer 3=100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 791us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 914us/step
# Training model with configuration 199: Hidden Layer 1=40, Hidden Layer 2=60, Hidden Layer 3=20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 997us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 831us/step
# Training model with configuration 200: Hidden Layer 1=40, Hidden Layer 2=60, Hidden Layer 3=30
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 998us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Training model with configuration 201: Hidden Layer 1=40, Hidden Layer 2=60, Hidden Layer 3=40
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Training model with configuration 202: Hidden Layer 1=40, Hidden Layer 2=60, Hidden Layer 3=50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Training model with configuration 203: Hidden Layer 1=40, Hidden Layer 2=60, Hidden Layer 3=60
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Training model with configuration 204: Hidden Layer 1=40, Hidden Layer 2=60, Hidden Layer 3=70
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 990us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 911us/step
# Training model with configuration 205: Hidden Layer 1=40, Hidden Layer 2=60, Hidden Layer 3=80
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 992us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 754us/step
# Training model with configuration 206: Hidden Layer 1=40, Hidden Layer 2=60, Hidden Layer 3=90
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 668us/step
# Training model with configuration 207: Hidden Layer 1=40, Hidden Layer 2=60, Hidden Layer 3=100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Training model with configuration 208: Hidden Layer 1=40, Hidden Layer 2=70, Hidden Layer 3=20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 748us/step
# Training model with configuration 209: Hidden Layer 1=40, Hidden Layer 2=70, Hidden Layer 3=30
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 998us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 750us/step
# Training model with configuration 210: Hidden Layer 1=40, Hidden Layer 2=70, Hidden Layer 3=40
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 792us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 748us/step
# Training model with configuration 211: Hidden Layer 1=40, Hidden Layer 2=70, Hidden Layer 3=50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 798us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 664us/step
# Training model with configuration 212: Hidden Layer 1=40, Hidden Layer 2=70, Hidden Layer 3=60
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 991us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 665us/step
# Training model with configuration 213: Hidden Layer 1=40, Hidden Layer 2=70, Hidden Layer 3=70
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 998us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 997us/step
# Training model with configuration 214: Hidden Layer 1=40, Hidden Layer 2=70, Hidden Layer 3=80
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 831us/step
# Training model with configuration 215: Hidden Layer 1=40, Hidden Layer 2=70, Hidden Layer 3=90
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 997us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 665us/step
# Training model with configuration 216: Hidden Layer 1=40, Hidden Layer 2=70, Hidden Layer 3=100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 997us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 791us/step
# Training model with configuration 217: Hidden Layer 1=40, Hidden Layer 2=80, Hidden Layer 3=20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 997us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 748us/step
# Training model with configuration 218: Hidden Layer 1=40, Hidden Layer 2=80, Hidden Layer 3=30
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 998us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 834us/step
# Training model with configuration 219: Hidden Layer 1=40, Hidden Layer 2=80, Hidden Layer 3=40
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 798us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Training model with configuration 220: Hidden Layer 1=40, Hidden Layer 2=80, Hidden Layer 3=50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 960us/step
# Training model with configuration 221: Hidden Layer 1=40, Hidden Layer 2=80, Hidden Layer 3=60
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 811us/step
# Training model with configuration 222: Hidden Layer 1=40, Hidden Layer 2=80, Hidden Layer 3=70
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 806us/step
# Training model with configuration 223: Hidden Layer 1=40, Hidden Layer 2=80, Hidden Layer 3=80
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 739us/step
# Training model with configuration 224: Hidden Layer 1=40, Hidden Layer 2=80, Hidden Layer 3=90
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 890us/step
# Training model with configuration 225: Hidden Layer 1=40, Hidden Layer 2=80, Hidden Layer 3=100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# ...
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 998us/step
# Training model with configuration 656: Hidden Layer 1=100, Hidden Layer 2=20, Hidden Layer 3=90
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 799us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 833us/step
# Training model with configuration 657: Hidden Layer 1=100, Hidden Layer 2=20, Hidden Layer 3=100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 998us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 995us/step
# Training model with configuration 658: Hidden Layer 1=100, Hidden Layer 2=30, Hidden Layer 3=20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 798us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 669us/step
# Training model with configuration 659: Hidden Layer 1=100, Hidden Layer 2=30, Hidden Layer 3=30
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 831us/step
# Training model with configuration 660: Hidden Layer 1=100, Hidden Layer 2=30, Hidden Layer 3=40
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 803us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 874us/step
# Training model with configuration 661: Hidden Layer 1=100, Hidden Layer 2=30, Hidden Layer 3=50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 899us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 831us/step
# Training model with configuration 662: Hidden Layer 1=100, Hidden Layer 2=30, Hidden Layer 3=60
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 745us/step
# Training model with configuration 663: Hidden Layer 1=100, Hidden Layer 2=30, Hidden Layer 3=70
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 999us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 748us/step
# Training model with configuration 664: Hidden Layer 1=100, Hidden Layer 2=30, Hidden Layer 3=80
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 791us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 748us/step
# Training model with configuration 665: Hidden Layer 1=100, Hidden Layer 2=30, Hidden Layer 3=90
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 798us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Training model with configuration 666: Hidden Layer 1=100, Hidden Layer 2=30, Hidden Layer 3=100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 798us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 748us/step
# Training model with configuration 667: Hidden Layer 1=100, Hidden Layer 2=40, Hidden Layer 3=20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Training model with configuration 668: Hidden Layer 1=100, Hidden Layer 2=40, Hidden Layer 3=30
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 833us/step
# Training model with configuration 669: Hidden Layer 1=100, Hidden Layer 2=40, Hidden Layer 3=40
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 798us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 791us/step
# Training model with configuration 670: Hidden Layer 1=100, Hidden Layer 2=40, Hidden Layer 3=50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Training model with configuration 671: Hidden Layer 1=100, Hidden Layer 2=40, Hidden Layer 3=60
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 997us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 997us/step
# Training model with configuration 672: Hidden Layer 1=100, Hidden Layer 2=40, Hidden Layer 3=70
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 748us/step
# Training model with configuration 673: Hidden Layer 1=100, Hidden Layer 2=40, Hidden Layer 3=80
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 798us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 831us/step
# Training model with configuration 674: Hidden Layer 1=100, Hidden Layer 2=40, Hidden Layer 3=90
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 792us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 834us/step
# Training model with configuration 675: Hidden Layer 1=100, Hidden Layer 2=40, Hidden Layer 3=100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Training model with configuration 676: Hidden Layer 1=100, Hidden Layer 2=50, Hidden Layer 3=20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 798us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 874us/step
# Training model with configuration 677: Hidden Layer 1=100, Hidden Layer 2=50, Hidden Layer 3=30
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Training model with configuration 678: Hidden Layer 1=100, Hidden Layer 2=50, Hidden Layer 3=40
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 997us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 914us/step
# Training model with configuration 679: Hidden Layer 1=100, Hidden Layer 2=50, Hidden Layer 3=50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 801us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 710us/step
# Training model with configuration 680: Hidden Layer 1=100, Hidden Layer 2=50, Hidden Layer 3=60
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 914us/step
# Training model with configuration 681: Hidden Layer 1=100, Hidden Layer 2=50, Hidden Layer 3=70
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 997us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 831us/step
# Training model with configuration 682: Hidden Layer 1=100, Hidden Layer 2=50, Hidden Layer 3=80
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 798us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 998us/step
# Training model with configuration 683: Hidden Layer 1=100, Hidden Layer 2=50, Hidden Layer 3=90
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 991us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 828us/step
# Training model with configuration 684: Hidden Layer 1=100, Hidden Layer 2=50, Hidden Layer 3=100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 997us/step
# Training model with configuration 685: Hidden Layer 1=100, Hidden Layer 2=60, Hidden Layer 3=20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 831us/step
# Training model with configuration 686: Hidden Layer 1=100, Hidden Layer 2=60, Hidden Layer 3=30
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 998us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 914us/step
# Training model with configuration 687: Hidden Layer 1=100, Hidden Layer 2=60, Hidden Layer 3=40
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Training model with configuration 688: Hidden Layer 1=100, Hidden Layer 2=60, Hidden Layer 3=50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Training model with configuration 689: Hidden Layer 1=100, Hidden Layer 2=60, Hidden Layer 3=60
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 992us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 831us/step
# Training model with configuration 690: Hidden Layer 1=100, Hidden Layer 2=60, Hidden Layer 3=70
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 914us/step
# Training model with configuration 691: Hidden Layer 1=100, Hidden Layer 2=60, Hidden Layer 3=80
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Training model with configuration 692: Hidden Layer 1=100, Hidden Layer 2=60, Hidden Layer 3=90
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 915us/step
# Training model with configuration 693: Hidden Layer 1=100, Hidden Layer 2=60, Hidden Layer 3=100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 997us/step
# Training model with configuration 694: Hidden Layer 1=100, Hidden Layer 2=70, Hidden Layer 3=20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Training model with configuration 695: Hidden Layer 1=100, Hidden Layer 2=70, Hidden Layer 3=30
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 998us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 831us/step
# Training model with configuration 696: Hidden Layer 1=100, Hidden Layer 2=70, Hidden Layer 3=40
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 912us/step
# Training model with configuration 697: Hidden Layer 1=100, Hidden Layer 2=70, Hidden Layer 3=50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 948us/step
# Training model with configuration 698: Hidden Layer 1=100, Hidden Layer 2=70, Hidden Layer 3=60
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 914us/step
# Training model with configuration 699: Hidden Layer 1=100, Hidden Layer 2=70, Hidden Layer 3=70
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 997us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 916us/step
# Training model with configuration 700: Hidden Layer 1=100, Hidden Layer 2=70, Hidden Layer 3=80
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 874us/step
# Training model with configuration 701: Hidden Layer 1=100, Hidden Layer 2=70, Hidden Layer 3=90
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 997us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 914us/step
# Training model with configuration 702: Hidden Layer 1=100, Hidden Layer 2=70, Hidden Layer 3=100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 798us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 914us/step
# Training model with configuration 703: Hidden Layer 1=100, Hidden Layer 2=80, Hidden Layer 3=20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 997us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 831us/step
# Training model with configuration 704: Hidden Layer 1=100, Hidden Layer 2=80, Hidden Layer 3=30
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 997us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 828us/step
# Training model with configuration 705: Hidden Layer 1=100, Hidden Layer 2=80, Hidden Layer 3=40
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 914us/step
# Training model with configuration 706: Hidden Layer 1=100, Hidden Layer 2=80, Hidden Layer 3=50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Training model with configuration 707: Hidden Layer 1=100, Hidden Layer 2=80, Hidden Layer 3=60
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 992us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 997us/step
# Training model with configuration 708: Hidden Layer 1=100, Hidden Layer 2=80, Hidden Layer 3=70
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 996us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 831us/step
# Training model with configuration 709: Hidden Layer 1=100, Hidden Layer 2=80, Hidden Layer 3=80
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 914us/step
# Training model with configuration 710: Hidden Layer 1=100, Hidden Layer 2=80, Hidden Layer 3=90
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Training model with configuration 711: Hidden Layer 1=100, Hidden Layer 2=80, Hidden Layer 3=100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Training model with configuration 712: Hidden Layer 1=100, Hidden Layer 2=90, Hidden Layer 3=20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Training model with configuration 713: Hidden Layer 1=100, Hidden Layer 2=90, Hidden Layer 3=30
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 831us/step
# Training model with configuration 714: Hidden Layer 1=100, Hidden Layer 2=90, Hidden Layer 3=40
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 748us/step
# Training model with configuration 715: Hidden Layer 1=100, Hidden Layer 2=90, Hidden Layer 3=50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 831us/step
# Training model with configuration 716: Hidden Layer 1=100, Hidden Layer 2=90, Hidden Layer 3=60
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 997us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 914us/step
# Training model with configuration 717: Hidden Layer 1=100, Hidden Layer 2=90, Hidden Layer 3=70
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 991us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 914us/step
# Training model with configuration 718: Hidden Layer 1=100, Hidden Layer 2=90, Hidden Layer 3=80
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 998us/step
# Training model with configuration 719: Hidden Layer 1=100, Hidden Layer 2=90, Hidden Layer 3=90
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 833us/step
# Training model with configuration 720: Hidden Layer 1=100, Hidden Layer 2=90, Hidden Layer 3=100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 798us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 914us/step
# Training model with configuration 721: Hidden Layer 1=100, Hidden Layer 2=100, Hidden Layer 3=20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Training model with configuration 722: Hidden Layer 1=100, Hidden Layer 2=100, Hidden Layer 3=30
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Training model with configuration 723: Hidden Layer 1=100, Hidden Layer 2=100, Hidden Layer 3=40
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 997us/step
# Training model with configuration 724: Hidden Layer 1=100, Hidden Layer 2=100, Hidden Layer 3=50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Training model with configuration 725: Hidden Layer 1=100, Hidden Layer 2=100, Hidden Layer 3=60
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 998us/step
# Training model with configuration 726: Hidden Layer 1=100, Hidden Layer 2=100, Hidden Layer 3=70
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Training model with configuration 727: Hidden Layer 1=100, Hidden Layer 2=100, Hidden Layer 3=80
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 997us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 834us/step
# Training model with configuration 728: Hidden Layer 1=100, Hidden Layer 2=100, Hidden Layer 3=90
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 831us/step
# Training model with configuration 729: Hidden Layer 1=100, Hidden Layer 2=100, Hidden Layer 3=100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 873us/step
# Results saved to 3HiddenLayers_VariousNeurons_Results.xlsx

# %% [markdown]
# ### loss vs the number of epochs & MAE vs the number of epochs

# %%
def plot_loss(loss,val_loss):
  plt.figure()
  plt.style.use('bmh')
  plt.grid(False)
  plt.plot(loss, linewidth=2)
  plt.plot(val_loss, linewidth=2)
  plt.ylabel('Loss')
  plt.xlabel('Epoch')
  plt.legend(['Train', 'Val'], loc='upper right')
  plt.show()

def plot_mae(mae,val_mae):
  plt.figure()
  plt.style.use('ggplot')
  plt.grid(False)
  plt.plot(mae, linewidth=2)
  plt.plot(val_mae, linewidth=2)
  plt.ylabel('MAE')
  plt.xlabel('Epoch')
  plt.legend(['Train', 'Val'], loc='upper right')
  plt.show()

train_loss = (np.array(history.history["loss"]))/100
val_loss = np.array((history.history["val_loss"]))/100

plot_loss(train_loss, val_loss)
plot_mae(history.history["mae"], history.history["val_mae"])

# %% [markdown]
# ### Correlation between the actual output and the predicted output with the training dataset

# %%
custom_params = {"axes.spines.right": False, "axes.spines.top": False}
sns.set_theme(style="ticks", rc=custom_params)
a = plt.axes(aspect='equal')
plt.scatter(y_train, train_pred, s = 20, alpha=0.7, c = 'brown')
plt.xlabel('Actual Critical Buckling Loads (kN)')
plt.ylabel('Predicted Critical Buckling Loads (kN)')
plt.annotate("R-squared = {:.3f}".format(r2_score(y_train, train_pred)), (6, 17.5))
plt.xlim([5, 20])
plt.ylim([5, 20])
plt.plot([5, 20], [5, 20])
plt.plot()

# %% [markdown]
# ### Correlation between the actual output and the predicted output with the testing dataset

# %%
custom_params = {"axes.spines.right": False, "axes.spines.top": False}
sns.set_theme(style="ticks", rc=custom_params)
a = plt.axes(aspect='equal')
plt.scatter(y_test, test_pred, s = 20, alpha=0.7, c = 'brown')
plt.xlabel('Actual Critical Buckling Loads (kN)')
plt.ylabel('Predicted Critical Buckling Loads (kN)')
plt.annotate("R-squared = {:.3f}".format(r2_score(y_train, train_pred)), (5, 19))
plt.xlim([4, 20])
plt.ylim([4, 20])
plt.plot([4, 20], [4, 20])
plt.plot()

# %% [markdown]
# ## Variable importance SHAP plot

# %%
### VARIABLE IMPORTANCE
# See more here: https://shap-lrjball.readthedocs.io/en/latest/example_notebooks/plots/bar.html
features = ["Number of holes, nh", "Web-post width, WP (mm)",  "Web opening diameter, Do (mm)",  "Ply 1 (ø)", "Ply 2 (ø)", "Ply 3 (ø)", "Ply 4 (ø)", "Ply 5 (ø)", "Ply 6 (ø)", "Ply 7 (ø)", "Ply 8 (ø)"]

# Create a SHAP explainer using KernelExplainer
explainer = shap.KernelExplainer(model, shap.sample(X_train, 1))

# Calculate SHAP values for the test dataset
shap_values = explainer.shap_values(X_test)

# Reshape shap_values to remove the last dimension
shap_values_reshaped = shap_values.reshape(X_test.shape)  # Assuming X_test.shape is (389, 11)

# Visualize feature importances using bar plot
shap.summary_plot(shap_values_reshaped, X_test, feature_names=features, plot_type="bar")
plt.show()
