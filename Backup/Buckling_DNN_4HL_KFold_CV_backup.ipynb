# %% [markdown]
# ##  A 4-Hidden Layer Architecture
# What is happening here?
#     [1] A traditional ANN model.
#     [2] Import and preprocessing data.
#     [3] Trigonometric transformations, which converting the original angle plies into sine and cosine values range between -1 and 1 to helps normalize data.
#     [4] Create a neural network model with specific hidden layer and the model uses the Sequential API from Keras, starting with an input layer, followed by a dense (fully connected) hidden layer with ReLU activation, and then an output layer with linear activation (for regression tasks).
#     [5] Model Training and Evaluation: run over a range of different number of neurons (from 20 to 80 with step of 20) to tune the model's hyperparameters.
#     For each number of neurons: A KerasRegressor wrapper is instantiated with the defined neural network model and training settings (epochs, batch size).
#     5-Fold Cross-Validation for robust evaluates the model's performance metrics (MSE, MAE, R-squared) on each fold of the data and to avoid overfitting.
#     [6] Model Evaluation (mean and standard deviation of performance metrics).
#     [7] Plot Mean of(R2, MAE, RMSE) vs number of neurons.

# %%
import pandas as pd 
import numpy as np                                             
from keras.models import Sequential
from keras.layers import Dense, Input
from keras.optimizers import Adam
from matplotlib import pyplot as plt
from sklearn.base import TransformerMixin
from scikeras.wrappers import KerasRegressor
from sklearn.model_selection import KFold, cross_validate

## Import data
bucklingdata = pd.read_csv("CBL_SimulationResults.csv", encoding='cp1252')

## Convert the hole_column from integer into a floating data type
bucklingdata['Number of holes, nh'] = bucklingdata['Number of holes, nh'].astype('float64')
bucklingdata['Web opening diameter, Do (mm)'] = bucklingdata['Web opening diameter, Do (mm)'].astype('float64')

## Trigonometric transformation of the ply angles: We develop a trigonometric transformation function to convert the angles (this is important)
# Create a transformation class here for the angle plies:
class TrigonometricTransformer(TransformerMixin):
    def __init__(self, start_column=1, end_column=-1):
        self.start_column = start_column
        self.end_column = end_column
        self.transform_functions = [np.sin, np.cos]

    def fit(self, X, y=None):
        return self

    def transform(self, X):
        X_transformed = X.copy()
        columns_to_transform = X.columns[self.start_column:self.end_column]

        for col in columns_to_transform:
            for func in self.transform_functions:
                X_transformed[col + '_' + func.__name__] = func(X[col])

        # Remove the original columns
        X_transformed.drop(columns=columns_to_transform, inplace=True)

        return X_transformed

# Specify the input and output datasets
input_data = bucklingdata.drop(['Critical Buckling Load (N)','Critical Buckling Load (kN)'], axis=1)
output_data = bucklingdata['Critical Buckling Load (kN)']

# Apply the transformation on the ply columns
transformer = TrigonometricTransformer(start_column=3, end_column=11)
# Transform the input DataFrame
transformed_bucklingdata = transformer.fit_transform(input_data)

# The input dimension for the Neural Network is then obtained as. Then, the input_size will use in following: model.add(Input(shape=(19,)))
input_size = transformed_bucklingdata.shape[1]
#print(input_size)

## Define a specific neural network model with one hidden layer
def create_model4H(neurons_list):
    model = Sequential()
    model.add(Input(shape=(19,)))
    hp_activation = 'selu'
    model.add(Dense(neurons_list[0], activation=hp_activation))
    model.add(Dense(neurons_list[1], activation=hp_activation))
    model.add(Dense(neurons_list[2], activation=hp_activation))
    model.add(Dense(neurons_list[3], activation=hp_activation))
    model.add(Dense(1, activation='linear'))
    hp_learning_rate = 0.01
    model.compile(loss='mse',
                  optimizer=Adam(learning_rate=hp_learning_rate),
                  metrics=['mae'])
    return model

# Pass the input and output dataframes to X , y (this is just convention in Python ML)
X = transformed_bucklingdata.copy()
y = output_data.copy()

# Specify the range for neurons in the first and second hidden layers
min_neurons = 20
max_neurons = 80
step = 20

neuron_configs = []


# Generate configurations with increasing neurons in all three layers
for neurons1 in range(min_neurons, max_neurons + 1, step):
    for neurons2 in range(min_neurons, max_neurons + 1, step):
        for neurons3 in range(min_neurons, max_neurons + 1, step):
            for neurons4 in range(min_neurons, max_neurons + 1, step):
                neuron_configs.append((neurons1, neurons2, neurons3, neurons4))

# Define lists to store results
results = []


for i, (p1, p2, p3, p4) in enumerate(neuron_configs):
    print(f"Training model with configuration {i+1}: Hidden Layer 1={p1}, Hidden Layer 2={p2}, Hidden Layer 3={p3}, Hidden Layer 4={p4}")
    
    keras_regressor = KerasRegressor(model=lambda: create_model4H([neurons1, neurons2, neurons3, neurons4]), epochs=150, batch_size=32, verbose=0)
    
    # Use cross_val_score to evaluate the model
    # Cross validation
    kf = KFold(n_splits=5, shuffle=True, random_state=42)
    cv_results = cross_validate(keras_regressor, X, y, cv=kf,
                             scoring=('neg_mean_squared_error', 'neg_mean_absolute_error', 'r2'))
    mse_scores = -cv_results['test_neg_mean_squared_error']
    mae_scores = -cv_results['test_neg_mean_absolute_error']
    r2_scores = cv_results['test_r2']                           # R-squared scores are already positive
         
    # Store the evaluation metrics in a DataFrame
    result_df = pd.DataFrame({
        'Configuration': i + 1,
        'Neurons_1HL': p1,
        'Neurons_2HL': p2,
        'Neurons_3HL': p3,
        'Neurons_4HL': p4,
        'Mean RMSE': np.sqrt(mse_scores).mean(),
        'Std RMSE': np.sqrt(mse_scores).std(),
        'Mean MAE': mae_scores.mean(),
        'Std MAE': mae_scores.std(),
        'Mean R-squared': r2_scores.mean(),
        'Std R-squared': r2_scores.std()
    }, index=[0])
    
    results.append(result_df)

# Concatenate all results into a single DataFrame
results_df = pd.concat(results, ignore_index=True)

# Save results to an Excel file
results_df.to_excel('4HL_Neurons_Network_Results_KFold_CV.xlsx', index=False)
print()
print("------------Congrats! You have successfully save the results to 4HL_Neurons_Network_Results_KFold_CV------------")

# Plot R-squared against neurons
plt.errorbar(results_df['Neurons_1HL'], results_df['Mean R-squared'], yerr=results_df['Std R-squared'], fmt='o', label='Neurons_1HL')
plt.errorbar(results_df['Neurons_2HL'], results_df['Mean R-squared'], yerr=results_df['Std R-squared'], fmt='o', label='Neurons_2HL')
plt.errorbar(results_df['Neurons_3HL'], results_df['Mean R-squared'], yerr=results_df['Std R-squared'], fmt='o', label='Neurons_3HL')
plt.errorbar(results_df['Neurons_4HL'], results_df['Mean R-squared'], yerr=results_df['Std R-squared'], fmt='o', label='Neurons_4HL')
plt.xlabel('Number of Neurons')
plt.ylabel('Mean R-squared')
plt.title('Mean R-squared vs. Number of Neurons')
plt.legend()
plt.show()

# Plot MAE against neurons
plt.errorbar(results_df['Neurons_1HL'], results_df['Mean MAE'], yerr=results_df['Std MAE'], fmt='o', label='Neurons_1HL')
plt.errorbar(results_df['Neurons_2HL'], results_df['Mean MAE'], yerr=results_df['Std MAE'], fmt='o', label='Neurons_2HL')
plt.errorbar(results_df['Neurons_3HL'], results_df['Mean MAE'], yerr=results_df['Std MAE'], fmt='o', label='Neurons_3HL')
plt.errorbar(results_df['Neurons_4HL'], results_df['Mean MAE'], yerr=results_df['Std MAE'], fmt='o', label='Neurons_4HL')
plt.xlabel('Number of Neurons')
plt.ylabel('Mean MAE')
plt.title('Mean MAE vs. Number of Neurons')
plt.legend()
plt.show()

# Plot RMSE against neurons
plt.errorbar(results_df['Neurons_1HL'], results_df['Mean RMSE'], yerr=results_df['Std RMSE'], fmt='o', label='Neurons_1HL')
plt.errorbar(results_df['Neurons_2HL'], results_df['Mean RMSE'], yerr=results_df['Std RMSE'], fmt='o', label='Neurons_2HL')
plt.errorbar(results_df['Neurons_3HL'], results_df['Mean RMSE'], yerr=results_df['Std RMSE'], fmt='o', label='Neurons_3HL')
plt.errorbar(results_df['Neurons_4HL'], results_df['Mean RMSE'], yerr=results_df['Std RMSE'], fmt='o', label='Neurons_4HL')
plt.xlabel('Number of Neurons')
plt.ylabel('Mean RMSE')
plt.title('Mean RMSE vs. Number of Neurons')
plt.legend()
plt.show()
# Out:
# Training model with configuration 1: Hidden Layer 1=20, Hidden Layer 2=20, Hidden Layer 3=20, Hidden Layer 4=20
# Training model with configuration 2: Hidden Layer 1=20, Hidden Layer 2=20, Hidden Layer 3=20, Hidden Layer 4=40
# Training model with configuration 3: Hidden Layer 1=20, Hidden Layer 2=20, Hidden Layer 3=20, Hidden Layer 4=60
# Training model with configuration 4: Hidden Layer 1=20, Hidden Layer 2=20, Hidden Layer 3=20, Hidden Layer 4=80
# Training model with configuration 5: Hidden Layer 1=20, Hidden Layer 2=20, Hidden Layer 3=40, Hidden Layer 4=20
# Training model with configuration 6: Hidden Layer 1=20, Hidden Layer 2=20, Hidden Layer 3=40, Hidden Layer 4=40
# Training model with configuration 7: Hidden Layer 1=20, Hidden Layer 2=20, Hidden Layer 3=40, Hidden Layer 4=60
# Training model with configuration 8: Hidden Layer 1=20, Hidden Layer 2=20, Hidden Layer 3=40, Hidden Layer 4=80
# Training model with configuration 9: Hidden Layer 1=20, Hidden Layer 2=20, Hidden Layer 3=60, Hidden Layer 4=20
# Training model with configuration 10: Hidden Layer 1=20, Hidden Layer 2=20, Hidden Layer 3=60, Hidden Layer 4=40
# Training model with configuration 11: Hidden Layer 1=20, Hidden Layer 2=20, Hidden Layer 3=60, Hidden Layer 4=60
# Training model with configuration 12: Hidden Layer 1=20, Hidden Layer 2=20, Hidden Layer 3=60, Hidden Layer 4=80
# Training model with configuration 13: Hidden Layer 1=20, Hidden Layer 2=20, Hidden Layer 3=80, Hidden Layer 4=20
# Training model with configuration 14: Hidden Layer 1=20, Hidden Layer 2=20, Hidden Layer 3=80, Hidden Layer 4=40
# Training model with configuration 15: Hidden Layer 1=20, Hidden Layer 2=20, Hidden Layer 3=80, Hidden Layer 4=60
# Training model with configuration 16: Hidden Layer 1=20, Hidden Layer 2=20, Hidden Layer 3=80, Hidden Layer 4=80
# Training model with configuration 17: Hidden Layer 1=20, Hidden Layer 2=40, Hidden Layer 3=20, Hidden Layer 4=20
# Training model with configuration 18: Hidden Layer 1=20, Hidden Layer 2=40, Hidden Layer 3=20, Hidden Layer 4=40
# Training model with configuration 19: Hidden Layer 1=20, Hidden Layer 2=40, Hidden Layer 3=20, Hidden Layer 4=60
# Training model with configuration 20: Hidden Layer 1=20, Hidden Layer 2=40, Hidden Layer 3=20, Hidden Layer 4=80
# Training model with configuration 21: Hidden Layer 1=20, Hidden Layer 2=40, Hidden Layer 3=40, Hidden Layer 4=20
# Training model with configuration 22: Hidden Layer 1=20, Hidden Layer 2=40, Hidden Layer 3=40, Hidden Layer 4=40
# Training model with configuration 23: Hidden Layer 1=20, Hidden Layer 2=40, Hidden Layer 3=40, Hidden Layer 4=60
# Training model with configuration 24: Hidden Layer 1=20, Hidden Layer 2=40, Hidden Layer 3=40, Hidden Layer 4=80
# Training model with configuration 25: Hidden Layer 1=20, Hidden Layer 2=40, Hidden Layer 3=60, Hidden Layer 4=20
# Training model with configuration 26: Hidden Layer 1=20, Hidden Layer 2=40, Hidden Layer 3=60, Hidden Layer 4=40
# Training model with configuration 27: Hidden Layer 1=20, Hidden Layer 2=40, Hidden Layer 3=60, Hidden Layer 4=60
# Training model with configuration 28: Hidden Layer 1=20, Hidden Layer 2=40, Hidden Layer 3=60, Hidden Layer 4=80
# Training model with configuration 29: Hidden Layer 1=20, Hidden Layer 2=40, Hidden Layer 3=80, Hidden Layer 4=20
# Training model with configuration 30: Hidden Layer 1=20, Hidden Layer 2=40, Hidden Layer 3=80, Hidden Layer 4=40
# Training model with configuration 31: Hidden Layer 1=20, Hidden Layer 2=40, Hidden Layer 3=80, Hidden Layer 4=60
# Training model with configuration 32: Hidden Layer 1=20, Hidden Layer 2=40, Hidden Layer 3=80, Hidden Layer 4=80
# Training model with configuration 33: Hidden Layer 1=20, Hidden Layer 2=60, Hidden Layer 3=20, Hidden Layer 4=20
# Training model with configuration 34: Hidden Layer 1=20, Hidden Layer 2=60, Hidden Layer 3=20, Hidden Layer 4=40
# Training model with configuration 35: Hidden Layer 1=20, Hidden Layer 2=60, Hidden Layer 3=20, Hidden Layer 4=60
# Training model with configuration 36: Hidden Layer 1=20, Hidden Layer 2=60, Hidden Layer 3=20, Hidden Layer 4=80
# Training model with configuration 37: Hidden Layer 1=20, Hidden Layer 2=60, Hidden Layer 3=40, Hidden Layer 4=20
# Training model with configuration 38: Hidden Layer 1=20, Hidden Layer 2=60, Hidden Layer 3=40, Hidden Layer 4=40
# Training model with configuration 39: Hidden Layer 1=20, Hidden Layer 2=60, Hidden Layer 3=40, Hidden Layer 4=60
# Training model with configuration 40: Hidden Layer 1=20, Hidden Layer 2=60, Hidden Layer 3=40, Hidden Layer 4=80
# Training model with configuration 41: Hidden Layer 1=20, Hidden Layer 2=60, Hidden Layer 3=60, Hidden Layer 4=20
# Training model with configuration 42: Hidden Layer 1=20, Hidden Layer 2=60, Hidden Layer 3=60, Hidden Layer 4=40
# Training model with configuration 43: Hidden Layer 1=20, Hidden Layer 2=60, Hidden Layer 3=60, Hidden Layer 4=60
# Training model with configuration 44: Hidden Layer 1=20, Hidden Layer 2=60, Hidden Layer 3=60, Hidden Layer 4=80
# Training model with configuration 45: Hidden Layer 1=20, Hidden Layer 2=60, Hidden Layer 3=80, Hidden Layer 4=20
# Training model with configuration 46: Hidden Layer 1=20, Hidden Layer 2=60, Hidden Layer 3=80, Hidden Layer 4=40
# Training model with configuration 47: Hidden Layer 1=20, Hidden Layer 2=60, Hidden Layer 3=80, Hidden Layer 4=60
# Training model with configuration 48: Hidden Layer 1=20, Hidden Layer 2=60, Hidden Layer 3=80, Hidden Layer 4=80
# Training model with configuration 49: Hidden Layer 1=20, Hidden Layer 2=80, Hidden Layer 3=20, Hidden Layer 4=20
# Training model with configuration 50: Hidden Layer 1=20, Hidden Layer 2=80, Hidden Layer 3=20, Hidden Layer 4=40
# Training model with configuration 51: Hidden Layer 1=20, Hidden Layer 2=80, Hidden Layer 3=20, Hidden Layer 4=60
# Training model with configuration 52: Hidden Layer 1=20, Hidden Layer 2=80, Hidden Layer 3=20, Hidden Layer 4=80
# Training model with configuration 53: Hidden Layer 1=20, Hidden Layer 2=80, Hidden Layer 3=40, Hidden Layer 4=20
# Training model with configuration 54: Hidden Layer 1=20, Hidden Layer 2=80, Hidden Layer 3=40, Hidden Layer 4=40
# Training model with configuration 55: Hidden Layer 1=20, Hidden Layer 2=80, Hidden Layer 3=40, Hidden Layer 4=60
# Training model with configuration 56: Hidden Layer 1=20, Hidden Layer 2=80, Hidden Layer 3=40, Hidden Layer 4=80
# Training model with configuration 57: Hidden Layer 1=20, Hidden Layer 2=80, Hidden Layer 3=60, Hidden Layer 4=20
# Training model with configuration 58: Hidden Layer 1=20, Hidden Layer 2=80, Hidden Layer 3=60, Hidden Layer 4=40
# Training model with configuration 59: Hidden Layer 1=20, Hidden Layer 2=80, Hidden Layer 3=60, Hidden Layer 4=60
# Training model with configuration 60: Hidden Layer 1=20, Hidden Layer 2=80, Hidden Layer 3=60, Hidden Layer 4=80
# Training model with configuration 61: Hidden Layer 1=20, Hidden Layer 2=80, Hidden Layer 3=80, Hidden Layer 4=20
# Training model with configuration 62: Hidden Layer 1=20, Hidden Layer 2=80, Hidden Layer 3=80, Hidden Layer 4=40
# Training model with configuration 63: Hidden Layer 1=20, Hidden Layer 2=80, Hidden Layer 3=80, Hidden Layer 4=60
# Training model with configuration 64: Hidden Layer 1=20, Hidden Layer 2=80, Hidden Layer 3=80, Hidden Layer 4=80
# Training model with configuration 65: Hidden Layer 1=40, Hidden Layer 2=20, Hidden Layer 3=20, Hidden Layer 4=20
# Training model with configuration 66: Hidden Layer 1=40, Hidden Layer 2=20, Hidden Layer 3=20, Hidden Layer 4=40
# Training model with configuration 67: Hidden Layer 1=40, Hidden Layer 2=20, Hidden Layer 3=20, Hidden Layer 4=60
# Training model with configuration 68: Hidden Layer 1=40, Hidden Layer 2=20, Hidden Layer 3=20, Hidden Layer 4=80
# Training model with configuration 69: Hidden Layer 1=40, Hidden Layer 2=20, Hidden Layer 3=40, Hidden Layer 4=20
# Training model with configuration 70: Hidden Layer 1=40, Hidden Layer 2=20, Hidden Layer 3=40, Hidden Layer 4=40
# Training model with configuration 71: Hidden Layer 1=40, Hidden Layer 2=20, Hidden Layer 3=40, Hidden Layer 4=60
# Training model with configuration 72: Hidden Layer 1=40, Hidden Layer 2=20, Hidden Layer 3=40, Hidden Layer 4=80
# Training model with configuration 73: Hidden Layer 1=40, Hidden Layer 2=20, Hidden Layer 3=60, Hidden Layer 4=20
# Training model with configuration 74: Hidden Layer 1=40, Hidden Layer 2=20, Hidden Layer 3=60, Hidden Layer 4=40
# Training model with configuration 75: Hidden Layer 1=40, Hidden Layer 2=20, Hidden Layer 3=60, Hidden Layer 4=60
# Training model with configuration 76: Hidden Layer 1=40, Hidden Layer 2=20, Hidden Layer 3=60, Hidden Layer 4=80
# Training model with configuration 77: Hidden Layer 1=40, Hidden Layer 2=20, Hidden Layer 3=80, Hidden Layer 4=20
# Training model with configuration 78: Hidden Layer 1=40, Hidden Layer 2=20, Hidden Layer 3=80, Hidden Layer 4=40
# Training model with configuration 79: Hidden Layer 1=40, Hidden Layer 2=20, Hidden Layer 3=80, Hidden Layer 4=60
# Training model with configuration 80: Hidden Layer 1=40, Hidden Layer 2=20, Hidden Layer 3=80, Hidden Layer 4=80
# Training model with configuration 81: Hidden Layer 1=40, Hidden Layer 2=40, Hidden Layer 3=20, Hidden Layer 4=20
# Training model with configuration 82: Hidden Layer 1=40, Hidden Layer 2=40, Hidden Layer 3=20, Hidden Layer 4=40
# Training model with configuration 83: Hidden Layer 1=40, Hidden Layer 2=40, Hidden Layer 3=20, Hidden Layer 4=60
# Training model with configuration 84: Hidden Layer 1=40, Hidden Layer 2=40, Hidden Layer 3=20, Hidden Layer 4=80
# Training model with configuration 85: Hidden Layer 1=40, Hidden Layer 2=40, Hidden Layer 3=40, Hidden Layer 4=20
# Training model with configuration 86: Hidden Layer 1=40, Hidden Layer 2=40, Hidden Layer 3=40, Hidden Layer 4=40
# Training model with configuration 87: Hidden Layer 1=40, Hidden Layer 2=40, Hidden Layer 3=40, Hidden Layer 4=60
# Training model with configuration 88: Hidden Layer 1=40, Hidden Layer 2=40, Hidden Layer 3=40, Hidden Layer 4=80
# Training model with configuration 89: Hidden Layer 1=40, Hidden Layer 2=40, Hidden Layer 3=60, Hidden Layer 4=20
# Training model with configuration 90: Hidden Layer 1=40, Hidden Layer 2=40, Hidden Layer 3=60, Hidden Layer 4=40
# Training model with configuration 91: Hidden Layer 1=40, Hidden Layer 2=40, Hidden Layer 3=60, Hidden Layer 4=60
# Training model with configuration 92: Hidden Layer 1=40, Hidden Layer 2=40, Hidden Layer 3=60, Hidden Layer 4=80
# Training model with configuration 93: Hidden Layer 1=40, Hidden Layer 2=40, Hidden Layer 3=80, Hidden Layer 4=20
# Training model with configuration 94: Hidden Layer 1=40, Hidden Layer 2=40, Hidden Layer 3=80, Hidden Layer 4=40
# Training model with configuration 95: Hidden Layer 1=40, Hidden Layer 2=40, Hidden Layer 3=80, Hidden Layer 4=60
# Training model with configuration 96: Hidden Layer 1=40, Hidden Layer 2=40, Hidden Layer 3=80, Hidden Layer 4=80
# Training model with configuration 97: Hidden Layer 1=40, Hidden Layer 2=60, Hidden Layer 3=20, Hidden Layer 4=20
# Training model with configuration 98: Hidden Layer 1=40, Hidden Layer 2=60, Hidden Layer 3=20, Hidden Layer 4=40
# Training model with configuration 99: Hidden Layer 1=40, Hidden Layer 2=60, Hidden Layer 3=20, Hidden Layer 4=60
# Training model with configuration 100: Hidden Layer 1=40, Hidden Layer 2=60, Hidden Layer 3=20, Hidden Layer 4=80
# Training model with configuration 101: Hidden Layer 1=40, Hidden Layer 2=60, Hidden Layer 3=40, Hidden Layer 4=20
# Training model with configuration 102: Hidden Layer 1=40, Hidden Layer 2=60, Hidden Layer 3=40, Hidden Layer 4=40
# Training model with configuration 103: Hidden Layer 1=40, Hidden Layer 2=60, Hidden Layer 3=40, Hidden Layer 4=60
# Training model with configuration 104: Hidden Layer 1=40, Hidden Layer 2=60, Hidden Layer 3=40, Hidden Layer 4=80
# Training model with configuration 105: Hidden Layer 1=40, Hidden Layer 2=60, Hidden Layer 3=60, Hidden Layer 4=20
# Training model with configuration 106: Hidden Layer 1=40, Hidden Layer 2=60, Hidden Layer 3=60, Hidden Layer 4=40
# Training model with configuration 107: Hidden Layer 1=40, Hidden Layer 2=60, Hidden Layer 3=60, Hidden Layer 4=60
# Training model with configuration 108: Hidden Layer 1=40, Hidden Layer 2=60, Hidden Layer 3=60, Hidden Layer 4=80
# Training model with configuration 109: Hidden Layer 1=40, Hidden Layer 2=60, Hidden Layer 3=80, Hidden Layer 4=20
# Training model with configuration 110: Hidden Layer 1=40, Hidden Layer 2=60, Hidden Layer 3=80, Hidden Layer 4=40
# Training model with configuration 111: Hidden Layer 1=40, Hidden Layer 2=60, Hidden Layer 3=80, Hidden Layer 4=60
# Training model with configuration 112: Hidden Layer 1=40, Hidden Layer 2=60, Hidden Layer 3=80, Hidden Layer 4=80
# Training model with configuration 113: Hidden Layer 1=40, Hidden Layer 2=80, Hidden Layer 3=20, Hidden Layer 4=20
# Training model with configuration 114: Hidden Layer 1=40, Hidden Layer 2=80, Hidden Layer 3=20, Hidden Layer 4=40
# Training model with configuration 115: Hidden Layer 1=40, Hidden Layer 2=80, Hidden Layer 3=20, Hidden Layer 4=60
# Training model with configuration 116: Hidden Layer 1=40, Hidden Layer 2=80, Hidden Layer 3=20, Hidden Layer 4=80
# Training model with configuration 117: Hidden Layer 1=40, Hidden Layer 2=80, Hidden Layer 3=40, Hidden Layer 4=20
# Training model with configuration 118: Hidden Layer 1=40, Hidden Layer 2=80, Hidden Layer 3=40, Hidden Layer 4=40
# Training model with configuration 119: Hidden Layer 1=40, Hidden Layer 2=80, Hidden Layer 3=40, Hidden Layer 4=60
# Training model with configuration 120: Hidden Layer 1=40, Hidden Layer 2=80, Hidden Layer 3=40, Hidden Layer 4=80
# Training model with configuration 121: Hidden Layer 1=40, Hidden Layer 2=80, Hidden Layer 3=60, Hidden Layer 4=20
# Training model with configuration 122: Hidden Layer 1=40, Hidden Layer 2=80, Hidden Layer 3=60, Hidden Layer 4=40
# Training model with configuration 123: Hidden Layer 1=40, Hidden Layer 2=80, Hidden Layer 3=60, Hidden Layer 4=60
# Training model with configuration 124: Hidden Layer 1=40, Hidden Layer 2=80, Hidden Layer 3=60, Hidden Layer 4=80
# Training model with configuration 125: Hidden Layer 1=40, Hidden Layer 2=80, Hidden Layer 3=80, Hidden Layer 4=20
# Training model with configuration 126: Hidden Layer 1=40, Hidden Layer 2=80, Hidden Layer 3=80, Hidden Layer 4=40
# Training model with configuration 127: Hidden Layer 1=40, Hidden Layer 2=80, Hidden Layer 3=80, Hidden Layer 4=60
# Training model with configuration 128: Hidden Layer 1=40, Hidden Layer 2=80, Hidden Layer 3=80, Hidden Layer 4=80
# Training model with configuration 129: Hidden Layer 1=60, Hidden Layer 2=20, Hidden Layer 3=20, Hidden Layer 4=20
# Training model with configuration 130: Hidden Layer 1=60, Hidden Layer 2=20, Hidden Layer 3=20, Hidden Layer 4=40
# Training model with configuration 131: Hidden Layer 1=60, Hidden Layer 2=20, Hidden Layer 3=20, Hidden Layer 4=60
# Training model with configuration 132: Hidden Layer 1=60, Hidden Layer 2=20, Hidden Layer 3=20, Hidden Layer 4=80
# Training model with configuration 133: Hidden Layer 1=60, Hidden Layer 2=20, Hidden Layer 3=40, Hidden Layer 4=20
# Training model with configuration 134: Hidden Layer 1=60, Hidden Layer 2=20, Hidden Layer 3=40, Hidden Layer 4=40
# Training model with configuration 135: Hidden Layer 1=60, Hidden Layer 2=20, Hidden Layer 3=40, Hidden Layer 4=60
# Training model with configuration 136: Hidden Layer 1=60, Hidden Layer 2=20, Hidden Layer 3=40, Hidden Layer 4=80
# Training model with configuration 137: Hidden Layer 1=60, Hidden Layer 2=20, Hidden Layer 3=60, Hidden Layer 4=20
# Training model with configuration 138: Hidden Layer 1=60, Hidden Layer 2=20, Hidden Layer 3=60, Hidden Layer 4=40
# Training model with configuration 139: Hidden Layer 1=60, Hidden Layer 2=20, Hidden Layer 3=60, Hidden Layer 4=60
# Training model with configuration 140: Hidden Layer 1=60, Hidden Layer 2=20, Hidden Layer 3=60, Hidden Layer 4=80
# Training model with configuration 141: Hidden Layer 1=60, Hidden Layer 2=20, Hidden Layer 3=80, Hidden Layer 4=20
# Training model with configuration 142: Hidden Layer 1=60, Hidden Layer 2=20, Hidden Layer 3=80, Hidden Layer 4=40
# Training model with configuration 143: Hidden Layer 1=60, Hidden Layer 2=20, Hidden Layer 3=80, Hidden Layer 4=60
# Training model with configuration 144: Hidden Layer 1=60, Hidden Layer 2=20, Hidden Layer 3=80, Hidden Layer 4=80
# Training model with configuration 145: Hidden Layer 1=60, Hidden Layer 2=40, Hidden Layer 3=20, Hidden Layer 4=20
# Training model with configuration 146: Hidden Layer 1=60, Hidden Layer 2=40, Hidden Layer 3=20, Hidden Layer 4=40
# Training model with configuration 147: Hidden Layer 1=60, Hidden Layer 2=40, Hidden Layer 3=20, Hidden Layer 4=60
# Training model with configuration 148: Hidden Layer 1=60, Hidden Layer 2=40, Hidden Layer 3=20, Hidden Layer 4=80
# Training model with configuration 149: Hidden Layer 1=60, Hidden Layer 2=40, Hidden Layer 3=40, Hidden Layer 4=20
# Training model with configuration 150: Hidden Layer 1=60, Hidden Layer 2=40, Hidden Layer 3=40, Hidden Layer 4=40
# Training model with configuration 151: Hidden Layer 1=60, Hidden Layer 2=40, Hidden Layer 3=40, Hidden Layer 4=60
# Training model with configuration 152: Hidden Layer 1=60, Hidden Layer 2=40, Hidden Layer 3=40, Hidden Layer 4=80
# Training model with configuration 153: Hidden Layer 1=60, Hidden Layer 2=40, Hidden Layer 3=60, Hidden Layer 4=20
# Training model with configuration 154: Hidden Layer 1=60, Hidden Layer 2=40, Hidden Layer 3=60, Hidden Layer 4=40
# Training model with configuration 155: Hidden Layer 1=60, Hidden Layer 2=40, Hidden Layer 3=60, Hidden Layer 4=60
# Training model with configuration 156: Hidden Layer 1=60, Hidden Layer 2=40, Hidden Layer 3=60, Hidden Layer 4=80
# Training model with configuration 157: Hidden Layer 1=60, Hidden Layer 2=40, Hidden Layer 3=80, Hidden Layer 4=20
# Training model with configuration 158: Hidden Layer 1=60, Hidden Layer 2=40, Hidden Layer 3=80, Hidden Layer 4=40
# Training model with configuration 159: Hidden Layer 1=60, Hidden Layer 2=40, Hidden Layer 3=80, Hidden Layer 4=60
# Training model with configuration 160: Hidden Layer 1=60, Hidden Layer 2=40, Hidden Layer 3=80, Hidden Layer 4=80
# Training model with configuration 161: Hidden Layer 1=60, Hidden Layer 2=60, Hidden Layer 3=20, Hidden Layer 4=20
# Training model with configuration 162: Hidden Layer 1=60, Hidden Layer 2=60, Hidden Layer 3=20, Hidden Layer 4=40
# Training model with configuration 163: Hidden Layer 1=60, Hidden Layer 2=60, Hidden Layer 3=20, Hidden Layer 4=60
# Training model with configuration 164: Hidden Layer 1=60, Hidden Layer 2=60, Hidden Layer 3=20, Hidden Layer 4=80
# Training model with configuration 165: Hidden Layer 1=60, Hidden Layer 2=60, Hidden Layer 3=40, Hidden Layer 4=20
# Training model with configuration 166: Hidden Layer 1=60, Hidden Layer 2=60, Hidden Layer 3=40, Hidden Layer 4=40
# Training model with configuration 167: Hidden Layer 1=60, Hidden Layer 2=60, Hidden Layer 3=40, Hidden Layer 4=60
# Training model with configuration 168: Hidden Layer 1=60, Hidden Layer 2=60, Hidden Layer 3=40, Hidden Layer 4=80
# Training model with configuration 169: Hidden Layer 1=60, Hidden Layer 2=60, Hidden Layer 3=60, Hidden Layer 4=20
# Training model with configuration 170: Hidden Layer 1=60, Hidden Layer 2=60, Hidden Layer 3=60, Hidden Layer 4=40
# Training model with configuration 171: Hidden Layer 1=60, Hidden Layer 2=60, Hidden Layer 3=60, Hidden Layer 4=60
# Training model with configuration 172: Hidden Layer 1=60, Hidden Layer 2=60, Hidden Layer 3=60, Hidden Layer 4=80
# Training model with configuration 173: Hidden Layer 1=60, Hidden Layer 2=60, Hidden Layer 3=80, Hidden Layer 4=20
# Training model with configuration 174: Hidden Layer 1=60, Hidden Layer 2=60, Hidden Layer 3=80, Hidden Layer 4=40
# Training model with configuration 175: Hidden Layer 1=60, Hidden Layer 2=60, Hidden Layer 3=80, Hidden Layer 4=60
# Training model with configuration 176: Hidden Layer 1=60, Hidden Layer 2=60, Hidden Layer 3=80, Hidden Layer 4=80
# Training model with configuration 177: Hidden Layer 1=60, Hidden Layer 2=80, Hidden Layer 3=20, Hidden Layer 4=20
# Training model with configuration 178: Hidden Layer 1=60, Hidden Layer 2=80, Hidden Layer 3=20, Hidden Layer 4=40
# Training model with configuration 179: Hidden Layer 1=60, Hidden Layer 2=80, Hidden Layer 3=20, Hidden Layer 4=60
# Training model with configuration 180: Hidden Layer 1=60, Hidden Layer 2=80, Hidden Layer 3=20, Hidden Layer 4=80
# Training model with configuration 181: Hidden Layer 1=60, Hidden Layer 2=80, Hidden Layer 3=40, Hidden Layer 4=20
# Training model with configuration 182: Hidden Layer 1=60, Hidden Layer 2=80, Hidden Layer 3=40, Hidden Layer 4=40
# Training model with configuration 183: Hidden Layer 1=60, Hidden Layer 2=80, Hidden Layer 3=40, Hidden Layer 4=60
# Training model with configuration 184: Hidden Layer 1=60, Hidden Layer 2=80, Hidden Layer 3=40, Hidden Layer 4=80
# Training model with configuration 185: Hidden Layer 1=60, Hidden Layer 2=80, Hidden Layer 3=60, Hidden Layer 4=20
# Training model with configuration 186: Hidden Layer 1=60, Hidden Layer 2=80, Hidden Layer 3=60, Hidden Layer 4=40
# Training model with configuration 187: Hidden Layer 1=60, Hidden Layer 2=80, Hidden Layer 3=60, Hidden Layer 4=60
# Training model with configuration 188: Hidden Layer 1=60, Hidden Layer 2=80, Hidden Layer 3=60, Hidden Layer 4=80
# Training model with configuration 189: Hidden Layer 1=60, Hidden Layer 2=80, Hidden Layer 3=80, Hidden Layer 4=20
# Training model with configuration 190: Hidden Layer 1=60, Hidden Layer 2=80, Hidden Layer 3=80, Hidden Layer 4=40
# Training model with configuration 191: Hidden Layer 1=60, Hidden Layer 2=80, Hidden Layer 3=80, Hidden Layer 4=60
# Training model with configuration 192: Hidden Layer 1=60, Hidden Layer 2=80, Hidden Layer 3=80, Hidden Layer 4=80
# Training model with configuration 193: Hidden Layer 1=80, Hidden Layer 2=20, Hidden Layer 3=20, Hidden Layer 4=20
# Training model with configuration 194: Hidden Layer 1=80, Hidden Layer 2=20, Hidden Layer 3=20, Hidden Layer 4=40
# Training model with configuration 195: Hidden Layer 1=80, Hidden Layer 2=20, Hidden Layer 3=20, Hidden Layer 4=60
# Training model with configuration 196: Hidden Layer 1=80, Hidden Layer 2=20, Hidden Layer 3=20, Hidden Layer 4=80
# Training model with configuration 197: Hidden Layer 1=80, Hidden Layer 2=20, Hidden Layer 3=40, Hidden Layer 4=20
# Training model with configuration 198: Hidden Layer 1=80, Hidden Layer 2=20, Hidden Layer 3=40, Hidden Layer 4=40
# Training model with configuration 199: Hidden Layer 1=80, Hidden Layer 2=20, Hidden Layer 3=40, Hidden Layer 4=60
# Training model with configuration 200: Hidden Layer 1=80, Hidden Layer 2=20, Hidden Layer 3=40, Hidden Layer 4=80
# Training model with configuration 201: Hidden Layer 1=80, Hidden Layer 2=20, Hidden Layer 3=60, Hidden Layer 4=20
# Training model with configuration 202: Hidden Layer 1=80, Hidden Layer 2=20, Hidden Layer 3=60, Hidden Layer 4=40
# Training model with configuration 203: Hidden Layer 1=80, Hidden Layer 2=20, Hidden Layer 3=60, Hidden Layer 4=60
# Training model with configuration 204: Hidden Layer 1=80, Hidden Layer 2=20, Hidden Layer 3=60, Hidden Layer 4=80
# Training model with configuration 205: Hidden Layer 1=80, Hidden Layer 2=20, Hidden Layer 3=80, Hidden Layer 4=20
# Training model with configuration 206: Hidden Layer 1=80, Hidden Layer 2=20, Hidden Layer 3=80, Hidden Layer 4=40
# Training model with configuration 207: Hidden Layer 1=80, Hidden Layer 2=20, Hidden Layer 3=80, Hidden Layer 4=60
# Training model with configuration 208: Hidden Layer 1=80, Hidden Layer 2=20, Hidden Layer 3=80, Hidden Layer 4=80
# Training model with configuration 209: Hidden Layer 1=80, Hidden Layer 2=40, Hidden Layer 3=20, Hidden Layer 4=20
# Training model with configuration 210: Hidden Layer 1=80, Hidden Layer 2=40, Hidden Layer 3=20, Hidden Layer 4=40
# Training model with configuration 211: Hidden Layer 1=80, Hidden Layer 2=40, Hidden Layer 3=20, Hidden Layer 4=60
# Training model with configuration 212: Hidden Layer 1=80, Hidden Layer 2=40, Hidden Layer 3=20, Hidden Layer 4=80
# Training model with configuration 213: Hidden Layer 1=80, Hidden Layer 2=40, Hidden Layer 3=40, Hidden Layer 4=20
# Training model with configuration 214: Hidden Layer 1=80, Hidden Layer 2=40, Hidden Layer 3=40, Hidden Layer 4=40
# Training model with configuration 215: Hidden Layer 1=80, Hidden Layer 2=40, Hidden Layer 3=40, Hidden Layer 4=60
# Training model with configuration 216: Hidden Layer 1=80, Hidden Layer 2=40, Hidden Layer 3=40, Hidden Layer 4=80
# Training model with configuration 217: Hidden Layer 1=80, Hidden Layer 2=40, Hidden Layer 3=60, Hidden Layer 4=20
# Training model with configuration 218: Hidden Layer 1=80, Hidden Layer 2=40, Hidden Layer 3=60, Hidden Layer 4=40
# Training model with configuration 219: Hidden Layer 1=80, Hidden Layer 2=40, Hidden Layer 3=60, Hidden Layer 4=60
# Training model with configuration 220: Hidden Layer 1=80, Hidden Layer 2=40, Hidden Layer 3=60, Hidden Layer 4=80
# Training model with configuration 221: Hidden Layer 1=80, Hidden Layer 2=40, Hidden Layer 3=80, Hidden Layer 4=20
# Training model with configuration 222: Hidden Layer 1=80, Hidden Layer 2=40, Hidden Layer 3=80, Hidden Layer 4=40
# Training model with configuration 223: Hidden Layer 1=80, Hidden Layer 2=40, Hidden Layer 3=80, Hidden Layer 4=60
# Training model with configuration 224: Hidden Layer 1=80, Hidden Layer 2=40, Hidden Layer 3=80, Hidden Layer 4=80
# Training model with configuration 225: Hidden Layer 1=80, Hidden Layer 2=60, Hidden Layer 3=20, Hidden Layer 4=20
# Training model with configuration 226: Hidden Layer 1=80, Hidden Layer 2=60, Hidden Layer 3=20, Hidden Layer 4=40
# Training model with configuration 227: Hidden Layer 1=80, Hidden Layer 2=60, Hidden Layer 3=20, Hidden Layer 4=60
# Training model with configuration 228: Hidden Layer 1=80, Hidden Layer 2=60, Hidden Layer 3=20, Hidden Layer 4=80
# Training model with configuration 229: Hidden Layer 1=80, Hidden Layer 2=60, Hidden Layer 3=40, Hidden Layer 4=20
# Training model with configuration 230: Hidden Layer 1=80, Hidden Layer 2=60, Hidden Layer 3=40, Hidden Layer 4=40
# Training model with configuration 231: Hidden Layer 1=80, Hidden Layer 2=60, Hidden Layer 3=40, Hidden Layer 4=60
# Training model with configuration 232: Hidden Layer 1=80, Hidden Layer 2=60, Hidden Layer 3=40, Hidden Layer 4=80
# Training model with configuration 233: Hidden Layer 1=80, Hidden Layer 2=60, Hidden Layer 3=60, Hidden Layer 4=20
# Training model with configuration 234: Hidden Layer 1=80, Hidden Layer 2=60, Hidden Layer 3=60, Hidden Layer 4=40
# Training model with configuration 235: Hidden Layer 1=80, Hidden Layer 2=60, Hidden Layer 3=60, Hidden Layer 4=60
# Training model with configuration 236: Hidden Layer 1=80, Hidden Layer 2=60, Hidden Layer 3=60, Hidden Layer 4=80
# Training model with configuration 237: Hidden Layer 1=80, Hidden Layer 2=60, Hidden Layer 3=80, Hidden Layer 4=20
# Training model with configuration 238: Hidden Layer 1=80, Hidden Layer 2=60, Hidden Layer 3=80, Hidden Layer 4=40
# Training model with configuration 239: Hidden Layer 1=80, Hidden Layer 2=60, Hidden Layer 3=80, Hidden Layer 4=60
# Training model with configuration 240: Hidden Layer 1=80, Hidden Layer 2=60, Hidden Layer 3=80, Hidden Layer 4=80
# Training model with configuration 241: Hidden Layer 1=80, Hidden Layer 2=80, Hidden Layer 3=20, Hidden Layer 4=20
# Training model with configuration 242: Hidden Layer 1=80, Hidden Layer 2=80, Hidden Layer 3=20, Hidden Layer 4=40
# Training model with configuration 243: Hidden Layer 1=80, Hidden Layer 2=80, Hidden Layer 3=20, Hidden Layer 4=60
# Training model with configuration 244: Hidden Layer 1=80, Hidden Layer 2=80, Hidden Layer 3=20, Hidden Layer 4=80
# Training model with configuration 245: Hidden Layer 1=80, Hidden Layer 2=80, Hidden Layer 3=40, Hidden Layer 4=20
# Training model with configuration 246: Hidden Layer 1=80, Hidden Layer 2=80, Hidden Layer 3=40, Hidden Layer 4=40
# Training model with configuration 247: Hidden Layer 1=80, Hidden Layer 2=80, Hidden Layer 3=40, Hidden Layer 4=60
# Training model with configuration 248: Hidden Layer 1=80, Hidden Layer 2=80, Hidden Layer 3=40, Hidden Layer 4=80
# Training model with configuration 249: Hidden Layer 1=80, Hidden Layer 2=80, Hidden Layer 3=60, Hidden Layer 4=20
# Training model with configuration 250: Hidden Layer 1=80, Hidden Layer 2=80, Hidden Layer 3=60, Hidden Layer 4=40
# Training model with configuration 251: Hidden Layer 1=80, Hidden Layer 2=80, Hidden Layer 3=60, Hidden Layer 4=60
# Training model with configuration 252: Hidden Layer 1=80, Hidden Layer 2=80, Hidden Layer 3=60, Hidden Layer 4=80
# Training model with configuration 253: Hidden Layer 1=80, Hidden Layer 2=80, Hidden Layer 3=80, Hidden Layer 4=20
# Training model with configuration 254: Hidden Layer 1=80, Hidden Layer 2=80, Hidden Layer 3=80, Hidden Layer 4=40
# Training model with configuration 255: Hidden Layer 1=80, Hidden Layer 2=80, Hidden Layer 3=80, Hidden Layer 4=60
# Training model with configuration 256: Hidden Layer 1=80, Hidden Layer 2=80, Hidden Layer 3=80, Hidden Layer 4=80
#
# ------------Congrats! You have successfully save the results to 4HL_Neurons_Network_Results_KFold_CV------------
