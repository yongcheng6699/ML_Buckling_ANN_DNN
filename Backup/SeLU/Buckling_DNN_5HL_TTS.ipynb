# %% [markdown]
# ##  A 5-Hidden Layer Architecture
# What is happening here?
#     [1] A traditional ANN model.
#     [2] Import and preprocessing data. The dataset is split into training and testing sets. Then, a validation set allows monitoring the model's performance on unseen data during training, which helps in early stopping and preventing overfitting.
#     [3] Create a neural network model with specific hidden layer and the model uses the Sequential API from Keras, starting with an input layer, followed by a dense (fully connected) hidden layer with ReLU activation, and then an output layer with linear activation (for regression tasks).
#     [4] Model Training and Evaluation: run over a range of different number of neurons (from 20 to 80 with step of 20) to tune the model's hyperparameters.
#     For each configuration: The model is trained on the training data for 150 epochs, with validation data used for validation during training.
#     Performance metrics such as R-squared, RMSE (Root Mean Squared Error), and MAE (Mean Absolute Error) are computed on training, validation, and test sets.
#     [5] Plot loss vs the number of epochs & MAE vs the number of epochs
#     [6] Plot Correlation between the actual output and the predicted output with the training dataset
#     [7] Plot Correlation between the actual output and the predicted output with the testing dataset
#     [8] Lastly, SHAP (SHapley Additive exPlanations) values are computed to explain variable importance in the model using shap library. SHAP summary plots (shap.summary_plot) are created to show the impact of different features on the model predictions.

# %%
import pandas as pd 
import numpy as np                                             
from sklearn.model_selection import train_test_split
from keras.models import Sequential
from keras.layers import Dense, Input
from keras.optimizers import Adam
from sklearn.metrics import r2_score
import math
from matplotlib import pyplot as plt
import seaborn as sns
import shap

## Imports the data
bucklingdata = pd.read_csv("CBL_SimulationResults.csv", encoding='cp1252')
input_data = bucklingdata.drop(['Critical Buckling Load (N)','Critical Buckling Load (kN)'], axis=1)
output_data = bucklingdata['Critical Buckling Load (kN)']

## Data splitting
np.random.seed(0)
X_train, X_test, y_train, y_test = train_test_split(input_data, output_data,
                                                   test_size=0.3,
                                                    shuffle=False,
                                                    stratify=None,
                                                    random_state=42)

# For validation number input and output data
val_no = round(0.2*y_train.size)
x_val = X_train[:val_no]
y_val = y_train[:val_no]

def create_model5H(hp_layer_1, hp_layer_2, hp_layer_3, hp_layer_4, hp_layer_5):
    model = Sequential()
    model.add(Input(shape=(11,)))
    hp_activation = 'relu'
    hp_learning_rate = 0.01
    model.add(Dense(hp_layer_1, activation=hp_activation))
    model.add(Dense(hp_layer_2, activation=hp_activation))
    model.add(Dense(hp_layer_3, activation=hp_activation))
    model.add(Dense(hp_layer_4, activation=hp_activation))
    model.add(Dense(hp_layer_5, activation=hp_activation))
    model.add(Dense(1, activation="linear"))
    # Compile your model with your optimizer, loss, and metrics
    model.compile(loss='mse',
                  optimizer=Adam(learning_rate = hp_learning_rate),
                  metrics=["mae"])
    return model

# Specify the range for neurons in the first and second hidden layers
min_neurons = 20
max_neurons = 80
step = 20

neuron_configs = []

# Generate configurations with increasing neurons in all five layers
for neurons1 in range(min_neurons, max_neurons + 1, step):
    for neurons2 in range(min_neurons, max_neurons + 1, step):
        for neurons3 in range(min_neurons, max_neurons + 1, step):
            for neurons4 in range(min_neurons, max_neurons + 1, step):
                for neurons5 in range(min_neurons, max_neurons + 1, step):
                    neuron_configs.append((neurons1, neurons2, neurons3, neurons4, neurons5))
                
results = []

## Train your model for a number of epochs, with the .fit()
## Get the performance metrics for the network and the learning curves
# Iterate over each configuration of neurons
for i, (p1, p2, p3, p4, p5) in enumerate(neuron_configs):
    print(f"Training model with configuration {i+1}: Hidden Layer 1={p1}, Hidden Layer 2={p2}, Hidden Layer 3={p3}, Hidden Layer 4={p4}, Hidden Layer 5={p5}")
    
    # Create the model for the current configuration
    model = create_model5H(p1, p2, p3, p4, p5)
    
    # Fit the model
    history = model.fit(X_train, y_train, epochs=150,
                        validation_data=(x_val, y_val), batch_size=32,
                        verbose=0)
    
    # Evaluate the model on training, validation, and test sets
    trainmse, trainmae = model.evaluate(X_train, y_train, verbose=0)
    valmse, valmae = model.evaluate(x_val, y_val, verbose=0)
    testmse, testmae = model.evaluate(X_test, y_test, verbose=0)
    
    # Predictions for R-squared calculation
    train_pred = model.predict(X_train)
    val_pred = model.predict(x_val)
    test_pred = model.predict(X_test)
    
    # Calculate R-squared scores
    train_r2 = r2_score(y_train, train_pred)
    val_r2 = r2_score(y_val, val_pred)
    test_r2 = r2_score(y_test, test_pred)
    
    # Store the evaluation metrics in a DataFrame
    result_df = pd.DataFrame({
        'Configuration': i + 1,
        'Neurons_1HL': p1,
        'Neurons_2HL': p2,
        'Neurons_3HL': p3,
        'Neurons_4HL': p4,
        'Neurons_5HL': p5,
        'Train R2': train_r2,
        'Val R2': val_r2,
        'Test R2': test_r2,
        'Train RMSE': math.sqrt(trainmse),
        'Val RMSE': math.sqrt(valmse),
        'Test RMSE': math.sqrt(testmse),
        'Train MAE': trainmae,
        'Val MAE': valmae,
        'Test MAE': testmae
    }, index=[0])
    
    results.append(result_df)

# Concatenate all results into a single DataFrame
results_df = pd.concat(results, ignore_index=True)

# Save the results to an Excel file
results_df.to_excel('5HL_Neurons_Network_Results_TTS.xlsx', index=False)
print()
print("------------Congrats! You have successfully save the results to 5HL_Neurons_Network_Results_TTS------------")
# Out:
# Training model with configuration 1: Hidden Layer 1=20, Hidden Layer 2=20, Hidden Layer 3=20, Hidden Layer 4=20, Hidden Layer 5=20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 990us/step
# Training model with configuration 2: Hidden Layer 1=20, Hidden Layer 2=20, Hidden Layer 3=20, Hidden Layer 4=20, Hidden Layer 5=40
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 833us/step
# Training model with configuration 3: Hidden Layer 1=20, Hidden Layer 2=20, Hidden Layer 3=20, Hidden Layer 4=20, Hidden Layer 5=60
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 927us/step
# Training model with configuration 4: Hidden Layer 1=20, Hidden Layer 2=20, Hidden Layer 3=20, Hidden Layer 4=20, Hidden Layer 5=80
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 997us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 785us/step
# Training model with configuration 5: Hidden Layer 1=20, Hidden Layer 2=20, Hidden Layer 3=20, Hidden Layer 4=40, Hidden Layer 5=20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 859us/step
# Training model with configuration 6: Hidden Layer 1=20, Hidden Layer 2=20, Hidden Layer 3=20, Hidden Layer 4=40, Hidden Layer 5=40
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 855us/step
# Training model with configuration 7: Hidden Layer 1=20, Hidden Layer 2=20, Hidden Layer 3=20, Hidden Layer 4=40, Hidden Layer 5=60
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 937us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 995us/step
# Training model with configuration 8: Hidden Layer 1=20, Hidden Layer 2=20, Hidden Layer 3=20, Hidden Layer 4=40, Hidden Layer 5=80
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 820us/step
# Training model with configuration 9: Hidden Layer 1=20, Hidden Layer 2=20, Hidden Layer 3=20, Hidden Layer 4=60, Hidden Layer 5=20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 886us/step
# Training model with configuration 10: Hidden Layer 1=20, Hidden Layer 2=20, Hidden Layer 3=20, Hidden Layer 4=60, Hidden Layer 5=40
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 997us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 954us/step
# Training model with configuration 11: Hidden Layer 1=20, Hidden Layer 2=20, Hidden Layer 3=20, Hidden Layer 4=60, Hidden Layer 5=60
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Training model with configuration 12: Hidden Layer 1=20, Hidden Layer 2=20, Hidden Layer 3=20, Hidden Layer 4=60, Hidden Layer 5=80
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 717us/step
# Training model with configuration 13: Hidden Layer 1=20, Hidden Layer 2=20, Hidden Layer 3=20, Hidden Layer 4=80, Hidden Layer 5=20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 798us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 840us/step
# Training model with configuration 14: Hidden Layer 1=20, Hidden Layer 2=20, Hidden Layer 3=20, Hidden Layer 4=80, Hidden Layer 5=40
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 968us/step
# Training model with configuration 15: Hidden Layer 1=20, Hidden Layer 2=20, Hidden Layer 3=20, Hidden Layer 4=80, Hidden Layer 5=60
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 792us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 816us/step
# Training model with configuration 16: Hidden Layer 1=20, Hidden Layer 2=20, Hidden Layer 3=20, Hidden Layer 4=80, Hidden Layer 5=80
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 924us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 814us/step
# Training model with configuration 17: Hidden Layer 1=20, Hidden Layer 2=20, Hidden Layer 3=40, Hidden Layer 4=20, Hidden Layer 5=20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 997us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 784us/step
# Training model with configuration 18: Hidden Layer 1=20, Hidden Layer 2=20, Hidden Layer 3=40, Hidden Layer 4=20, Hidden Layer 5=40
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 783us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 730us/step
# Training model with configuration 19: Hidden Layer 1=20, Hidden Layer 2=20, Hidden Layer 3=40, Hidden Layer 4=20, Hidden Layer 5=60
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 845us/step
# Training model with configuration 20: Hidden Layer 1=20, Hidden Layer 2=20, Hidden Layer 3=40, Hidden Layer 4=20, Hidden Layer 5=80
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 939us/step
# Training model with configuration 21: Hidden Layer 1=20, Hidden Layer 2=20, Hidden Layer 3=40, Hidden Layer 4=40, Hidden Layer 5=20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Training model with configuration 22: Hidden Layer 1=20, Hidden Layer 2=20, Hidden Layer 3=40, Hidden Layer 4=40, Hidden Layer 5=40
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Training model with configuration 23: Hidden Layer 1=20, Hidden Layer 2=20, Hidden Layer 3=40, Hidden Layer 4=40, Hidden Layer 5=60
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 961us/step
# Training model with configuration 24: Hidden Layer 1=20, Hidden Layer 2=20, Hidden Layer 3=40, Hidden Layer 4=40, Hidden Layer 5=80
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 974us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Training model with configuration 25: Hidden Layer 1=20, Hidden Layer 2=20, Hidden Layer 3=40, Hidden Layer 4=60, Hidden Layer 5=20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 917us/step
# Training model with configuration 26: Hidden Layer 1=20, Hidden Layer 2=20, Hidden Layer 3=40, Hidden Layer 4=60, Hidden Layer 5=40
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 925us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 975us/step
# Training model with configuration 27: Hidden Layer 1=20, Hidden Layer 2=20, Hidden Layer 3=40, Hidden Layer 4=60, Hidden Layer 5=60
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 990us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 914us/step
# Training model with configuration 28: Hidden Layer 1=20, Hidden Layer 2=20, Hidden Layer 3=40, Hidden Layer 4=60, Hidden Layer 5=80
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 873us/step
# Training model with configuration 29: Hidden Layer 1=20, Hidden Layer 2=20, Hidden Layer 3=40, Hidden Layer 4=80, Hidden Layer 5=20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 997us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 914us/step
# Training model with configuration 30: Hidden Layer 1=20, Hidden Layer 2=20, Hidden Layer 3=40, Hidden Layer 4=80, Hidden Layer 5=40
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 831us/step
# Training model with configuration 31: Hidden Layer 1=20, Hidden Layer 2=20, Hidden Layer 3=40, Hidden Layer 4=80, Hidden Layer 5=60
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 997us/step
# Training model with configuration 32: Hidden Layer 1=20, Hidden Layer 2=20, Hidden Layer 3=40, Hidden Layer 4=80, Hidden Layer 5=80
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 997us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 831us/step
# Training model with configuration 33: Hidden Layer 1=20, Hidden Layer 2=20, Hidden Layer 3=60, Hidden Layer 4=20, Hidden Layer 5=20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 914us/step
# Training model with configuration 34: Hidden Layer 1=20, Hidden Layer 2=20, Hidden Layer 3=60, Hidden Layer 4=20, Hidden Layer 5=40
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 997us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 997us/step
# Training model with configuration 35: Hidden Layer 1=20, Hidden Layer 2=20, Hidden Layer 3=60, Hidden Layer 4=20, Hidden Layer 5=60
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 957us/step
# Training model with configuration 36: Hidden Layer 1=20, Hidden Layer 2=20, Hidden Layer 3=60, Hidden Layer 4=20, Hidden Layer 5=80
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 831us/step
# Training model with configuration 37: Hidden Layer 1=20, Hidden Layer 2=20, Hidden Layer 3=60, Hidden Layer 4=40, Hidden Layer 5=20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 997us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 998us/step
# Training model with configuration 38: Hidden Layer 1=20, Hidden Layer 2=20, Hidden Layer 3=60, Hidden Layer 4=40, Hidden Layer 5=40
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 998us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 914us/step
# Training model with configuration 39: Hidden Layer 1=20, Hidden Layer 2=20, Hidden Layer 3=60, Hidden Layer 4=40, Hidden Layer 5=60
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 997us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 831us/step
# Training model with configuration 40: Hidden Layer 1=20, Hidden Layer 2=20, Hidden Layer 3=60, Hidden Layer 4=40, Hidden Layer 5=80
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 997us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 914us/step
# Training model with configuration 41: Hidden Layer 1=20, Hidden Layer 2=20, Hidden Layer 3=60, Hidden Layer 4=60, Hidden Layer 5=20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 916us/step
# Training model with configuration 42: Hidden Layer 1=20, Hidden Layer 2=20, Hidden Layer 3=60, Hidden Layer 4=60, Hidden Layer 5=40
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 997us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 918us/step
# Training model with configuration 43: Hidden Layer 1=20, Hidden Layer 2=20, Hidden Layer 3=60, Hidden Layer 4=60, Hidden Layer 5=60
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 997us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 831us/step
# Training model with configuration 44: Hidden Layer 1=20, Hidden Layer 2=20, Hidden Layer 3=60, Hidden Layer 4=60, Hidden Layer 5=80
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 991us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 914us/step
# Training model with configuration 45: Hidden Layer 1=20, Hidden Layer 2=20, Hidden Layer 3=60, Hidden Layer 4=80, Hidden Layer 5=20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 994us/step
# Training model with configuration 46: Hidden Layer 1=20, Hidden Layer 2=20, Hidden Layer 3=60, Hidden Layer 4=80, Hidden Layer 5=40
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 997us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 831us/step
# Training model with configuration 47: Hidden Layer 1=20, Hidden Layer 2=20, Hidden Layer 3=60, Hidden Layer 4=80, Hidden Layer 5=60
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 798us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 828us/step
# Training model with configuration 48: Hidden Layer 1=20, Hidden Layer 2=20, Hidden Layer 3=60, Hidden Layer 4=80, Hidden Layer 5=80
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 798us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 828us/step
# Training model with configuration 49: Hidden Layer 1=20, Hidden Layer 2=20, Hidden Layer 3=80, Hidden Layer 4=20, Hidden Layer 5=20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 836us/step
# Training model with configuration 50: Hidden Layer 1=20, Hidden Layer 2=20, Hidden Layer 3=80, Hidden Layer 4=20, Hidden Layer 5=40
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 828us/step
# Training model with configuration 51: Hidden Layer 1=20, Hidden Layer 2=20, Hidden Layer 3=80, Hidden Layer 4=20, Hidden Layer 5=60
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 997us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 914us/step
# Training model with configuration 52: Hidden Layer 1=20, Hidden Layer 2=20, Hidden Layer 3=80, Hidden Layer 4=20, Hidden Layer 5=80
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 829us/step
# Training model with configuration 53: Hidden Layer 1=20, Hidden Layer 2=20, Hidden Layer 3=80, Hidden Layer 4=40, Hidden Layer 5=20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 997us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 831us/step
# Training model with configuration 54: Hidden Layer 1=20, Hidden Layer 2=20, Hidden Layer 3=80, Hidden Layer 4=40, Hidden Layer 5=40
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 997us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 877us/step
# Training model with configuration 55: Hidden Layer 1=20, Hidden Layer 2=20, Hidden Layer 3=80, Hidden Layer 4=40, Hidden Layer 5=60
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 997us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 831us/step
# Training model with configuration 56: Hidden Layer 1=20, Hidden Layer 2=20, Hidden Layer 3=80, Hidden Layer 4=40, Hidden Layer 5=80
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 793us/step
# Training model with configuration 57: Hidden Layer 1=20, Hidden Layer 2=20, Hidden Layer 3=80, Hidden Layer 4=60, Hidden Layer 5=20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 798us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 831us/step
# Training model with configuration 58: Hidden Layer 1=20, Hidden Layer 2=20, Hidden Layer 3=80, Hidden Layer 4=60, Hidden Layer 5=40
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 997us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 831us/step
# Training model with configuration 59: Hidden Layer 1=20, Hidden Layer 2=20, Hidden Layer 3=80, Hidden Layer 4=60, Hidden Layer 5=60
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 997us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 831us/step
# Training model with configuration 60: Hidden Layer 1=20, Hidden Layer 2=20, Hidden Layer 3=80, Hidden Layer 4=60, Hidden Layer 5=80
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Training model with configuration 61: Hidden Layer 1=20, Hidden Layer 2=20, Hidden Layer 3=80, Hidden Layer 4=80, Hidden Layer 5=20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 748us/step
# Training model with configuration 62: Hidden Layer 1=20, Hidden Layer 2=20, Hidden Layer 3=80, Hidden Layer 4=80, Hidden Layer 5=40
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Training model with configuration 63: Hidden Layer 1=20, Hidden Layer 2=20, Hidden Layer 3=80, Hidden Layer 4=80, Hidden Layer 5=60
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 957us/step
# Training model with configuration 64: Hidden Layer 1=20, Hidden Layer 2=20, Hidden Layer 3=80, Hidden Layer 4=80, Hidden Layer 5=80
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 997us/step
# Training model with configuration 65: Hidden Layer 1=20, Hidden Layer 2=40, Hidden Layer 3=20, Hidden Layer 4=20, Hidden Layer 5=20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Training model with configuration 66: Hidden Layer 1=20, Hidden Layer 2=40, Hidden Layer 3=20, Hidden Layer 4=20, Hidden Layer 5=40
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 997us/step
# Training model with configuration 67: Hidden Layer 1=20, Hidden Layer 2=40, Hidden Layer 3=20, Hidden Layer 4=20, Hidden Layer 5=60
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Training model with configuration 68: Hidden Layer 1=20, Hidden Layer 2=40, Hidden Layer 3=20, Hidden Layer 4=20, Hidden Layer 5=80
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 911us/step
# Training model with configuration 69: Hidden Layer 1=20, Hidden Layer 2=40, Hidden Layer 3=20, Hidden Layer 4=40, Hidden Layer 5=20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Training model with configuration 70: Hidden Layer 1=20, Hidden Layer 2=40, Hidden Layer 3=20, Hidden Layer 4=40, Hidden Layer 5=40
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 997us/step
# Training model with configuration 71: Hidden Layer 1=20, Hidden Layer 2=40, Hidden Layer 3=20, Hidden Layer 4=40, Hidden Layer 5=60
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Training model with configuration 72: Hidden Layer 1=20, Hidden Layer 2=40, Hidden Layer 3=20, Hidden Layer 4=40, Hidden Layer 5=80
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Training model with configuration 73: Hidden Layer 1=20, Hidden Layer 2=40, Hidden Layer 3=20, Hidden Layer 4=60, Hidden Layer 5=20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Training model with configuration 74: Hidden Layer 1=20, Hidden Layer 2=40, Hidden Layer 3=20, Hidden Layer 4=60, Hidden Layer 5=40
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 997us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 831us/step
# Training model with configuration 75: Hidden Layer 1=20, Hidden Layer 2=40, Hidden Layer 3=20, Hidden Layer 4=60, Hidden Layer 5=60
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 997us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 997us/step
# Training model with configuration 76: Hidden Layer 1=20, Hidden Layer 2=40, Hidden Layer 3=20, Hidden Layer 4=60, Hidden Layer 5=80
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 997us/step
# Training model with configuration 77: Hidden Layer 1=20, Hidden Layer 2=40, Hidden Layer 3=20, Hidden Layer 4=80, Hidden Layer 5=20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 997us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 997us/step
# Training model with configuration 78: Hidden Layer 1=20, Hidden Layer 2=40, Hidden Layer 3=20, Hidden Layer 4=80, Hidden Layer 5=40
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 998us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 915us/step
# Training model with configuration 79: Hidden Layer 1=20, Hidden Layer 2=40, Hidden Layer 3=20, Hidden Layer 4=80, Hidden Layer 5=60
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 997us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 914us/step
# Training model with configuration 80: Hidden Layer 1=20, Hidden Layer 2=40, Hidden Layer 3=20, Hidden Layer 4=80, Hidden Layer 5=80
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 995us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 831us/step
# Training model with configuration 81: Hidden Layer 1=20, Hidden Layer 2=40, Hidden Layer 3=40, Hidden Layer 4=20, Hidden Layer 5=20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 997us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 912us/step
# Training model with configuration 82: Hidden Layer 1=20, Hidden Layer 2=40, Hidden Layer 3=40, Hidden Layer 4=20, Hidden Layer 5=40
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Training model with configuration 83: Hidden Layer 1=20, Hidden Layer 2=40, Hidden Layer 3=40, Hidden Layer 4=20, Hidden Layer 5=60
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 831us/step
# Training model with configuration 84: Hidden Layer 1=20, Hidden Layer 2=40, Hidden Layer 3=40, Hidden Layer 4=20, Hidden Layer 5=80
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 799us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 828us/step
# Training model with configuration 85: Hidden Layer 1=20, Hidden Layer 2=40, Hidden Layer 3=40, Hidden Layer 4=40, Hidden Layer 5=20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 798us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 877us/step
# Training model with configuration 86: Hidden Layer 1=20, Hidden Layer 2=40, Hidden Layer 3=40, Hidden Layer 4=40, Hidden Layer 5=40
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 831us/step
# Training model with configuration 87: Hidden Layer 1=20, Hidden Layer 2=40, Hidden Layer 3=40, Hidden Layer 4=40, Hidden Layer 5=60
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 914us/step
# Training model with configuration 88: Hidden Layer 1=20, Hidden Layer 2=40, Hidden Layer 3=40, Hidden Layer 4=40, Hidden Layer 5=80
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 997us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 914us/step
# Training model with configuration 89: Hidden Layer 1=20, Hidden Layer 2=40, Hidden Layer 3=40, Hidden Layer 4=60, Hidden Layer 5=20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 997us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 831us/step
# Training model with configuration 90: Hidden Layer 1=20, Hidden Layer 2=40, Hidden Layer 3=40, Hidden Layer 4=60, Hidden Layer 5=40
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 997us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 914us/step
# Training model with configuration 91: Hidden Layer 1=20, Hidden Layer 2=40, Hidden Layer 3=40, Hidden Layer 4=60, Hidden Layer 5=60
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 998us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 914us/step
# Training model with configuration 92: Hidden Layer 1=20, Hidden Layer 2=40, Hidden Layer 3=40, Hidden Layer 4=60, Hidden Layer 5=80
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 997us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 916us/step
# Training model with configuration 93: Hidden Layer 1=20, Hidden Layer 2=40, Hidden Layer 3=40, Hidden Layer 4=80, Hidden Layer 5=20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 997us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 914us/step
# Training model with configuration 94: Hidden Layer 1=20, Hidden Layer 2=40, Hidden Layer 3=40, Hidden Layer 4=80, Hidden Layer 5=40
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 914us/step
# Training model with configuration 95: Hidden Layer 1=20, Hidden Layer 2=40, Hidden Layer 3=40, Hidden Layer 4=80, Hidden Layer 5=60
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 914us/step
# Training model with configuration 96: Hidden Layer 1=20, Hidden Layer 2=40, Hidden Layer 3=40, Hidden Layer 4=80, Hidden Layer 5=80
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 997us/step
# Training model with configuration 97: Hidden Layer 1=20, Hidden Layer 2=40, Hidden Layer 3=60, Hidden Layer 4=20, Hidden Layer 5=20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 831us/step
# Training model with configuration 98: Hidden Layer 1=20, Hidden Layer 2=40, Hidden Layer 3=60, Hidden Layer 4=20, Hidden Layer 5=40
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 874us/step
# Training model with configuration 99: Hidden Layer 1=20, Hidden Layer 2=40, Hidden Layer 3=60, Hidden Layer 4=20, Hidden Layer 5=60
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 991us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 833us/step
# Training model with configuration 100: Hidden Layer 1=20, Hidden Layer 2=40, Hidden Layer 3=60, Hidden Layer 4=20, Hidden Layer 5=80
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 994us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 833us/step
# Training model with configuration 101: Hidden Layer 1=20, Hidden Layer 2=40, Hidden Layer 3=60, Hidden Layer 4=40, Hidden Layer 5=20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 996us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 831us/step
# Training model with configuration 102: Hidden Layer 1=20, Hidden Layer 2=40, Hidden Layer 3=60, Hidden Layer 4=40, Hidden Layer 5=40
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 991us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 748us/step
# Training model with configuration 103: Hidden Layer 1=20, Hidden Layer 2=40, Hidden Layer 3=60, Hidden Layer 4=40, Hidden Layer 5=60
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 997us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 914us/step
# Training model with configuration 104: Hidden Layer 1=20, Hidden Layer 2=40, Hidden Layer 3=60, Hidden Layer 4=40, Hidden Layer 5=80
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 798us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 748us/step
# Training model with configuration 105: Hidden Layer 1=20, Hidden Layer 2=40, Hidden Layer 3=60, Hidden Layer 4=60, Hidden Layer 5=20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 798us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 831us/step
# Training model with configuration 106: Hidden Layer 1=20, Hidden Layer 2=40, Hidden Layer 3=60, Hidden Layer 4=60, Hidden Layer 5=40
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 833us/step
# Training model with configuration 107: Hidden Layer 1=20, Hidden Layer 2=40, Hidden Layer 3=60, Hidden Layer 4=60, Hidden Layer 5=60
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 992us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 914us/step
# Training model with configuration 108: Hidden Layer 1=20, Hidden Layer 2=40, Hidden Layer 3=60, Hidden Layer 4=60, Hidden Layer 5=80
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 997us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 914us/step
# Training model with configuration 109: Hidden Layer 1=20, Hidden Layer 2=40, Hidden Layer 3=60, Hidden Layer 4=80, Hidden Layer 5=20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 798us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 834us/step
# Training model with configuration 110: Hidden Layer 1=20, Hidden Layer 2=40, Hidden Layer 3=60, Hidden Layer 4=80, Hidden Layer 5=40
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 829us/step
# Training model with configuration 111: Hidden Layer 1=20, Hidden Layer 2=40, Hidden Layer 3=60, Hidden Layer 4=80, Hidden Layer 5=60
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 798us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 831us/step
# Training model with configuration 112: Hidden Layer 1=20, Hidden Layer 2=40, Hidden Layer 3=60, Hidden Layer 4=80, Hidden Layer 5=80
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 997us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 831us/step
# Training model with configuration 113: Hidden Layer 1=20, Hidden Layer 2=40, Hidden Layer 3=80, Hidden Layer 4=20, Hidden Layer 5=20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 990us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 998us/step
# Training model with configuration 114: Hidden Layer 1=20, Hidden Layer 2=40, Hidden Layer 3=80, Hidden Layer 4=20, Hidden Layer 5=40
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 997us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 914us/step
# Training model with configuration 115: Hidden Layer 1=20, Hidden Layer 2=40, Hidden Layer 3=80, Hidden Layer 4=20, Hidden Layer 5=60
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 748us/step
# Training model with configuration 116: Hidden Layer 1=20, Hidden Layer 2=40, Hidden Layer 3=80, Hidden Layer 4=20, Hidden Layer 5=80
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 791us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 797us/step
# Training model with configuration 117: Hidden Layer 1=20, Hidden Layer 2=40, Hidden Layer 3=80, Hidden Layer 4=40, Hidden Layer 5=20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 997us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Training model with configuration 118: Hidden Layer 1=20, Hidden Layer 2=40, Hidden Layer 3=80, Hidden Layer 4=40, Hidden Layer 5=40
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 798us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 831us/step
# Training model with configuration 119: Hidden Layer 1=20, Hidden Layer 2=40, Hidden Layer 3=80, Hidden Layer 4=40, Hidden Layer 5=60
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 999us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 833us/step
# Training model with configuration 120: Hidden Layer 1=20, Hidden Layer 2=40, Hidden Layer 3=80, Hidden Layer 4=40, Hidden Layer 5=80
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 991us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 831us/step
# Training model with configuration 121: Hidden Layer 1=20, Hidden Layer 2=40, Hidden Layer 3=80, Hidden Layer 4=60, Hidden Layer 5=20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 998us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 914us/step
# Training model with configuration 122: Hidden Layer 1=20, Hidden Layer 2=40, Hidden Layer 3=80, Hidden Layer 4=60, Hidden Layer 5=40
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 746us/step
# Training model with configuration 123: Hidden Layer 1=20, Hidden Layer 2=40, Hidden Layer 3=80, Hidden Layer 4=60, Hidden Layer 5=60
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 791us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 748us/step
# Training model with configuration 124: Hidden Layer 1=20, Hidden Layer 2=40, Hidden Layer 3=80, Hidden Layer 4=60, Hidden Layer 5=80
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 997us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 752us/step
# Training model with configuration 125: Hidden Layer 1=20, Hidden Layer 2=40, Hidden Layer 3=80, Hidden Layer 4=80, Hidden Layer 5=20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 914us/step
# Training model with configuration 126: Hidden Layer 1=20, Hidden Layer 2=40, Hidden Layer 3=80, Hidden Layer 4=80, Hidden Layer 5=40
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 831us/step
# Training model with configuration 127: Hidden Layer 1=20, Hidden Layer 2=40, Hidden Layer 3=80, Hidden Layer 4=80, Hidden Layer 5=60
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 997us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 751us/step
# Training model with configuration 128: Hidden Layer 1=20, Hidden Layer 2=40, Hidden Layer 3=80, Hidden Layer 4=80, Hidden Layer 5=80
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 997us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 831us/step
# Training model with configuration 129: Hidden Layer 1=20, Hidden Layer 2=60, Hidden Layer 3=20, Hidden Layer 4=20, Hidden Layer 5=20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 831us/step
# Training model with configuration 130: Hidden Layer 1=20, Hidden Layer 2=60, Hidden Layer 3=20, Hidden Layer 4=20, Hidden Layer 5=40
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 914us/step
# Training model with configuration 131: Hidden Layer 1=20, Hidden Layer 2=60, Hidden Layer 3=20, Hidden Layer 4=20, Hidden Layer 5=60
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 997us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 831us/step
# Training model with configuration 132: Hidden Layer 1=20, Hidden Layer 2=60, Hidden Layer 3=20, Hidden Layer 4=20, Hidden Layer 5=80
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Training model with configuration 133: Hidden Layer 1=20, Hidden Layer 2=60, Hidden Layer 3=20, Hidden Layer 4=40, Hidden Layer 5=20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 998us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 831us/step
# Training model with configuration 134: Hidden Layer 1=20, Hidden Layer 2=60, Hidden Layer 3=20, Hidden Layer 4=40, Hidden Layer 5=40
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 990us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 997us/step
# Training model with configuration 135: Hidden Layer 1=20, Hidden Layer 2=60, Hidden Layer 3=20, Hidden Layer 4=40, Hidden Layer 5=60
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 914us/step
# Training model with configuration 136: Hidden Layer 1=20, Hidden Layer 2=60, Hidden Layer 3=20, Hidden Layer 4=40, Hidden Layer 5=80
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Training model with configuration 137: Hidden Layer 1=20, Hidden Layer 2=60, Hidden Layer 3=20, Hidden Layer 4=60, Hidden Layer 5=20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 998us/step
# Training model with configuration 138: Hidden Layer 1=20, Hidden Layer 2=60, Hidden Layer 3=20, Hidden Layer 4=60, Hidden Layer 5=40
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 992us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 914us/step
# Training model with configuration 139: Hidden Layer 1=20, Hidden Layer 2=60, Hidden Layer 3=20, Hidden Layer 4=60, Hidden Layer 5=60
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 997us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 874us/step
# Training model with configuration 140: Hidden Layer 1=20, Hidden Layer 2=60, Hidden Layer 3=20, Hidden Layer 4=60, Hidden Layer 5=80
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 914us/step
# Training model with configuration 141: Hidden Layer 1=20, Hidden Layer 2=60, Hidden Layer 3=20, Hidden Layer 4=80, Hidden Layer 5=20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 914us/step
# Training model with configuration 142: Hidden Layer 1=20, Hidden Layer 2=60, Hidden Layer 3=20, Hidden Layer 4=80, Hidden Layer 5=40
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 791us/step
# Training model with configuration 143: Hidden Layer 1=20, Hidden Layer 2=60, Hidden Layer 3=20, Hidden Layer 4=80, Hidden Layer 5=60
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 914us/step
# Training model with configuration 144: Hidden Layer 1=20, Hidden Layer 2=60, Hidden Layer 3=20, Hidden Layer 4=80, Hidden Layer 5=80
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 990us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 914us/step
# Training model with configuration 145: Hidden Layer 1=20, Hidden Layer 2=60, Hidden Layer 3=40, Hidden Layer 4=20, Hidden Layer 5=20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 997us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 997us/step
# Training model with configuration 146: Hidden Layer 1=20, Hidden Layer 2=60, Hidden Layer 3=40, Hidden Layer 4=20, Hidden Layer 5=40
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 957us/step
# Training model with configuration 147: Hidden Layer 1=20, Hidden Layer 2=60, Hidden Layer 3=40, Hidden Layer 4=20, Hidden Layer 5=60
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 830us/step
# Training model with configuration 148: Hidden Layer 1=20, Hidden Layer 2=60, Hidden Layer 3=40, Hidden Layer 4=20, Hidden Layer 5=80
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 798us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 748us/step
# Training model with configuration 149: Hidden Layer 1=20, Hidden Layer 2=60, Hidden Layer 3=40, Hidden Layer 4=40, Hidden Layer 5=20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 831us/step
# Training model with configuration 150: Hidden Layer 1=20, Hidden Layer 2=60, Hidden Layer 3=40, Hidden Layer 4=40, Hidden Layer 5=40
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 791us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 747us/step
# Training model with configuration 151: Hidden Layer 1=20, Hidden Layer 2=60, Hidden Layer 3=40, Hidden Layer 4=40, Hidden Layer 5=60
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 830us/step
# Training model with configuration 152: Hidden Layer 1=20, Hidden Layer 2=60, Hidden Layer 3=40, Hidden Layer 4=40, Hidden Layer 5=80
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 997us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 834us/step
# Training model with configuration 153: Hidden Layer 1=20, Hidden Layer 2=60, Hidden Layer 3=40, Hidden Layer 4=60, Hidden Layer 5=20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 798us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 874us/step
# Training model with configuration 154: Hidden Layer 1=20, Hidden Layer 2=60, Hidden Layer 3=40, Hidden Layer 4=60, Hidden Layer 5=40
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 798us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 917us/step
# Training model with configuration 155: Hidden Layer 1=20, Hidden Layer 2=60, Hidden Layer 3=40, Hidden Layer 4=60, Hidden Layer 5=60
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Training model with configuration 156: Hidden Layer 1=20, Hidden Layer 2=60, Hidden Layer 3=40, Hidden Layer 4=60, Hidden Layer 5=80
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 991us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 874us/step
# Training model with configuration 157: Hidden Layer 1=20, Hidden Layer 2=60, Hidden Layer 3=40, Hidden Layer 4=80, Hidden Layer 5=20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 997us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 791us/step
# Training model with configuration 158: Hidden Layer 1=20, Hidden Layer 2=60, Hidden Layer 3=40, Hidden Layer 4=80, Hidden Layer 5=40
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 798us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 831us/step
# Training model with configuration 159: Hidden Layer 1=20, Hidden Layer 2=60, Hidden Layer 3=40, Hidden Layer 4=80, Hidden Layer 5=60
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 746us/step
# Training model with configuration 160: Hidden Layer 1=20, Hidden Layer 2=60, Hidden Layer 3=40, Hidden Layer 4=80, Hidden Layer 5=80
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 998us/step
# Training model with configuration 161: Hidden Layer 1=20, Hidden Layer 2=60, Hidden Layer 3=60, Hidden Layer 4=20, Hidden Layer 5=20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 997us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 745us/step
# Training model with configuration 162: Hidden Layer 1=20, Hidden Layer 2=60, Hidden Layer 3=60, Hidden Layer 4=20, Hidden Layer 5=40
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 791us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 831us/step
# Training model with configuration 163: Hidden Layer 1=20, Hidden Layer 2=60, Hidden Layer 3=60, Hidden Layer 4=20, Hidden Layer 5=60
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 750us/step
# Training model with configuration 164: Hidden Layer 1=20, Hidden Layer 2=60, Hidden Layer 3=60, Hidden Layer 4=20, Hidden Layer 5=80
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 989us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 831us/step
# Training model with configuration 165: Hidden Layer 1=20, Hidden Layer 2=60, Hidden Layer 3=60, Hidden Layer 4=40, Hidden Layer 5=20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 997us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 831us/step
# Training model with configuration 166: Hidden Layer 1=20, Hidden Layer 2=60, Hidden Layer 3=60, Hidden Layer 4=40, Hidden Layer 5=40
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 793us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 997us/step
# Training model with configuration 167: Hidden Layer 1=20, Hidden Layer 2=60, Hidden Layer 3=60, Hidden Layer 4=40, Hidden Layer 5=60
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 804us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 914us/step
# Training model with configuration 168: Hidden Layer 1=20, Hidden Layer 2=60, Hidden Layer 3=60, Hidden Layer 4=40, Hidden Layer 5=80
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 998us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 745us/step
# Training model with configuration 169: Hidden Layer 1=20, Hidden Layer 2=60, Hidden Layer 3=60, Hidden Layer 4=60, Hidden Layer 5=20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 997us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 831us/step
# Training model with configuration 170: Hidden Layer 1=20, Hidden Layer 2=60, Hidden Layer 3=60, Hidden Layer 4=60, Hidden Layer 5=40
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 997us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 917us/step
# Training model with configuration 171: Hidden Layer 1=20, Hidden Layer 2=60, Hidden Layer 3=60, Hidden Layer 4=60, Hidden Layer 5=60
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 997us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 831us/step
# Training model with configuration 172: Hidden Layer 1=20, Hidden Layer 2=60, Hidden Layer 3=60, Hidden Layer 4=60, Hidden Layer 5=80
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 997us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 833us/step
# Training model with configuration 173: Hidden Layer 1=20, Hidden Layer 2=60, Hidden Layer 3=60, Hidden Layer 4=80, Hidden Layer 5=20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 997us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 791us/step
# Training model with configuration 174: Hidden Layer 1=20, Hidden Layer 2=60, Hidden Layer 3=60, Hidden Layer 4=80, Hidden Layer 5=40
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 823us/step
# Training model with configuration 175: Hidden Layer 1=20, Hidden Layer 2=60, Hidden Layer 3=60, Hidden Layer 4=80, Hidden Layer 5=60
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 997us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Training model with configuration 176: Hidden Layer 1=20, Hidden Layer 2=60, Hidden Layer 3=60, Hidden Layer 4=80, Hidden Layer 5=80
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 913us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 745us/step
# Training model with configuration 177: Hidden Layer 1=20, Hidden Layer 2=60, Hidden Layer 3=80, Hidden Layer 4=20, Hidden Layer 5=20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 798us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Training model with configuration 178: Hidden Layer 1=20, Hidden Layer 2=60, Hidden Layer 3=80, Hidden Layer 4=20, Hidden Layer 5=40
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Training model with configuration 179: Hidden Layer 1=20, Hidden Layer 2=60, Hidden Layer 3=80, Hidden Layer 4=20, Hidden Layer 5=60
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 994us/step
# Training model with configuration 180: Hidden Layer 1=20, Hidden Layer 2=60, Hidden Layer 3=80, Hidden Layer 4=20, Hidden Layer 5=80
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 914us/step
# Training model with configuration 181: Hidden Layer 1=20, Hidden Layer 2=60, Hidden Layer 3=80, Hidden Layer 4=40, Hidden Layer 5=20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 997us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 914us/step
# Training model with configuration 182: Hidden Layer 1=20, Hidden Layer 2=60, Hidden Layer 3=80, Hidden Layer 4=40, Hidden Layer 5=40
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 991us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 914us/step
# Training model with configuration 183: Hidden Layer 1=20, Hidden Layer 2=60, Hidden Layer 3=80, Hidden Layer 4=40, Hidden Layer 5=60
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 997us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 831us/step
# Training model with configuration 184: Hidden Layer 1=20, Hidden Layer 2=60, Hidden Layer 3=80, Hidden Layer 4=40, Hidden Layer 5=80
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 997us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 911us/step
# Training model with configuration 185: Hidden Layer 1=20, Hidden Layer 2=60, Hidden Layer 3=80, Hidden Layer 4=60, Hidden Layer 5=20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 914us/step
# Training model with configuration 186: Hidden Layer 1=20, Hidden Layer 2=60, Hidden Layer 3=80, Hidden Layer 4=60, Hidden Layer 5=40
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 914us/step
# Training model with configuration 187: Hidden Layer 1=20, Hidden Layer 2=60, Hidden Layer 3=80, Hidden Layer 4=60, Hidden Layer 5=60
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 914us/step
# Training model with configuration 188: Hidden Layer 1=20, Hidden Layer 2=60, Hidden Layer 3=80, Hidden Layer 4=60, Hidden Layer 5=80
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 831us/step
# Training model with configuration 189: Hidden Layer 1=20, Hidden Layer 2=60, Hidden Layer 3=80, Hidden Layer 4=80, Hidden Layer 5=20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 874us/step
# Training model with configuration 190: Hidden Layer 1=20, Hidden Layer 2=60, Hidden Layer 3=80, Hidden Layer 4=80, Hidden Layer 5=40
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 997us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 913us/step
# Training model with configuration 191: Hidden Layer 1=20, Hidden Layer 2=60, Hidden Layer 3=80, Hidden Layer 4=80, Hidden Layer 5=60
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 798us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 831us/step
# ...
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Training model with configuration 962: Hidden Layer 1=80, Hidden Layer 2=80, Hidden Layer 3=20, Hidden Layer 4=20, Hidden Layer 5=40
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Training model with configuration 963: Hidden Layer 1=80, Hidden Layer 2=80, Hidden Layer 3=20, Hidden Layer 4=20, Hidden Layer 5=60
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Training model with configuration 964: Hidden Layer 1=80, Hidden Layer 2=80, Hidden Layer 3=20, Hidden Layer 4=20, Hidden Layer 5=80
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Training model with configuration 965: Hidden Layer 1=80, Hidden Layer 2=80, Hidden Layer 3=20, Hidden Layer 4=40, Hidden Layer 5=20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Training model with configuration 966: Hidden Layer 1=80, Hidden Layer 2=80, Hidden Layer 3=20, Hidden Layer 4=40, Hidden Layer 5=40
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Training model with configuration 967: Hidden Layer 1=80, Hidden Layer 2=80, Hidden Layer 3=20, Hidden Layer 4=40, Hidden Layer 5=60
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Training model with configuration 968: Hidden Layer 1=80, Hidden Layer 2=80, Hidden Layer 3=20, Hidden Layer 4=40, Hidden Layer 5=80
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Training model with configuration 969: Hidden Layer 1=80, Hidden Layer 2=80, Hidden Layer 3=20, Hidden Layer 4=60, Hidden Layer 5=20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Training model with configuration 970: Hidden Layer 1=80, Hidden Layer 2=80, Hidden Layer 3=20, Hidden Layer 4=60, Hidden Layer 5=40
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Training model with configuration 971: Hidden Layer 1=80, Hidden Layer 2=80, Hidden Layer 3=20, Hidden Layer 4=60, Hidden Layer 5=60
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Training model with configuration 972: Hidden Layer 1=80, Hidden Layer 2=80, Hidden Layer 3=20, Hidden Layer 4=60, Hidden Layer 5=80
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Training model with configuration 973: Hidden Layer 1=80, Hidden Layer 2=80, Hidden Layer 3=20, Hidden Layer 4=80, Hidden Layer 5=20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Training model with configuration 974: Hidden Layer 1=80, Hidden Layer 2=80, Hidden Layer 3=20, Hidden Layer 4=80, Hidden Layer 5=40
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Training model with configuration 975: Hidden Layer 1=80, Hidden Layer 2=80, Hidden Layer 3=20, Hidden Layer 4=80, Hidden Layer 5=60
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Training model with configuration 976: Hidden Layer 1=80, Hidden Layer 2=80, Hidden Layer 3=20, Hidden Layer 4=80, Hidden Layer 5=80
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Training model with configuration 977: Hidden Layer 1=80, Hidden Layer 2=80, Hidden Layer 3=40, Hidden Layer 4=20, Hidden Layer 5=20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Training model with configuration 978: Hidden Layer 1=80, Hidden Layer 2=80, Hidden Layer 3=40, Hidden Layer 4=20, Hidden Layer 5=40
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Training model with configuration 979: Hidden Layer 1=80, Hidden Layer 2=80, Hidden Layer 3=40, Hidden Layer 4=20, Hidden Layer 5=60
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Training model with configuration 980: Hidden Layer 1=80, Hidden Layer 2=80, Hidden Layer 3=40, Hidden Layer 4=20, Hidden Layer 5=80
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Training model with configuration 981: Hidden Layer 1=80, Hidden Layer 2=80, Hidden Layer 3=40, Hidden Layer 4=40, Hidden Layer 5=20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Training model with configuration 982: Hidden Layer 1=80, Hidden Layer 2=80, Hidden Layer 3=40, Hidden Layer 4=40, Hidden Layer 5=40
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Training model with configuration 983: Hidden Layer 1=80, Hidden Layer 2=80, Hidden Layer 3=40, Hidden Layer 4=40, Hidden Layer 5=60
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Training model with configuration 984: Hidden Layer 1=80, Hidden Layer 2=80, Hidden Layer 3=40, Hidden Layer 4=40, Hidden Layer 5=80
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Training model with configuration 985: Hidden Layer 1=80, Hidden Layer 2=80, Hidden Layer 3=40, Hidden Layer 4=60, Hidden Layer 5=20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Training model with configuration 986: Hidden Layer 1=80, Hidden Layer 2=80, Hidden Layer 3=40, Hidden Layer 4=60, Hidden Layer 5=40
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Training model with configuration 987: Hidden Layer 1=80, Hidden Layer 2=80, Hidden Layer 3=40, Hidden Layer 4=60, Hidden Layer 5=60
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Training model with configuration 988: Hidden Layer 1=80, Hidden Layer 2=80, Hidden Layer 3=40, Hidden Layer 4=60, Hidden Layer 5=80
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Training model with configuration 989: Hidden Layer 1=80, Hidden Layer 2=80, Hidden Layer 3=40, Hidden Layer 4=80, Hidden Layer 5=20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Training model with configuration 990: Hidden Layer 1=80, Hidden Layer 2=80, Hidden Layer 3=40, Hidden Layer 4=80, Hidden Layer 5=40
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Training model with configuration 991: Hidden Layer 1=80, Hidden Layer 2=80, Hidden Layer 3=40, Hidden Layer 4=80, Hidden Layer 5=60
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Training model with configuration 992: Hidden Layer 1=80, Hidden Layer 2=80, Hidden Layer 3=40, Hidden Layer 4=80, Hidden Layer 5=80
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Training model with configuration 993: Hidden Layer 1=80, Hidden Layer 2=80, Hidden Layer 3=60, Hidden Layer 4=20, Hidden Layer 5=20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Training model with configuration 994: Hidden Layer 1=80, Hidden Layer 2=80, Hidden Layer 3=60, Hidden Layer 4=20, Hidden Layer 5=40
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Training model with configuration 995: Hidden Layer 1=80, Hidden Layer 2=80, Hidden Layer 3=60, Hidden Layer 4=20, Hidden Layer 5=60
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Training model with configuration 996: Hidden Layer 1=80, Hidden Layer 2=80, Hidden Layer 3=60, Hidden Layer 4=20, Hidden Layer 5=80
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Training model with configuration 997: Hidden Layer 1=80, Hidden Layer 2=80, Hidden Layer 3=60, Hidden Layer 4=40, Hidden Layer 5=20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Training model with configuration 998: Hidden Layer 1=80, Hidden Layer 2=80, Hidden Layer 3=60, Hidden Layer 4=40, Hidden Layer 5=40
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Training model with configuration 999: Hidden Layer 1=80, Hidden Layer 2=80, Hidden Layer 3=60, Hidden Layer 4=40, Hidden Layer 5=60
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Training model with configuration 1000: Hidden Layer 1=80, Hidden Layer 2=80, Hidden Layer 3=60, Hidden Layer 4=40, Hidden Layer 5=80
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Training model with configuration 1001: Hidden Layer 1=80, Hidden Layer 2=80, Hidden Layer 3=60, Hidden Layer 4=60, Hidden Layer 5=20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Training model with configuration 1002: Hidden Layer 1=80, Hidden Layer 2=80, Hidden Layer 3=60, Hidden Layer 4=60, Hidden Layer 5=40
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Training model with configuration 1003: Hidden Layer 1=80, Hidden Layer 2=80, Hidden Layer 3=60, Hidden Layer 4=60, Hidden Layer 5=60
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Training model with configuration 1004: Hidden Layer 1=80, Hidden Layer 2=80, Hidden Layer 3=60, Hidden Layer 4=60, Hidden Layer 5=80
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Training model with configuration 1005: Hidden Layer 1=80, Hidden Layer 2=80, Hidden Layer 3=60, Hidden Layer 4=80, Hidden Layer 5=20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Training model with configuration 1006: Hidden Layer 1=80, Hidden Layer 2=80, Hidden Layer 3=60, Hidden Layer 4=80, Hidden Layer 5=40
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Training model with configuration 1007: Hidden Layer 1=80, Hidden Layer 2=80, Hidden Layer 3=60, Hidden Layer 4=80, Hidden Layer 5=60
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Training model with configuration 1008: Hidden Layer 1=80, Hidden Layer 2=80, Hidden Layer 3=60, Hidden Layer 4=80, Hidden Layer 5=80
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Training model with configuration 1009: Hidden Layer 1=80, Hidden Layer 2=80, Hidden Layer 3=80, Hidden Layer 4=20, Hidden Layer 5=20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Training model with configuration 1010: Hidden Layer 1=80, Hidden Layer 2=80, Hidden Layer 3=80, Hidden Layer 4=20, Hidden Layer 5=40
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Training model with configuration 1011: Hidden Layer 1=80, Hidden Layer 2=80, Hidden Layer 3=80, Hidden Layer 4=20, Hidden Layer 5=60
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Training model with configuration 1012: Hidden Layer 1=80, Hidden Layer 2=80, Hidden Layer 3=80, Hidden Layer 4=20, Hidden Layer 5=80
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Training model with configuration 1013: Hidden Layer 1=80, Hidden Layer 2=80, Hidden Layer 3=80, Hidden Layer 4=40, Hidden Layer 5=20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Training model with configuration 1014: Hidden Layer 1=80, Hidden Layer 2=80, Hidden Layer 3=80, Hidden Layer 4=40, Hidden Layer 5=40
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Training model with configuration 1015: Hidden Layer 1=80, Hidden Layer 2=80, Hidden Layer 3=80, Hidden Layer 4=40, Hidden Layer 5=60
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Training model with configuration 1016: Hidden Layer 1=80, Hidden Layer 2=80, Hidden Layer 3=80, Hidden Layer 4=40, Hidden Layer 5=80
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Training model with configuration 1017: Hidden Layer 1=80, Hidden Layer 2=80, Hidden Layer 3=80, Hidden Layer 4=60, Hidden Layer 5=20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Training model with configuration 1018: Hidden Layer 1=80, Hidden Layer 2=80, Hidden Layer 3=80, Hidden Layer 4=60, Hidden Layer 5=40
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Training model with configuration 1019: Hidden Layer 1=80, Hidden Layer 2=80, Hidden Layer 3=80, Hidden Layer 4=60, Hidden Layer 5=60
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Training model with configuration 1020: Hidden Layer 1=80, Hidden Layer 2=80, Hidden Layer 3=80, Hidden Layer 4=60, Hidden Layer 5=80
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Training model with configuration 1021: Hidden Layer 1=80, Hidden Layer 2=80, Hidden Layer 3=80, Hidden Layer 4=80, Hidden Layer 5=20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Training model with configuration 1022: Hidden Layer 1=80, Hidden Layer 2=80, Hidden Layer 3=80, Hidden Layer 4=80, Hidden Layer 5=40
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Training model with configuration 1023: Hidden Layer 1=80, Hidden Layer 2=80, Hidden Layer 3=80, Hidden Layer 4=80, Hidden Layer 5=60
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Training model with configuration 1024: Hidden Layer 1=80, Hidden Layer 2=80, Hidden Layer 3=80, Hidden Layer 4=80, Hidden Layer 5=80
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
#
# ------------Congrats! You have successfully save the results to 5HL_Neurons_Network_Results_TTS------------

# %% [markdown]
# ### loss vs the number of epochs & MAE vs the number of epochs

# %%
def plot_loss(loss,val_loss):
  plt.figure()
  plt.style.use('bmh')
  plt.grid(False)
  plt.plot(loss, linewidth=2)
  plt.plot(val_loss, linewidth=2)
  plt.ylabel('Loss')
  plt.xlabel('Epoch')
  plt.legend(['Train', 'Val'], loc='upper right')
  plt.show()

def plot_mae(mae,val_mae):
  plt.figure()
  plt.style.use('ggplot')
  plt.grid(False)
  plt.plot(mae, linewidth=2)
  plt.plot(val_mae, linewidth=2)
  plt.ylabel('MAE')
  plt.xlabel('Epoch')
  plt.legend(['Train', 'Val'], loc='upper right')
  plt.show()

train_loss = (np.array(history.history["loss"]))/100
val_loss = np.array((history.history["val_loss"]))/100

plot_loss(train_loss, val_loss)
plot_mae(history.history["mae"], history.history["val_mae"])

# %% [markdown]
# ### Correlation between the actual output and the predicted output with the training dataset

# %%
custom_params = {"axes.spines.right": False, "axes.spines.top": False}
sns.set_theme(style="ticks", rc=custom_params)
a = plt.axes(aspect='equal')
plt.scatter(y_train, train_pred, s = 20, alpha=0.7, c = 'brown')
plt.xlabel('Actual Critical Buckling Loads (kN)')
plt.ylabel('Predicted Critical Buckling Loads (kN)')
plt.annotate("R-squared = {:.3f}".format(r2_score(y_train, train_pred)), (5, 19))
plt.xlim([4, 20])
plt.ylim([4, 20])
plt.plot([4, 20], [4, 20])
plt.plot()
# Out:
# []

# %% [markdown]
# ### Correlation between the actual output and the predicted output with the testing dataset

# %%
custom_params = {"axes.spines.right": False, "axes.spines.top": False}
sns.set_theme(style="ticks", rc=custom_params)
a = plt.axes(aspect='equal')
plt.scatter(y_test, test_pred, s = 20, alpha=0.7, c = 'brown')
plt.xlabel('Actual Critical Buckling Loads (kN)')
plt.ylabel('Predicted Critical Buckling Loads (kN)')
plt.annotate("R-squared = {:.3f}".format(r2_score(y_train, train_pred)), (5, 19))
plt.xlim([4, 20])
plt.ylim([4, 20])
plt.plot([4, 20], [4, 20])
plt.plot()
# Out:
# []

# %% [markdown]
# ## Variable importance SHAP plot

# %%
### VARIABLE IMPORTANCE
# See more here: https://shap-lrjball.readthedocs.io/en/latest/example_notebooks/plots/bar.html
features = ["Number of holes, nh", "Web-post width, WP (mm)",  "Web opening diameter, Do (mm)",  "Ply 1 (ø)", "Ply 2 (ø)", "Ply 3 (ø)", "Ply 4 (ø)", "Ply 5 (ø)", "Ply 6 (ø)", "Ply 7 (ø)", "Ply 8 (ø)"]

# Create a SHAP explainer using KernelExplainer
explainer = shap.KernelExplainer(model, shap.sample(X_train, 5))

# Calculate SHAP values for the test dataset
shap_values = explainer.shap_values(X_test)

# Reshape shap_values to remove the last dimension
shap_values_reshaped = shap_values.reshape(X_test.shape)  # Assuming X_test.shape is (389, 11)

# Visualize feature importances using bar plot
shap.summary_plot(shap_values_reshaped, X_test, feature_names=features, plot_type="bar")
plt.show()
