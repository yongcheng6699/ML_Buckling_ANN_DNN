# %% [markdown]
# ##  A 4-Hidden Layer Architecture
# What is happening here?
#     [1] A traditional ANN model.
#     [2] Import and preprocessing data.
#     [3] Trigonometric transformations, which converting the original angle plies into sine and cosine values range between -1 and 1 to helps normalize data.
#     [4] Create a neural network model with specific hidden layer and the model uses the Sequential API from Keras, starting with an input layer, followed by a dense (fully connected) hidden layer with ReLU activation, and then an output layer with linear activation (for regression tasks).
#     [5] Model Training and Evaluation: run over a range of different number of neurons (from 20 to 80 with step of 10) to tune the model's hyperparameters.
#     For each number of neurons: A KerasRegressor wrapper is instantiated with the defined neural network model and training settings (epochs, batch size).
#     5-Fold Cross-Validation for robust evaluates the model's performance metrics (MSE, MAE, R-squared) on each fold of the data and to avoid overfitting.
#     [6] Model Evaluation (mean and standard deviation of performance metrics).
#     [7] Plot Mean of(R2, MAE, RMSE) vs number of neurons.

# %%
import pandas as pd 
import numpy as np                                             
from keras.models import Sequential
from keras.layers import Dense, Input
from keras.optimizers import Adam
from matplotlib import pyplot as plt
from sklearn.base import TransformerMixin
from scikeras.wrappers import KerasRegressor
from sklearn.model_selection import KFold, cross_validate
import matplotlib.patches as mpatches

## Import data
bucklingdata = pd.read_csv("CBL_SimulationResults.csv", encoding='cp1252')

## Convert the hole_column from integer into a floating data type
bucklingdata['Number of holes, nh'] = bucklingdata['Number of holes, nh'].astype('float64')
bucklingdata['Web opening diameter, Do (mm)'] = bucklingdata['Web opening diameter, Do (mm)'].astype('float64')

## Trigonometric transformation of the ply angles: We develop a trigonometric transformation function to convert the angles (this is important)
# Create a transformation class here for the angle plies:
class TrigonometricTransformer(TransformerMixin):
    def __init__(self, start_column=1, end_column=-1):
        self.start_column = start_column
        self.end_column = end_column
        self.transform_functions = [np.sin, np.cos]

    def fit(self, X, y=None):
        return self

    def transform(self, X):
        X_transformed = X.copy()
        columns_to_transform = X.columns[self.start_column:self.end_column]

        for col in columns_to_transform:
            for func in self.transform_functions:
                X_transformed[col + '_' + func.__name__] = func(X[col])

        # Remove the original columns
        X_transformed.drop(columns=columns_to_transform, inplace=True)

        return X_transformed

# Specify the input and output datasets
input_data = bucklingdata.drop(['Critical Buckling Load (N)','Critical Buckling Load (kN)'], axis=1)
output_data = bucklingdata['Critical Buckling Load (kN)']

# Apply the transformation on the ply columns
transformer = TrigonometricTransformer(start_column=3, end_column=11)
# Transform the input DataFrame
transformed_bucklingdata = transformer.fit_transform(input_data)

# The input dimension for the Neural Network is then obtained as. Then, the input_size will use in following: model.add(Input(shape=(19,)))
input_size = transformed_bucklingdata.shape[1]
#print(input_size)

## Define a specific neural network model with four hidden layer
def create_model4H(neurons_list):
    model = Sequential()
    model.add(Input(shape=(19,)))
    hp_activation = 'selu'
    model.add(Dense(neurons_list[0], activation=hp_activation))
    model.add(Dense(neurons_list[1], activation=hp_activation))
    model.add(Dense(neurons_list[2], activation=hp_activation))
    model.add(Dense(neurons_list[3], activation=hp_activation))
    model.add(Dense(1, activation='linear'))
    hp_learning_rate = 0.01
    model.compile(loss='mse',
                  optimizer=Adam(learning_rate=hp_learning_rate),
                  metrics=['mae'])
    return model

# Pass the input and output dataframes to X , y (this is just convention in Python ML)
X = transformed_bucklingdata.copy()
y = output_data.copy()

# Specify the range for neurons in the first and second hidden layers
min_neurons = 20
max_neurons = 80
step = 10

neuron_configs = []


# Generate configurations with increasing neurons in all three layers
for neurons1 in range(min_neurons, max_neurons + 1, step):
    for neurons2 in range(min_neurons, max_neurons + 1, step):
        for neurons3 in range(min_neurons, max_neurons + 1, step):
            for neurons4 in range(min_neurons, max_neurons + 1, step):
                neuron_configs.append((neurons1, neurons2, neurons3, neurons4))

# Define lists to store results
results = []


for i, (p1, p2, p3, p4) in enumerate(neuron_configs):
    print(f"Training model with configuration {i+1}: Hidden Layer 1={p1}, Hidden Layer 2={p2}, Hidden Layer 3={p3}, Hidden Layer 4={p4}")
    
    keras_regressor = KerasRegressor(model=lambda: create_model4H([neurons1, neurons2, neurons3, neurons4]), epochs=150, batch_size=32, verbose=0)
    
    # Use cross_val_score to evaluate the model
    # Cross validation
    kf = KFold(n_splits=5, shuffle=True, random_state=42)
    cv_results = cross_validate(keras_regressor, X, y, cv=kf,
                             scoring=('neg_mean_squared_error', 'neg_mean_absolute_error', 'r2'))
    mse_scores = -cv_results['test_neg_mean_squared_error']
    mae_scores = -cv_results['test_neg_mean_absolute_error']
    r2_scores = cv_results['test_r2']                           # R-squared scores are already positive
         
    # Store the evaluation metrics in a DataFrame
    result_df = pd.DataFrame({
        'Configuration': i + 1,
        'Neurons_1HL': p1,
        'Neurons_2HL': p2,
        'Neurons_3HL': p3,
        'Neurons_4HL': p4,
        'Mean RMSE': np.sqrt(mse_scores).mean(),
        'Std RMSE': np.sqrt(mse_scores).std(),
        'Mean MAE': mae_scores.mean(),
        'Std MAE': mae_scores.std(),
        'Mean R-squared': r2_scores.mean(),
        'Std R-squared': r2_scores.std()
    }, index=[0])
    
    results.append(result_df)

# Concatenate all results into a single DataFrame
results_df = pd.concat(results, ignore_index=True)

# Save results to an Excel file
results_df.to_excel('4HL_Neurons_Network_Results_KFold_CV.xlsx', index=False)
print()
print("------------Congrats! You have successfully save the results to 4HL_Neurons_Network_Results_KFold_CV------------")
# Out:
# Training model with configuration 1: Hidden Layer 1=20, Hidden Layer 2=20, Hidden Layer 3=20, Hidden Layer 4=20
# Training model with configuration 2: Hidden Layer 1=20, Hidden Layer 2=20, Hidden Layer 3=20, Hidden Layer 4=30
# Training model with configuration 3: Hidden Layer 1=20, Hidden Layer 2=20, Hidden Layer 3=20, Hidden Layer 4=40
# Training model with configuration 4: Hidden Layer 1=20, Hidden Layer 2=20, Hidden Layer 3=20, Hidden Layer 4=50
# Training model with configuration 5: Hidden Layer 1=20, Hidden Layer 2=20, Hidden Layer 3=20, Hidden Layer 4=60
# Training model with configuration 6: Hidden Layer 1=20, Hidden Layer 2=20, Hidden Layer 3=20, Hidden Layer 4=70
# Training model with configuration 7: Hidden Layer 1=20, Hidden Layer 2=20, Hidden Layer 3=20, Hidden Layer 4=80
# Training model with configuration 8: Hidden Layer 1=20, Hidden Layer 2=20, Hidden Layer 3=30, Hidden Layer 4=20
# Training model with configuration 9: Hidden Layer 1=20, Hidden Layer 2=20, Hidden Layer 3=30, Hidden Layer 4=30
# Training model with configuration 10: Hidden Layer 1=20, Hidden Layer 2=20, Hidden Layer 3=30, Hidden Layer 4=40
# Training model with configuration 11: Hidden Layer 1=20, Hidden Layer 2=20, Hidden Layer 3=30, Hidden Layer 4=50
# Training model with configuration 12: Hidden Layer 1=20, Hidden Layer 2=20, Hidden Layer 3=30, Hidden Layer 4=60
# Training model with configuration 13: Hidden Layer 1=20, Hidden Layer 2=20, Hidden Layer 3=30, Hidden Layer 4=70
# Training model with configuration 14: Hidden Layer 1=20, Hidden Layer 2=20, Hidden Layer 3=30, Hidden Layer 4=80
# Training model with configuration 15: Hidden Layer 1=20, Hidden Layer 2=20, Hidden Layer 3=40, Hidden Layer 4=20
# Training model with configuration 16: Hidden Layer 1=20, Hidden Layer 2=20, Hidden Layer 3=40, Hidden Layer 4=30
# Training model with configuration 17: Hidden Layer 1=20, Hidden Layer 2=20, Hidden Layer 3=40, Hidden Layer 4=40
# Training model with configuration 18: Hidden Layer 1=20, Hidden Layer 2=20, Hidden Layer 3=40, Hidden Layer 4=50
# Training model with configuration 19: Hidden Layer 1=20, Hidden Layer 2=20, Hidden Layer 3=40, Hidden Layer 4=60
# Training model with configuration 20: Hidden Layer 1=20, Hidden Layer 2=20, Hidden Layer 3=40, Hidden Layer 4=70
# Training model with configuration 21: Hidden Layer 1=20, Hidden Layer 2=20, Hidden Layer 3=40, Hidden Layer 4=80
# Training model with configuration 22: Hidden Layer 1=20, Hidden Layer 2=20, Hidden Layer 3=50, Hidden Layer 4=20
# Training model with configuration 23: Hidden Layer 1=20, Hidden Layer 2=20, Hidden Layer 3=50, Hidden Layer 4=30
# Training model with configuration 24: Hidden Layer 1=20, Hidden Layer 2=20, Hidden Layer 3=50, Hidden Layer 4=40
# Training model with configuration 25: Hidden Layer 1=20, Hidden Layer 2=20, Hidden Layer 3=50, Hidden Layer 4=50
# Training model with configuration 26: Hidden Layer 1=20, Hidden Layer 2=20, Hidden Layer 3=50, Hidden Layer 4=60
# Training model with configuration 27: Hidden Layer 1=20, Hidden Layer 2=20, Hidden Layer 3=50, Hidden Layer 4=70
# Training model with configuration 28: Hidden Layer 1=20, Hidden Layer 2=20, Hidden Layer 3=50, Hidden Layer 4=80
# Training model with configuration 29: Hidden Layer 1=20, Hidden Layer 2=20, Hidden Layer 3=60, Hidden Layer 4=20
# Training model with configuration 30: Hidden Layer 1=20, Hidden Layer 2=20, Hidden Layer 3=60, Hidden Layer 4=30
# Training model with configuration 31: Hidden Layer 1=20, Hidden Layer 2=20, Hidden Layer 3=60, Hidden Layer 4=40
# Training model with configuration 32: Hidden Layer 1=20, Hidden Layer 2=20, Hidden Layer 3=60, Hidden Layer 4=50
# Training model with configuration 33: Hidden Layer 1=20, Hidden Layer 2=20, Hidden Layer 3=60, Hidden Layer 4=60
# Training model with configuration 34: Hidden Layer 1=20, Hidden Layer 2=20, Hidden Layer 3=60, Hidden Layer 4=70
# Training model with configuration 35: Hidden Layer 1=20, Hidden Layer 2=20, Hidden Layer 3=60, Hidden Layer 4=80
# Training model with configuration 36: Hidden Layer 1=20, Hidden Layer 2=20, Hidden Layer 3=70, Hidden Layer 4=20
# Training model with configuration 37: Hidden Layer 1=20, Hidden Layer 2=20, Hidden Layer 3=70, Hidden Layer 4=30
# Training model with configuration 38: Hidden Layer 1=20, Hidden Layer 2=20, Hidden Layer 3=70, Hidden Layer 4=40
# Training model with configuration 39: Hidden Layer 1=20, Hidden Layer 2=20, Hidden Layer 3=70, Hidden Layer 4=50
# Training model with configuration 40: Hidden Layer 1=20, Hidden Layer 2=20, Hidden Layer 3=70, Hidden Layer 4=60
# Training model with configuration 41: Hidden Layer 1=20, Hidden Layer 2=20, Hidden Layer 3=70, Hidden Layer 4=70
# Training model with configuration 42: Hidden Layer 1=20, Hidden Layer 2=20, Hidden Layer 3=70, Hidden Layer 4=80
# Training model with configuration 43: Hidden Layer 1=20, Hidden Layer 2=20, Hidden Layer 3=80, Hidden Layer 4=20
# Training model with configuration 44: Hidden Layer 1=20, Hidden Layer 2=20, Hidden Layer 3=80, Hidden Layer 4=30
# Training model with configuration 45: Hidden Layer 1=20, Hidden Layer 2=20, Hidden Layer 3=80, Hidden Layer 4=40
# Training model with configuration 46: Hidden Layer 1=20, Hidden Layer 2=20, Hidden Layer 3=80, Hidden Layer 4=50
# Training model with configuration 47: Hidden Layer 1=20, Hidden Layer 2=20, Hidden Layer 3=80, Hidden Layer 4=60
# Training model with configuration 48: Hidden Layer 1=20, Hidden Layer 2=20, Hidden Layer 3=80, Hidden Layer 4=70
# Training model with configuration 49: Hidden Layer 1=20, Hidden Layer 2=20, Hidden Layer 3=80, Hidden Layer 4=80
# Training model with configuration 50: Hidden Layer 1=20, Hidden Layer 2=30, Hidden Layer 3=20, Hidden Layer 4=20
# Training model with configuration 51: Hidden Layer 1=20, Hidden Layer 2=30, Hidden Layer 3=20, Hidden Layer 4=30
# Training model with configuration 52: Hidden Layer 1=20, Hidden Layer 2=30, Hidden Layer 3=20, Hidden Layer 4=40
# Training model with configuration 53: Hidden Layer 1=20, Hidden Layer 2=30, Hidden Layer 3=20, Hidden Layer 4=50
# Training model with configuration 54: Hidden Layer 1=20, Hidden Layer 2=30, Hidden Layer 3=20, Hidden Layer 4=60
# Training model with configuration 55: Hidden Layer 1=20, Hidden Layer 2=30, Hidden Layer 3=20, Hidden Layer 4=70
# Training model with configuration 56: Hidden Layer 1=20, Hidden Layer 2=30, Hidden Layer 3=20, Hidden Layer 4=80
# Training model with configuration 57: Hidden Layer 1=20, Hidden Layer 2=30, Hidden Layer 3=30, Hidden Layer 4=20
# Training model with configuration 58: Hidden Layer 1=20, Hidden Layer 2=30, Hidden Layer 3=30, Hidden Layer 4=30
# Training model with configuration 59: Hidden Layer 1=20, Hidden Layer 2=30, Hidden Layer 3=30, Hidden Layer 4=40
# Training model with configuration 60: Hidden Layer 1=20, Hidden Layer 2=30, Hidden Layer 3=30, Hidden Layer 4=50
# Training model with configuration 61: Hidden Layer 1=20, Hidden Layer 2=30, Hidden Layer 3=30, Hidden Layer 4=60
# Training model with configuration 62: Hidden Layer 1=20, Hidden Layer 2=30, Hidden Layer 3=30, Hidden Layer 4=70
# Training model with configuration 63: Hidden Layer 1=20, Hidden Layer 2=30, Hidden Layer 3=30, Hidden Layer 4=80
# Training model with configuration 64: Hidden Layer 1=20, Hidden Layer 2=30, Hidden Layer 3=40, Hidden Layer 4=20
# Training model with configuration 65: Hidden Layer 1=20, Hidden Layer 2=30, Hidden Layer 3=40, Hidden Layer 4=30
# Training model with configuration 66: Hidden Layer 1=20, Hidden Layer 2=30, Hidden Layer 3=40, Hidden Layer 4=40
# Training model with configuration 67: Hidden Layer 1=20, Hidden Layer 2=30, Hidden Layer 3=40, Hidden Layer 4=50
# Training model with configuration 68: Hidden Layer 1=20, Hidden Layer 2=30, Hidden Layer 3=40, Hidden Layer 4=60
# Training model with configuration 69: Hidden Layer 1=20, Hidden Layer 2=30, Hidden Layer 3=40, Hidden Layer 4=70
# Training model with configuration 70: Hidden Layer 1=20, Hidden Layer 2=30, Hidden Layer 3=40, Hidden Layer 4=80
# Training model with configuration 71: Hidden Layer 1=20, Hidden Layer 2=30, Hidden Layer 3=50, Hidden Layer 4=20
# Training model with configuration 72: Hidden Layer 1=20, Hidden Layer 2=30, Hidden Layer 3=50, Hidden Layer 4=30
# Training model with configuration 73: Hidden Layer 1=20, Hidden Layer 2=30, Hidden Layer 3=50, Hidden Layer 4=40
# Training model with configuration 74: Hidden Layer 1=20, Hidden Layer 2=30, Hidden Layer 3=50, Hidden Layer 4=50
# Training model with configuration 75: Hidden Layer 1=20, Hidden Layer 2=30, Hidden Layer 3=50, Hidden Layer 4=60
# Training model with configuration 76: Hidden Layer 1=20, Hidden Layer 2=30, Hidden Layer 3=50, Hidden Layer 4=70
# Training model with configuration 77: Hidden Layer 1=20, Hidden Layer 2=30, Hidden Layer 3=50, Hidden Layer 4=80
# Training model with configuration 78: Hidden Layer 1=20, Hidden Layer 2=30, Hidden Layer 3=60, Hidden Layer 4=20
# Training model with configuration 79: Hidden Layer 1=20, Hidden Layer 2=30, Hidden Layer 3=60, Hidden Layer 4=30
# Training model with configuration 80: Hidden Layer 1=20, Hidden Layer 2=30, Hidden Layer 3=60, Hidden Layer 4=40
# Training model with configuration 81: Hidden Layer 1=20, Hidden Layer 2=30, Hidden Layer 3=60, Hidden Layer 4=50
# Training model with configuration 82: Hidden Layer 1=20, Hidden Layer 2=30, Hidden Layer 3=60, Hidden Layer 4=60
# Training model with configuration 83: Hidden Layer 1=20, Hidden Layer 2=30, Hidden Layer 3=60, Hidden Layer 4=70
# Training model with configuration 84: Hidden Layer 1=20, Hidden Layer 2=30, Hidden Layer 3=60, Hidden Layer 4=80
# Training model with configuration 85: Hidden Layer 1=20, Hidden Layer 2=30, Hidden Layer 3=70, Hidden Layer 4=20
# Training model with configuration 86: Hidden Layer 1=20, Hidden Layer 2=30, Hidden Layer 3=70, Hidden Layer 4=30
# Training model with configuration 87: Hidden Layer 1=20, Hidden Layer 2=30, Hidden Layer 3=70, Hidden Layer 4=40
# Training model with configuration 88: Hidden Layer 1=20, Hidden Layer 2=30, Hidden Layer 3=70, Hidden Layer 4=50
# Training model with configuration 89: Hidden Layer 1=20, Hidden Layer 2=30, Hidden Layer 3=70, Hidden Layer 4=60
# Training model with configuration 90: Hidden Layer 1=20, Hidden Layer 2=30, Hidden Layer 3=70, Hidden Layer 4=70
# Training model with configuration 91: Hidden Layer 1=20, Hidden Layer 2=30, Hidden Layer 3=70, Hidden Layer 4=80
# Training model with configuration 92: Hidden Layer 1=20, Hidden Layer 2=30, Hidden Layer 3=80, Hidden Layer 4=20
# Training model with configuration 93: Hidden Layer 1=20, Hidden Layer 2=30, Hidden Layer 3=80, Hidden Layer 4=30
# Training model with configuration 94: Hidden Layer 1=20, Hidden Layer 2=30, Hidden Layer 3=80, Hidden Layer 4=40
# Training model with configuration 95: Hidden Layer 1=20, Hidden Layer 2=30, Hidden Layer 3=80, Hidden Layer 4=50
# Training model with configuration 96: Hidden Layer 1=20, Hidden Layer 2=30, Hidden Layer 3=80, Hidden Layer 4=60
# Training model with configuration 97: Hidden Layer 1=20, Hidden Layer 2=30, Hidden Layer 3=80, Hidden Layer 4=70
# Training model with configuration 98: Hidden Layer 1=20, Hidden Layer 2=30, Hidden Layer 3=80, Hidden Layer 4=80
# Training model with configuration 99: Hidden Layer 1=20, Hidden Layer 2=40, Hidden Layer 3=20, Hidden Layer 4=20
# Training model with configuration 100: Hidden Layer 1=20, Hidden Layer 2=40, Hidden Layer 3=20, Hidden Layer 4=30
# Training model with configuration 101: Hidden Layer 1=20, Hidden Layer 2=40, Hidden Layer 3=20, Hidden Layer 4=40
# Training model with configuration 102: Hidden Layer 1=20, Hidden Layer 2=40, Hidden Layer 3=20, Hidden Layer 4=50
# Training model with configuration 103: Hidden Layer 1=20, Hidden Layer 2=40, Hidden Layer 3=20, Hidden Layer 4=60
# Training model with configuration 104: Hidden Layer 1=20, Hidden Layer 2=40, Hidden Layer 3=20, Hidden Layer 4=70
# Training model with configuration 105: Hidden Layer 1=20, Hidden Layer 2=40, Hidden Layer 3=20, Hidden Layer 4=80
# Training model with configuration 106: Hidden Layer 1=20, Hidden Layer 2=40, Hidden Layer 3=30, Hidden Layer 4=20
# Training model with configuration 107: Hidden Layer 1=20, Hidden Layer 2=40, Hidden Layer 3=30, Hidden Layer 4=30
# Training model with configuration 108: Hidden Layer 1=20, Hidden Layer 2=40, Hidden Layer 3=30, Hidden Layer 4=40
# Training model with configuration 109: Hidden Layer 1=20, Hidden Layer 2=40, Hidden Layer 3=30, Hidden Layer 4=50
# Training model with configuration 110: Hidden Layer 1=20, Hidden Layer 2=40, Hidden Layer 3=30, Hidden Layer 4=60
# Training model with configuration 111: Hidden Layer 1=20, Hidden Layer 2=40, Hidden Layer 3=30, Hidden Layer 4=70
# Training model with configuration 112: Hidden Layer 1=20, Hidden Layer 2=40, Hidden Layer 3=30, Hidden Layer 4=80
# Training model with configuration 113: Hidden Layer 1=20, Hidden Layer 2=40, Hidden Layer 3=40, Hidden Layer 4=20
# Training model with configuration 114: Hidden Layer 1=20, Hidden Layer 2=40, Hidden Layer 3=40, Hidden Layer 4=30
# Training model with configuration 115: Hidden Layer 1=20, Hidden Layer 2=40, Hidden Layer 3=40, Hidden Layer 4=40
# Training model with configuration 116: Hidden Layer 1=20, Hidden Layer 2=40, Hidden Layer 3=40, Hidden Layer 4=50
# Training model with configuration 117: Hidden Layer 1=20, Hidden Layer 2=40, Hidden Layer 3=40, Hidden Layer 4=60
# Training model with configuration 118: Hidden Layer 1=20, Hidden Layer 2=40, Hidden Layer 3=40, Hidden Layer 4=70
# Training model with configuration 119: Hidden Layer 1=20, Hidden Layer 2=40, Hidden Layer 3=40, Hidden Layer 4=80
# Training model with configuration 120: Hidden Layer 1=20, Hidden Layer 2=40, Hidden Layer 3=50, Hidden Layer 4=20
# Training model with configuration 121: Hidden Layer 1=20, Hidden Layer 2=40, Hidden Layer 3=50, Hidden Layer 4=30
# Training model with configuration 122: Hidden Layer 1=20, Hidden Layer 2=40, Hidden Layer 3=50, Hidden Layer 4=40
# Training model with configuration 123: Hidden Layer 1=20, Hidden Layer 2=40, Hidden Layer 3=50, Hidden Layer 4=50
# Training model with configuration 124: Hidden Layer 1=20, Hidden Layer 2=40, Hidden Layer 3=50, Hidden Layer 4=60
# Training model with configuration 125: Hidden Layer 1=20, Hidden Layer 2=40, Hidden Layer 3=50, Hidden Layer 4=70
# Training model with configuration 126: Hidden Layer 1=20, Hidden Layer 2=40, Hidden Layer 3=50, Hidden Layer 4=80
# Training model with configuration 127: Hidden Layer 1=20, Hidden Layer 2=40, Hidden Layer 3=60, Hidden Layer 4=20
# Training model with configuration 128: Hidden Layer 1=20, Hidden Layer 2=40, Hidden Layer 3=60, Hidden Layer 4=30
# Training model with configuration 129: Hidden Layer 1=20, Hidden Layer 2=40, Hidden Layer 3=60, Hidden Layer 4=40
# Training model with configuration 130: Hidden Layer 1=20, Hidden Layer 2=40, Hidden Layer 3=60, Hidden Layer 4=50
# Training model with configuration 131: Hidden Layer 1=20, Hidden Layer 2=40, Hidden Layer 3=60, Hidden Layer 4=60
# Training model with configuration 132: Hidden Layer 1=20, Hidden Layer 2=40, Hidden Layer 3=60, Hidden Layer 4=70
# Training model with configuration 133: Hidden Layer 1=20, Hidden Layer 2=40, Hidden Layer 3=60, Hidden Layer 4=80
# Training model with configuration 134: Hidden Layer 1=20, Hidden Layer 2=40, Hidden Layer 3=70, Hidden Layer 4=20
# Training model with configuration 135: Hidden Layer 1=20, Hidden Layer 2=40, Hidden Layer 3=70, Hidden Layer 4=30
# Training model with configuration 136: Hidden Layer 1=20, Hidden Layer 2=40, Hidden Layer 3=70, Hidden Layer 4=40
# Training model with configuration 137: Hidden Layer 1=20, Hidden Layer 2=40, Hidden Layer 3=70, Hidden Layer 4=50
# Training model with configuration 138: Hidden Layer 1=20, Hidden Layer 2=40, Hidden Layer 3=70, Hidden Layer 4=60
# Training model with configuration 139: Hidden Layer 1=20, Hidden Layer 2=40, Hidden Layer 3=70, Hidden Layer 4=70
# Training model with configuration 140: Hidden Layer 1=20, Hidden Layer 2=40, Hidden Layer 3=70, Hidden Layer 4=80
# Training model with configuration 141: Hidden Layer 1=20, Hidden Layer 2=40, Hidden Layer 3=80, Hidden Layer 4=20
# Training model with configuration 142: Hidden Layer 1=20, Hidden Layer 2=40, Hidden Layer 3=80, Hidden Layer 4=30
# Training model with configuration 143: Hidden Layer 1=20, Hidden Layer 2=40, Hidden Layer 3=80, Hidden Layer 4=40
# Training model with configuration 144: Hidden Layer 1=20, Hidden Layer 2=40, Hidden Layer 3=80, Hidden Layer 4=50
# Training model with configuration 145: Hidden Layer 1=20, Hidden Layer 2=40, Hidden Layer 3=80, Hidden Layer 4=60
# Training model with configuration 146: Hidden Layer 1=20, Hidden Layer 2=40, Hidden Layer 3=80, Hidden Layer 4=70
# Training model with configuration 147: Hidden Layer 1=20, Hidden Layer 2=40, Hidden Layer 3=80, Hidden Layer 4=80
# Training model with configuration 148: Hidden Layer 1=20, Hidden Layer 2=50, Hidden Layer 3=20, Hidden Layer 4=20
# Training model with configuration 149: Hidden Layer 1=20, Hidden Layer 2=50, Hidden Layer 3=20, Hidden Layer 4=30
# Training model with configuration 150: Hidden Layer 1=20, Hidden Layer 2=50, Hidden Layer 3=20, Hidden Layer 4=40
# Training model with configuration 151: Hidden Layer 1=20, Hidden Layer 2=50, Hidden Layer 3=20, Hidden Layer 4=50
# Training model with configuration 152: Hidden Layer 1=20, Hidden Layer 2=50, Hidden Layer 3=20, Hidden Layer 4=60
# Training model with configuration 153: Hidden Layer 1=20, Hidden Layer 2=50, Hidden Layer 3=20, Hidden Layer 4=70
# Training model with configuration 154: Hidden Layer 1=20, Hidden Layer 2=50, Hidden Layer 3=20, Hidden Layer 4=80
# Training model with configuration 155: Hidden Layer 1=20, Hidden Layer 2=50, Hidden Layer 3=30, Hidden Layer 4=20
# Training model with configuration 156: Hidden Layer 1=20, Hidden Layer 2=50, Hidden Layer 3=30, Hidden Layer 4=30
# Training model with configuration 157: Hidden Layer 1=20, Hidden Layer 2=50, Hidden Layer 3=30, Hidden Layer 4=40
# Training model with configuration 158: Hidden Layer 1=20, Hidden Layer 2=50, Hidden Layer 3=30, Hidden Layer 4=50
# Training model with configuration 159: Hidden Layer 1=20, Hidden Layer 2=50, Hidden Layer 3=30, Hidden Layer 4=60
# Training model with configuration 160: Hidden Layer 1=20, Hidden Layer 2=50, Hidden Layer 3=30, Hidden Layer 4=70
# Training model with configuration 161: Hidden Layer 1=20, Hidden Layer 2=50, Hidden Layer 3=30, Hidden Layer 4=80
# Training model with configuration 162: Hidden Layer 1=20, Hidden Layer 2=50, Hidden Layer 3=40, Hidden Layer 4=20
# Training model with configuration 163: Hidden Layer 1=20, Hidden Layer 2=50, Hidden Layer 3=40, Hidden Layer 4=30
# Training model with configuration 164: Hidden Layer 1=20, Hidden Layer 2=50, Hidden Layer 3=40, Hidden Layer 4=40
# Training model with configuration 165: Hidden Layer 1=20, Hidden Layer 2=50, Hidden Layer 3=40, Hidden Layer 4=50
# Training model with configuration 166: Hidden Layer 1=20, Hidden Layer 2=50, Hidden Layer 3=40, Hidden Layer 4=60
# Training model with configuration 167: Hidden Layer 1=20, Hidden Layer 2=50, Hidden Layer 3=40, Hidden Layer 4=70
# Training model with configuration 168: Hidden Layer 1=20, Hidden Layer 2=50, Hidden Layer 3=40, Hidden Layer 4=80
# Training model with configuration 169: Hidden Layer 1=20, Hidden Layer 2=50, Hidden Layer 3=50, Hidden Layer 4=20
# Training model with configuration 170: Hidden Layer 1=20, Hidden Layer 2=50, Hidden Layer 3=50, Hidden Layer 4=30
# Training model with configuration 171: Hidden Layer 1=20, Hidden Layer 2=50, Hidden Layer 3=50, Hidden Layer 4=40
# Training model with configuration 172: Hidden Layer 1=20, Hidden Layer 2=50, Hidden Layer 3=50, Hidden Layer 4=50
# Training model with configuration 173: Hidden Layer 1=20, Hidden Layer 2=50, Hidden Layer 3=50, Hidden Layer 4=60
# Training model with configuration 174: Hidden Layer 1=20, Hidden Layer 2=50, Hidden Layer 3=50, Hidden Layer 4=70
# Training model with configuration 175: Hidden Layer 1=20, Hidden Layer 2=50, Hidden Layer 3=50, Hidden Layer 4=80
# Training model with configuration 176: Hidden Layer 1=20, Hidden Layer 2=50, Hidden Layer 3=60, Hidden Layer 4=20
# Training model with configuration 177: Hidden Layer 1=20, Hidden Layer 2=50, Hidden Layer 3=60, Hidden Layer 4=30
# Training model with configuration 178: Hidden Layer 1=20, Hidden Layer 2=50, Hidden Layer 3=60, Hidden Layer 4=40
# Training model with configuration 179: Hidden Layer 1=20, Hidden Layer 2=50, Hidden Layer 3=60, Hidden Layer 4=50
# Training model with configuration 180: Hidden Layer 1=20, Hidden Layer 2=50, Hidden Layer 3=60, Hidden Layer 4=60
# Training model with configuration 181: Hidden Layer 1=20, Hidden Layer 2=50, Hidden Layer 3=60, Hidden Layer 4=70
# Training model with configuration 182: Hidden Layer 1=20, Hidden Layer 2=50, Hidden Layer 3=60, Hidden Layer 4=80
# Training model with configuration 183: Hidden Layer 1=20, Hidden Layer 2=50, Hidden Layer 3=70, Hidden Layer 4=20
# Training model with configuration 184: Hidden Layer 1=20, Hidden Layer 2=50, Hidden Layer 3=70, Hidden Layer 4=30
# Training model with configuration 185: Hidden Layer 1=20, Hidden Layer 2=50, Hidden Layer 3=70, Hidden Layer 4=40
# Training model with configuration 186: Hidden Layer 1=20, Hidden Layer 2=50, Hidden Layer 3=70, Hidden Layer 4=50
# Training model with configuration 187: Hidden Layer 1=20, Hidden Layer 2=50, Hidden Layer 3=70, Hidden Layer 4=60
# Training model with configuration 188: Hidden Layer 1=20, Hidden Layer 2=50, Hidden Layer 3=70, Hidden Layer 4=70
# Training model with configuration 189: Hidden Layer 1=20, Hidden Layer 2=50, Hidden Layer 3=70, Hidden Layer 4=80
# Training model with configuration 190: Hidden Layer 1=20, Hidden Layer 2=50, Hidden Layer 3=80, Hidden Layer 4=20
# Training model with configuration 191: Hidden Layer 1=20, Hidden Layer 2=50, Hidden Layer 3=80, Hidden Layer 4=30
# Training model with configuration 192: Hidden Layer 1=20, Hidden Layer 2=50, Hidden Layer 3=80, Hidden Layer 4=40
# Training model with configuration 193: Hidden Layer 1=20, Hidden Layer 2=50, Hidden Layer 3=80, Hidden Layer 4=50
# Training model with configuration 194: Hidden Layer 1=20, Hidden Layer 2=50, Hidden Layer 3=80, Hidden Layer 4=60
# Training model with configuration 195: Hidden Layer 1=20, Hidden Layer 2=50, Hidden Layer 3=80, Hidden Layer 4=70
# Training model with configuration 196: Hidden Layer 1=20, Hidden Layer 2=50, Hidden Layer 3=80, Hidden Layer 4=80
# Training model with configuration 197: Hidden Layer 1=20, Hidden Layer 2=60, Hidden Layer 3=20, Hidden Layer 4=20
# Training model with configuration 198: Hidden Layer 1=20, Hidden Layer 2=60, Hidden Layer 3=20, Hidden Layer 4=30
# Training model with configuration 199: Hidden Layer 1=20, Hidden Layer 2=60, Hidden Layer 3=20, Hidden Layer 4=40
# Training model with configuration 200: Hidden Layer 1=20, Hidden Layer 2=60, Hidden Layer 3=20, Hidden Layer 4=50
# Training model with configuration 201: Hidden Layer 1=20, Hidden Layer 2=60, Hidden Layer 3=20, Hidden Layer 4=60
# Training model with configuration 202: Hidden Layer 1=20, Hidden Layer 2=60, Hidden Layer 3=20, Hidden Layer 4=70
# Training model with configuration 203: Hidden Layer 1=20, Hidden Layer 2=60, Hidden Layer 3=20, Hidden Layer 4=80
# Training model with configuration 204: Hidden Layer 1=20, Hidden Layer 2=60, Hidden Layer 3=30, Hidden Layer 4=20
# Training model with configuration 205: Hidden Layer 1=20, Hidden Layer 2=60, Hidden Layer 3=30, Hidden Layer 4=30
# Training model with configuration 206: Hidden Layer 1=20, Hidden Layer 2=60, Hidden Layer 3=30, Hidden Layer 4=40
# Training model with configuration 207: Hidden Layer 1=20, Hidden Layer 2=60, Hidden Layer 3=30, Hidden Layer 4=50
# Training model with configuration 208: Hidden Layer 1=20, Hidden Layer 2=60, Hidden Layer 3=30, Hidden Layer 4=60
# Training model with configuration 209: Hidden Layer 1=20, Hidden Layer 2=60, Hidden Layer 3=30, Hidden Layer 4=70
# Training model with configuration 210: Hidden Layer 1=20, Hidden Layer 2=60, Hidden Layer 3=30, Hidden Layer 4=80
# Training model with configuration 211: Hidden Layer 1=20, Hidden Layer 2=60, Hidden Layer 3=40, Hidden Layer 4=20
# Training model with configuration 212: Hidden Layer 1=20, Hidden Layer 2=60, Hidden Layer 3=40, Hidden Layer 4=30
# Training model with configuration 213: Hidden Layer 1=20, Hidden Layer 2=60, Hidden Layer 3=40, Hidden Layer 4=40
# Training model with configuration 214: Hidden Layer 1=20, Hidden Layer 2=60, Hidden Layer 3=40, Hidden Layer 4=50
# Training model with configuration 215: Hidden Layer 1=20, Hidden Layer 2=60, Hidden Layer 3=40, Hidden Layer 4=60
# Training model with configuration 216: Hidden Layer 1=20, Hidden Layer 2=60, Hidden Layer 3=40, Hidden Layer 4=70
# Training model with configuration 217: Hidden Layer 1=20, Hidden Layer 2=60, Hidden Layer 3=40, Hidden Layer 4=80
# Training model with configuration 218: Hidden Layer 1=20, Hidden Layer 2=60, Hidden Layer 3=50, Hidden Layer 4=20
# Training model with configuration 219: Hidden Layer 1=20, Hidden Layer 2=60, Hidden Layer 3=50, Hidden Layer 4=30
# Training model with configuration 220: Hidden Layer 1=20, Hidden Layer 2=60, Hidden Layer 3=50, Hidden Layer 4=40
# Training model with configuration 221: Hidden Layer 1=20, Hidden Layer 2=60, Hidden Layer 3=50, Hidden Layer 4=50
# Training model with configuration 222: Hidden Layer 1=20, Hidden Layer 2=60, Hidden Layer 3=50, Hidden Layer 4=60
# Training model with configuration 223: Hidden Layer 1=20, Hidden Layer 2=60, Hidden Layer 3=50, Hidden Layer 4=70
# Training model with configuration 224: Hidden Layer 1=20, Hidden Layer 2=60, Hidden Layer 3=50, Hidden Layer 4=80
# Training model with configuration 225: Hidden Layer 1=20, Hidden Layer 2=60, Hidden Layer 3=60, Hidden Layer 4=20
# Training model with configuration 226: Hidden Layer 1=20, Hidden Layer 2=60, Hidden Layer 3=60, Hidden Layer 4=30
# Training model with configuration 227: Hidden Layer 1=20, Hidden Layer 2=60, Hidden Layer 3=60, Hidden Layer 4=40
# Training model with configuration 228: Hidden Layer 1=20, Hidden Layer 2=60, Hidden Layer 3=60, Hidden Layer 4=50
# Training model with configuration 229: Hidden Layer 1=20, Hidden Layer 2=60, Hidden Layer 3=60, Hidden Layer 4=60
# Training model with configuration 230: Hidden Layer 1=20, Hidden Layer 2=60, Hidden Layer 3=60, Hidden Layer 4=70
# Training model with configuration 231: Hidden Layer 1=20, Hidden Layer 2=60, Hidden Layer 3=60, Hidden Layer 4=80
# Training model with configuration 232: Hidden Layer 1=20, Hidden Layer 2=60, Hidden Layer 3=70, Hidden Layer 4=20
# Training model with configuration 233: Hidden Layer 1=20, Hidden Layer 2=60, Hidden Layer 3=70, Hidden Layer 4=30
# Training model with configuration 234: Hidden Layer 1=20, Hidden Layer 2=60, Hidden Layer 3=70, Hidden Layer 4=40
# Training model with configuration 235: Hidden Layer 1=20, Hidden Layer 2=60, Hidden Layer 3=70, Hidden Layer 4=50
# Training model with configuration 236: Hidden Layer 1=20, Hidden Layer 2=60, Hidden Layer 3=70, Hidden Layer 4=60
# Training model with configuration 237: Hidden Layer 1=20, Hidden Layer 2=60, Hidden Layer 3=70, Hidden Layer 4=70
# Training model with configuration 238: Hidden Layer 1=20, Hidden Layer 2=60, Hidden Layer 3=70, Hidden Layer 4=80
# Training model with configuration 239: Hidden Layer 1=20, Hidden Layer 2=60, Hidden Layer 3=80, Hidden Layer 4=20
# Training model with configuration 240: Hidden Layer 1=20, Hidden Layer 2=60, Hidden Layer 3=80, Hidden Layer 4=30
# Training model with configuration 241: Hidden Layer 1=20, Hidden Layer 2=60, Hidden Layer 3=80, Hidden Layer 4=40
# Training model with configuration 242: Hidden Layer 1=20, Hidden Layer 2=60, Hidden Layer 3=80, Hidden Layer 4=50
# Training model with configuration 243: Hidden Layer 1=20, Hidden Layer 2=60, Hidden Layer 3=80, Hidden Layer 4=60
# Training model with configuration 244: Hidden Layer 1=20, Hidden Layer 2=60, Hidden Layer 3=80, Hidden Layer 4=70
# Training model with configuration 245: Hidden Layer 1=20, Hidden Layer 2=60, Hidden Layer 3=80, Hidden Layer 4=80
# Training model with configuration 246: Hidden Layer 1=20, Hidden Layer 2=70, Hidden Layer 3=20, Hidden Layer 4=20
# Training model with configuration 247: Hidden Layer 1=20, Hidden Layer 2=70, Hidden Layer 3=20, Hidden Layer 4=30
# Training model with configuration 248: Hidden Layer 1=20, Hidden Layer 2=70, Hidden Layer 3=20, Hidden Layer 4=40
# Training model with configuration 249: Hidden Layer 1=20, Hidden Layer 2=70, Hidden Layer 3=20, Hidden Layer 4=50
# Training model with configuration 250: Hidden Layer 1=20, Hidden Layer 2=70, Hidden Layer 3=20, Hidden Layer 4=60
# Training model with configuration 251: Hidden Layer 1=20, Hidden Layer 2=70, Hidden Layer 3=20, Hidden Layer 4=70
# Training model with configuration 252: Hidden Layer 1=20, Hidden Layer 2=70, Hidden Layer 3=20, Hidden Layer 4=80
# Training model with configuration 253: Hidden Layer 1=20, Hidden Layer 2=70, Hidden Layer 3=30, Hidden Layer 4=20
# Training model with configuration 254: Hidden Layer 1=20, Hidden Layer 2=70, Hidden Layer 3=30, Hidden Layer 4=30
# Training model with configuration 255: Hidden Layer 1=20, Hidden Layer 2=70, Hidden Layer 3=30, Hidden Layer 4=40
# Training model with configuration 256: Hidden Layer 1=20, Hidden Layer 2=70, Hidden Layer 3=30, Hidden Layer 4=50
# Training model with configuration 257: Hidden Layer 1=20, Hidden Layer 2=70, Hidden Layer 3=30, Hidden Layer 4=60
# Training model with configuration 258: Hidden Layer 1=20, Hidden Layer 2=70, Hidden Layer 3=30, Hidden Layer 4=70
# Training model with configuration 259: Hidden Layer 1=20, Hidden Layer 2=70, Hidden Layer 3=30, Hidden Layer 4=80
# Training model with configuration 260: Hidden Layer 1=20, Hidden Layer 2=70, Hidden Layer 3=40, Hidden Layer 4=20
# Training model with configuration 261: Hidden Layer 1=20, Hidden Layer 2=70, Hidden Layer 3=40, Hidden Layer 4=30
# Training model with configuration 262: Hidden Layer 1=20, Hidden Layer 2=70, Hidden Layer 3=40, Hidden Layer 4=40
# Training model with configuration 263: Hidden Layer 1=20, Hidden Layer 2=70, Hidden Layer 3=40, Hidden Layer 4=50
# Training model with configuration 264: Hidden Layer 1=20, Hidden Layer 2=70, Hidden Layer 3=40, Hidden Layer 4=60
# Training model with configuration 265: Hidden Layer 1=20, Hidden Layer 2=70, Hidden Layer 3=40, Hidden Layer 4=70
# Training model with configuration 266: Hidden Layer 1=20, Hidden Layer 2=70, Hidden Layer 3=40, Hidden Layer 4=80
# Training model with configuration 267: Hidden Layer 1=20, Hidden Layer 2=70, Hidden Layer 3=50, Hidden Layer 4=20
# Training model with configuration 268: Hidden Layer 1=20, Hidden Layer 2=70, Hidden Layer 3=50, Hidden Layer 4=30
# Training model with configuration 269: Hidden Layer 1=20, Hidden Layer 2=70, Hidden Layer 3=50, Hidden Layer 4=40
# Training model with configuration 270: Hidden Layer 1=20, Hidden Layer 2=70, Hidden Layer 3=50, Hidden Layer 4=50
# Training model with configuration 271: Hidden Layer 1=20, Hidden Layer 2=70, Hidden Layer 3=50, Hidden Layer 4=60
# Training model with configuration 272: Hidden Layer 1=20, Hidden Layer 2=70, Hidden Layer 3=50, Hidden Layer 4=70
# Training model with configuration 273: Hidden Layer 1=20, Hidden Layer 2=70, Hidden Layer 3=50, Hidden Layer 4=80
# Training model with configuration 274: Hidden Layer 1=20, Hidden Layer 2=70, Hidden Layer 3=60, Hidden Layer 4=20
# Training model with configuration 275: Hidden Layer 1=20, Hidden Layer 2=70, Hidden Layer 3=60, Hidden Layer 4=30
# Training model with configuration 276: Hidden Layer 1=20, Hidden Layer 2=70, Hidden Layer 3=60, Hidden Layer 4=40
# Training model with configuration 277: Hidden Layer 1=20, Hidden Layer 2=70, Hidden Layer 3=60, Hidden Layer 4=50
# Training model with configuration 278: Hidden Layer 1=20, Hidden Layer 2=70, Hidden Layer 3=60, Hidden Layer 4=60
# Training model with configuration 279: Hidden Layer 1=20, Hidden Layer 2=70, Hidden Layer 3=60, Hidden Layer 4=70
# Training model with configuration 280: Hidden Layer 1=20, Hidden Layer 2=70, Hidden Layer 3=60, Hidden Layer 4=80
# Training model with configuration 281: Hidden Layer 1=20, Hidden Layer 2=70, Hidden Layer 3=70, Hidden Layer 4=20
# Training model with configuration 282: Hidden Layer 1=20, Hidden Layer 2=70, Hidden Layer 3=70, Hidden Layer 4=30
# Training model with configuration 283: Hidden Layer 1=20, Hidden Layer 2=70, Hidden Layer 3=70, Hidden Layer 4=40
# Training model with configuration 284: Hidden Layer 1=20, Hidden Layer 2=70, Hidden Layer 3=70, Hidden Layer 4=50
# Training model with configuration 285: Hidden Layer 1=20, Hidden Layer 2=70, Hidden Layer 3=70, Hidden Layer 4=60
# Training model with configuration 286: Hidden Layer 1=20, Hidden Layer 2=70, Hidden Layer 3=70, Hidden Layer 4=70
# Training model with configuration 287: Hidden Layer 1=20, Hidden Layer 2=70, Hidden Layer 3=70, Hidden Layer 4=80
# Training model with configuration 288: Hidden Layer 1=20, Hidden Layer 2=70, Hidden Layer 3=80, Hidden Layer 4=20
# Training model with configuration 289: Hidden Layer 1=20, Hidden Layer 2=70, Hidden Layer 3=80, Hidden Layer 4=30
# Training model with configuration 290: Hidden Layer 1=20, Hidden Layer 2=70, Hidden Layer 3=80, Hidden Layer 4=40
# Training model with configuration 291: Hidden Layer 1=20, Hidden Layer 2=70, Hidden Layer 3=80, Hidden Layer 4=50
# Training model with configuration 292: Hidden Layer 1=20, Hidden Layer 2=70, Hidden Layer 3=80, Hidden Layer 4=60
# Training model with configuration 293: Hidden Layer 1=20, Hidden Layer 2=70, Hidden Layer 3=80, Hidden Layer 4=70
# Training model with configuration 294: Hidden Layer 1=20, Hidden Layer 2=70, Hidden Layer 3=80, Hidden Layer 4=80
# Training model with configuration 295: Hidden Layer 1=20, Hidden Layer 2=80, Hidden Layer 3=20, Hidden Layer 4=20
# Training model with configuration 296: Hidden Layer 1=20, Hidden Layer 2=80, Hidden Layer 3=20, Hidden Layer 4=30
# Training model with configuration 297: Hidden Layer 1=20, Hidden Layer 2=80, Hidden Layer 3=20, Hidden Layer 4=40
# Training model with configuration 298: Hidden Layer 1=20, Hidden Layer 2=80, Hidden Layer 3=20, Hidden Layer 4=50
# Training model with configuration 299: Hidden Layer 1=20, Hidden Layer 2=80, Hidden Layer 3=20, Hidden Layer 4=60
# Training model with configuration 300: Hidden Layer 1=20, Hidden Layer 2=80, Hidden Layer 3=20, Hidden Layer 4=70
# Training model with configuration 301: Hidden Layer 1=20, Hidden Layer 2=80, Hidden Layer 3=20, Hidden Layer 4=80
# Training model with configuration 302: Hidden Layer 1=20, Hidden Layer 2=80, Hidden Layer 3=30, Hidden Layer 4=20
# Training model with configuration 303: Hidden Layer 1=20, Hidden Layer 2=80, Hidden Layer 3=30, Hidden Layer 4=30
# Training model with configuration 304: Hidden Layer 1=20, Hidden Layer 2=80, Hidden Layer 3=30, Hidden Layer 4=40
# Training model with configuration 305: Hidden Layer 1=20, Hidden Layer 2=80, Hidden Layer 3=30, Hidden Layer 4=50
# Training model with configuration 306: Hidden Layer 1=20, Hidden Layer 2=80, Hidden Layer 3=30, Hidden Layer 4=60
# Training model with configuration 307: Hidden Layer 1=20, Hidden Layer 2=80, Hidden Layer 3=30, Hidden Layer 4=70
# Training model with configuration 308: Hidden Layer 1=20, Hidden Layer 2=80, Hidden Layer 3=30, Hidden Layer 4=80
# Training model with configuration 309: Hidden Layer 1=20, Hidden Layer 2=80, Hidden Layer 3=40, Hidden Layer 4=20
# Training model with configuration 310: Hidden Layer 1=20, Hidden Layer 2=80, Hidden Layer 3=40, Hidden Layer 4=30
# Training model with configuration 311: Hidden Layer 1=20, Hidden Layer 2=80, Hidden Layer 3=40, Hidden Layer 4=40
# Training model with configuration 312: Hidden Layer 1=20, Hidden Layer 2=80, Hidden Layer 3=40, Hidden Layer 4=50
# Training model with configuration 313: Hidden Layer 1=20, Hidden Layer 2=80, Hidden Layer 3=40, Hidden Layer 4=60
# Training model with configuration 314: Hidden Layer 1=20, Hidden Layer 2=80, Hidden Layer 3=40, Hidden Layer 4=70
# Training model with configuration 315: Hidden Layer 1=20, Hidden Layer 2=80, Hidden Layer 3=40, Hidden Layer 4=80
# Training model with configuration 316: Hidden Layer 1=20, Hidden Layer 2=80, Hidden Layer 3=50, Hidden Layer 4=20
# Training model with configuration 317: Hidden Layer 1=20, Hidden Layer 2=80, Hidden Layer 3=50, Hidden Layer 4=30
# Training model with configuration 318: Hidden Layer 1=20, Hidden Layer 2=80, Hidden Layer 3=50, Hidden Layer 4=40
# Training model with configuration 319: Hidden Layer 1=20, Hidden Layer 2=80, Hidden Layer 3=50, Hidden Layer 4=50
# Training model with configuration 320: Hidden Layer 1=20, Hidden Layer 2=80, Hidden Layer 3=50, Hidden Layer 4=60
# Training model with configuration 321: Hidden Layer 1=20, Hidden Layer 2=80, Hidden Layer 3=50, Hidden Layer 4=70
# Training model with configuration 322: Hidden Layer 1=20, Hidden Layer 2=80, Hidden Layer 3=50, Hidden Layer 4=80
# Training model with configuration 323: Hidden Layer 1=20, Hidden Layer 2=80, Hidden Layer 3=60, Hidden Layer 4=20
# Training model with configuration 324: Hidden Layer 1=20, Hidden Layer 2=80, Hidden Layer 3=60, Hidden Layer 4=30
# Training model with configuration 325: Hidden Layer 1=20, Hidden Layer 2=80, Hidden Layer 3=60, Hidden Layer 4=40
# Training model with configuration 326: Hidden Layer 1=20, Hidden Layer 2=80, Hidden Layer 3=60, Hidden Layer 4=50
# Training model with configuration 327: Hidden Layer 1=20, Hidden Layer 2=80, Hidden Layer 3=60, Hidden Layer 4=60
# Training model with configuration 328: Hidden Layer 1=20, Hidden Layer 2=80, Hidden Layer 3=60, Hidden Layer 4=70
# Training model with configuration 329: Hidden Layer 1=20, Hidden Layer 2=80, Hidden Layer 3=60, Hidden Layer 4=80
# Training model with configuration 330: Hidden Layer 1=20, Hidden Layer 2=80, Hidden Layer 3=70, Hidden Layer 4=20
# Training model with configuration 331: Hidden Layer 1=20, Hidden Layer 2=80, Hidden Layer 3=70, Hidden Layer 4=30
# Training model with configuration 332: Hidden Layer 1=20, Hidden Layer 2=80, Hidden Layer 3=70, Hidden Layer 4=40
# Training model with configuration 333: Hidden Layer 1=20, Hidden Layer 2=80, Hidden Layer 3=70, Hidden Layer 4=50
# Training model with configuration 334: Hidden Layer 1=20, Hidden Layer 2=80, Hidden Layer 3=70, Hidden Layer 4=60
# Training model with configuration 335: Hidden Layer 1=20, Hidden Layer 2=80, Hidden Layer 3=70, Hidden Layer 4=70
# Training model with configuration 336: Hidden Layer 1=20, Hidden Layer 2=80, Hidden Layer 3=70, Hidden Layer 4=80
# Training model with configuration 337: Hidden Layer 1=20, Hidden Layer 2=80, Hidden Layer 3=80, Hidden Layer 4=20
# Training model with configuration 338: Hidden Layer 1=20, Hidden Layer 2=80, Hidden Layer 3=80, Hidden Layer 4=30
# Training model with configuration 339: Hidden Layer 1=20, Hidden Layer 2=80, Hidden Layer 3=80, Hidden Layer 4=40
# Training model with configuration 340: Hidden Layer 1=20, Hidden Layer 2=80, Hidden Layer 3=80, Hidden Layer 4=50
# Training model with configuration 341: Hidden Layer 1=20, Hidden Layer 2=80, Hidden Layer 3=80, Hidden Layer 4=60
# Training model with configuration 342: Hidden Layer 1=20, Hidden Layer 2=80, Hidden Layer 3=80, Hidden Layer 4=70
# Training model with configuration 343: Hidden Layer 1=20, Hidden Layer 2=80, Hidden Layer 3=80, Hidden Layer 4=80
# Training model with configuration 344: Hidden Layer 1=30, Hidden Layer 2=20, Hidden Layer 3=20, Hidden Layer 4=20
# Training model with configuration 345: Hidden Layer 1=30, Hidden Layer 2=20, Hidden Layer 3=20, Hidden Layer 4=30
# Training model with configuration 346: Hidden Layer 1=30, Hidden Layer 2=20, Hidden Layer 3=20, Hidden Layer 4=40
# Training model with configuration 347: Hidden Layer 1=30, Hidden Layer 2=20, Hidden Layer 3=20, Hidden Layer 4=50
# Training model with configuration 348: Hidden Layer 1=30, Hidden Layer 2=20, Hidden Layer 3=20, Hidden Layer 4=60
# Training model with configuration 349: Hidden Layer 1=30, Hidden Layer 2=20, Hidden Layer 3=20, Hidden Layer 4=70
# Training model with configuration 350: Hidden Layer 1=30, Hidden Layer 2=20, Hidden Layer 3=20, Hidden Layer 4=80
# Training model with configuration 351: Hidden Layer 1=30, Hidden Layer 2=20, Hidden Layer 3=30, Hidden Layer 4=20
# Training model with configuration 352: Hidden Layer 1=30, Hidden Layer 2=20, Hidden Layer 3=30, Hidden Layer 4=30
# Training model with configuration 353: Hidden Layer 1=30, Hidden Layer 2=20, Hidden Layer 3=30, Hidden Layer 4=40
# Training model with configuration 354: Hidden Layer 1=30, Hidden Layer 2=20, Hidden Layer 3=30, Hidden Layer 4=50
# Training model with configuration 355: Hidden Layer 1=30, Hidden Layer 2=20, Hidden Layer 3=30, Hidden Layer 4=60
# Training model with configuration 356: Hidden Layer 1=30, Hidden Layer 2=20, Hidden Layer 3=30, Hidden Layer 4=70
# Training model with configuration 357: Hidden Layer 1=30, Hidden Layer 2=20, Hidden Layer 3=30, Hidden Layer 4=80
# Training model with configuration 358: Hidden Layer 1=30, Hidden Layer 2=20, Hidden Layer 3=40, Hidden Layer 4=20
# Training model with configuration 359: Hidden Layer 1=30, Hidden Layer 2=20, Hidden Layer 3=40, Hidden Layer 4=30
# Training model with configuration 360: Hidden Layer 1=30, Hidden Layer 2=20, Hidden Layer 3=40, Hidden Layer 4=40
# Training model with configuration 361: Hidden Layer 1=30, Hidden Layer 2=20, Hidden Layer 3=40, Hidden Layer 4=50
# Training model with configuration 362: Hidden Layer 1=30, Hidden Layer 2=20, Hidden Layer 3=40, Hidden Layer 4=60
# Training model with configuration 363: Hidden Layer 1=30, Hidden Layer 2=20, Hidden Layer 3=40, Hidden Layer 4=70
# Training model with configuration 364: Hidden Layer 1=30, Hidden Layer 2=20, Hidden Layer 3=40, Hidden Layer 4=80
# Training model with configuration 365: Hidden Layer 1=30, Hidden Layer 2=20, Hidden Layer 3=50, Hidden Layer 4=20
# Training model with configuration 366: Hidden Layer 1=30, Hidden Layer 2=20, Hidden Layer 3=50, Hidden Layer 4=30
# Training model with configuration 367: Hidden Layer 1=30, Hidden Layer 2=20, Hidden Layer 3=50, Hidden Layer 4=40
# Training model with configuration 368: Hidden Layer 1=30, Hidden Layer 2=20, Hidden Layer 3=50, Hidden Layer 4=50
# Training model with configuration 369: Hidden Layer 1=30, Hidden Layer 2=20, Hidden Layer 3=50, Hidden Layer 4=60
# Training model with configuration 370: Hidden Layer 1=30, Hidden Layer 2=20, Hidden Layer 3=50, Hidden Layer 4=70
# Training model with configuration 371: Hidden Layer 1=30, Hidden Layer 2=20, Hidden Layer 3=50, Hidden Layer 4=80
# Training model with configuration 372: Hidden Layer 1=30, Hidden Layer 2=20, Hidden Layer 3=60, Hidden Layer 4=20
# Training model with configuration 373: Hidden Layer 1=30, Hidden Layer 2=20, Hidden Layer 3=60, Hidden Layer 4=30
# Training model with configuration 374: Hidden Layer 1=30, Hidden Layer 2=20, Hidden Layer 3=60, Hidden Layer 4=40
# Training model with configuration 375: Hidden Layer 1=30, Hidden Layer 2=20, Hidden Layer 3=60, Hidden Layer 4=50
# Training model with configuration 376: Hidden Layer 1=30, Hidden Layer 2=20, Hidden Layer 3=60, Hidden Layer 4=60
# Training model with configuration 377: Hidden Layer 1=30, Hidden Layer 2=20, Hidden Layer 3=60, Hidden Layer 4=70
# Training model with configuration 378: Hidden Layer 1=30, Hidden Layer 2=20, Hidden Layer 3=60, Hidden Layer 4=80
# Training model with configuration 379: Hidden Layer 1=30, Hidden Layer 2=20, Hidden Layer 3=70, Hidden Layer 4=20
# Training model with configuration 380: Hidden Layer 1=30, Hidden Layer 2=20, Hidden Layer 3=70, Hidden Layer 4=30
# Training model with configuration 381: Hidden Layer 1=30, Hidden Layer 2=20, Hidden Layer 3=70, Hidden Layer 4=40
# Training model with configuration 382: Hidden Layer 1=30, Hidden Layer 2=20, Hidden Layer 3=70, Hidden Layer 4=50
# Training model with configuration 383: Hidden Layer 1=30, Hidden Layer 2=20, Hidden Layer 3=70, Hidden Layer 4=60
# Training model with configuration 384: Hidden Layer 1=30, Hidden Layer 2=20, Hidden Layer 3=70, Hidden Layer 4=70
# Training model with configuration 385: Hidden Layer 1=30, Hidden Layer 2=20, Hidden Layer 3=70, Hidden Layer 4=80
# Training model with configuration 386: Hidden Layer 1=30, Hidden Layer 2=20, Hidden Layer 3=80, Hidden Layer 4=20
# Training model with configuration 387: Hidden Layer 1=30, Hidden Layer 2=20, Hidden Layer 3=80, Hidden Layer 4=30
# Training model with configuration 388: Hidden Layer 1=30, Hidden Layer 2=20, Hidden Layer 3=80, Hidden Layer 4=40
# Training model with configuration 389: Hidden Layer 1=30, Hidden Layer 2=20, Hidden Layer 3=80, Hidden Layer 4=50
# Training model with configuration 390: Hidden Layer 1=30, Hidden Layer 2=20, Hidden Layer 3=80, Hidden Layer 4=60
# Training model with configuration 391: Hidden Layer 1=30, Hidden Layer 2=20, Hidden Layer 3=80, Hidden Layer 4=70
# Training model with configuration 392: Hidden Layer 1=30, Hidden Layer 2=20, Hidden Layer 3=80, Hidden Layer 4=80
# Training model with configuration 393: Hidden Layer 1=30, Hidden Layer 2=30, Hidden Layer 3=20, Hidden Layer 4=20
# Training model with configuration 394: Hidden Layer 1=30, Hidden Layer 2=30, Hidden Layer 3=20, Hidden Layer 4=30
# Training model with configuration 395: Hidden Layer 1=30, Hidden Layer 2=30, Hidden Layer 3=20, Hidden Layer 4=40
# Training model with configuration 396: Hidden Layer 1=30, Hidden Layer 2=30, Hidden Layer 3=20, Hidden Layer 4=50
# Training model with configuration 397: Hidden Layer 1=30, Hidden Layer 2=30, Hidden Layer 3=20, Hidden Layer 4=60
# Training model with configuration 398: Hidden Layer 1=30, Hidden Layer 2=30, Hidden Layer 3=20, Hidden Layer 4=70
# Training model with configuration 399: Hidden Layer 1=30, Hidden Layer 2=30, Hidden Layer 3=20, Hidden Layer 4=80
# Training model with configuration 400: Hidden Layer 1=30, Hidden Layer 2=30, Hidden Layer 3=30, Hidden Layer 4=20
# Training model with configuration 401: Hidden Layer 1=30, Hidden Layer 2=30, Hidden Layer 3=30, Hidden Layer 4=30
# Training model with configuration 402: Hidden Layer 1=30, Hidden Layer 2=30, Hidden Layer 3=30, Hidden Layer 4=40
# Training model with configuration 403: Hidden Layer 1=30, Hidden Layer 2=30, Hidden Layer 3=30, Hidden Layer 4=50
# Training model with configuration 404: Hidden Layer 1=30, Hidden Layer 2=30, Hidden Layer 3=30, Hidden Layer 4=60
# Training model with configuration 405: Hidden Layer 1=30, Hidden Layer 2=30, Hidden Layer 3=30, Hidden Layer 4=70
# Training model with configuration 406: Hidden Layer 1=30, Hidden Layer 2=30, Hidden Layer 3=30, Hidden Layer 4=80
# Training model with configuration 407: Hidden Layer 1=30, Hidden Layer 2=30, Hidden Layer 3=40, Hidden Layer 4=20
# Training model with configuration 408: Hidden Layer 1=30, Hidden Layer 2=30, Hidden Layer 3=40, Hidden Layer 4=30
# Training model with configuration 409: Hidden Layer 1=30, Hidden Layer 2=30, Hidden Layer 3=40, Hidden Layer 4=40
# Training model with configuration 410: Hidden Layer 1=30, Hidden Layer 2=30, Hidden Layer 3=40, Hidden Layer 4=50
# Training model with configuration 411: Hidden Layer 1=30, Hidden Layer 2=30, Hidden Layer 3=40, Hidden Layer 4=60
# Training model with configuration 412: Hidden Layer 1=30, Hidden Layer 2=30, Hidden Layer 3=40, Hidden Layer 4=70
# Training model with configuration 413: Hidden Layer 1=30, Hidden Layer 2=30, Hidden Layer 3=40, Hidden Layer 4=80
# Training model with configuration 414: Hidden Layer 1=30, Hidden Layer 2=30, Hidden Layer 3=50, Hidden Layer 4=20
# Training model with configuration 415: Hidden Layer 1=30, Hidden Layer 2=30, Hidden Layer 3=50, Hidden Layer 4=30
# Training model with configuration 416: Hidden Layer 1=30, Hidden Layer 2=30, Hidden Layer 3=50, Hidden Layer 4=40
# Training model with configuration 417: Hidden Layer 1=30, Hidden Layer 2=30, Hidden Layer 3=50, Hidden Layer 4=50
# Training model with configuration 418: Hidden Layer 1=30, Hidden Layer 2=30, Hidden Layer 3=50, Hidden Layer 4=60
# Training model with configuration 419: Hidden Layer 1=30, Hidden Layer 2=30, Hidden Layer 3=50, Hidden Layer 4=70
# Training model with configuration 420: Hidden Layer 1=30, Hidden Layer 2=30, Hidden Layer 3=50, Hidden Layer 4=80
# Training model with configuration 421: Hidden Layer 1=30, Hidden Layer 2=30, Hidden Layer 3=60, Hidden Layer 4=20
# Training model with configuration 422: Hidden Layer 1=30, Hidden Layer 2=30, Hidden Layer 3=60, Hidden Layer 4=30
# ...
# Training model with configuration 1761: Hidden Layer 1=70, Hidden Layer 2=20, Hidden Layer 3=80, Hidden Layer 4=50
# Training model with configuration 1762: Hidden Layer 1=70, Hidden Layer 2=20, Hidden Layer 3=80, Hidden Layer 4=60
# Training model with configuration 1763: Hidden Layer 1=70, Hidden Layer 2=20, Hidden Layer 3=80, Hidden Layer 4=70
# Training model with configuration 1764: Hidden Layer 1=70, Hidden Layer 2=20, Hidden Layer 3=80, Hidden Layer 4=80
# Training model with configuration 1765: Hidden Layer 1=70, Hidden Layer 2=30, Hidden Layer 3=20, Hidden Layer 4=20
# Training model with configuration 1766: Hidden Layer 1=70, Hidden Layer 2=30, Hidden Layer 3=20, Hidden Layer 4=30
# Training model with configuration 1767: Hidden Layer 1=70, Hidden Layer 2=30, Hidden Layer 3=20, Hidden Layer 4=40
# Training model with configuration 1768: Hidden Layer 1=70, Hidden Layer 2=30, Hidden Layer 3=20, Hidden Layer 4=50
# Training model with configuration 1769: Hidden Layer 1=70, Hidden Layer 2=30, Hidden Layer 3=20, Hidden Layer 4=60
# Training model with configuration 1770: Hidden Layer 1=70, Hidden Layer 2=30, Hidden Layer 3=20, Hidden Layer 4=70
# Training model with configuration 1771: Hidden Layer 1=70, Hidden Layer 2=30, Hidden Layer 3=20, Hidden Layer 4=80
# Training model with configuration 1772: Hidden Layer 1=70, Hidden Layer 2=30, Hidden Layer 3=30, Hidden Layer 4=20
# Training model with configuration 1773: Hidden Layer 1=70, Hidden Layer 2=30, Hidden Layer 3=30, Hidden Layer 4=30
# Training model with configuration 1774: Hidden Layer 1=70, Hidden Layer 2=30, Hidden Layer 3=30, Hidden Layer 4=40
# Training model with configuration 1775: Hidden Layer 1=70, Hidden Layer 2=30, Hidden Layer 3=30, Hidden Layer 4=50
# Training model with configuration 1776: Hidden Layer 1=70, Hidden Layer 2=30, Hidden Layer 3=30, Hidden Layer 4=60
# Training model with configuration 1777: Hidden Layer 1=70, Hidden Layer 2=30, Hidden Layer 3=30, Hidden Layer 4=70
# Training model with configuration 1778: Hidden Layer 1=70, Hidden Layer 2=30, Hidden Layer 3=30, Hidden Layer 4=80
# Training model with configuration 1779: Hidden Layer 1=70, Hidden Layer 2=30, Hidden Layer 3=40, Hidden Layer 4=20
# Training model with configuration 1780: Hidden Layer 1=70, Hidden Layer 2=30, Hidden Layer 3=40, Hidden Layer 4=30
# Training model with configuration 1781: Hidden Layer 1=70, Hidden Layer 2=30, Hidden Layer 3=40, Hidden Layer 4=40
# Training model with configuration 1782: Hidden Layer 1=70, Hidden Layer 2=30, Hidden Layer 3=40, Hidden Layer 4=50
# Training model with configuration 1783: Hidden Layer 1=70, Hidden Layer 2=30, Hidden Layer 3=40, Hidden Layer 4=60
# Training model with configuration 1784: Hidden Layer 1=70, Hidden Layer 2=30, Hidden Layer 3=40, Hidden Layer 4=70
# Training model with configuration 1785: Hidden Layer 1=70, Hidden Layer 2=30, Hidden Layer 3=40, Hidden Layer 4=80
# Training model with configuration 1786: Hidden Layer 1=70, Hidden Layer 2=30, Hidden Layer 3=50, Hidden Layer 4=20
# Training model with configuration 1787: Hidden Layer 1=70, Hidden Layer 2=30, Hidden Layer 3=50, Hidden Layer 4=30
# Training model with configuration 1788: Hidden Layer 1=70, Hidden Layer 2=30, Hidden Layer 3=50, Hidden Layer 4=40
# Training model with configuration 1789: Hidden Layer 1=70, Hidden Layer 2=30, Hidden Layer 3=50, Hidden Layer 4=50
# Training model with configuration 1790: Hidden Layer 1=70, Hidden Layer 2=30, Hidden Layer 3=50, Hidden Layer 4=60
# Training model with configuration 1791: Hidden Layer 1=70, Hidden Layer 2=30, Hidden Layer 3=50, Hidden Layer 4=70
# Training model with configuration 1792: Hidden Layer 1=70, Hidden Layer 2=30, Hidden Layer 3=50, Hidden Layer 4=80
# Training model with configuration 1793: Hidden Layer 1=70, Hidden Layer 2=30, Hidden Layer 3=60, Hidden Layer 4=20
# Training model with configuration 1794: Hidden Layer 1=70, Hidden Layer 2=30, Hidden Layer 3=60, Hidden Layer 4=30
# Training model with configuration 1795: Hidden Layer 1=70, Hidden Layer 2=30, Hidden Layer 3=60, Hidden Layer 4=40
# Training model with configuration 1796: Hidden Layer 1=70, Hidden Layer 2=30, Hidden Layer 3=60, Hidden Layer 4=50
# Training model with configuration 1797: Hidden Layer 1=70, Hidden Layer 2=30, Hidden Layer 3=60, Hidden Layer 4=60
# Training model with configuration 1798: Hidden Layer 1=70, Hidden Layer 2=30, Hidden Layer 3=60, Hidden Layer 4=70
# Training model with configuration 1799: Hidden Layer 1=70, Hidden Layer 2=30, Hidden Layer 3=60, Hidden Layer 4=80
# Training model with configuration 1800: Hidden Layer 1=70, Hidden Layer 2=30, Hidden Layer 3=70, Hidden Layer 4=20
# Training model with configuration 1801: Hidden Layer 1=70, Hidden Layer 2=30, Hidden Layer 3=70, Hidden Layer 4=30
# Training model with configuration 1802: Hidden Layer 1=70, Hidden Layer 2=30, Hidden Layer 3=70, Hidden Layer 4=40
# Training model with configuration 1803: Hidden Layer 1=70, Hidden Layer 2=30, Hidden Layer 3=70, Hidden Layer 4=50
# Training model with configuration 1804: Hidden Layer 1=70, Hidden Layer 2=30, Hidden Layer 3=70, Hidden Layer 4=60
# Training model with configuration 1805: Hidden Layer 1=70, Hidden Layer 2=30, Hidden Layer 3=70, Hidden Layer 4=70
# Training model with configuration 1806: Hidden Layer 1=70, Hidden Layer 2=30, Hidden Layer 3=70, Hidden Layer 4=80
# Training model with configuration 1807: Hidden Layer 1=70, Hidden Layer 2=30, Hidden Layer 3=80, Hidden Layer 4=20
# Training model with configuration 1808: Hidden Layer 1=70, Hidden Layer 2=30, Hidden Layer 3=80, Hidden Layer 4=30
# Training model with configuration 1809: Hidden Layer 1=70, Hidden Layer 2=30, Hidden Layer 3=80, Hidden Layer 4=40
# Training model with configuration 1810: Hidden Layer 1=70, Hidden Layer 2=30, Hidden Layer 3=80, Hidden Layer 4=50
# Training model with configuration 1811: Hidden Layer 1=70, Hidden Layer 2=30, Hidden Layer 3=80, Hidden Layer 4=60
# Training model with configuration 1812: Hidden Layer 1=70, Hidden Layer 2=30, Hidden Layer 3=80, Hidden Layer 4=70
# Training model with configuration 1813: Hidden Layer 1=70, Hidden Layer 2=30, Hidden Layer 3=80, Hidden Layer 4=80
# Training model with configuration 1814: Hidden Layer 1=70, Hidden Layer 2=40, Hidden Layer 3=20, Hidden Layer 4=20
# Training model with configuration 1815: Hidden Layer 1=70, Hidden Layer 2=40, Hidden Layer 3=20, Hidden Layer 4=30
# Training model with configuration 1816: Hidden Layer 1=70, Hidden Layer 2=40, Hidden Layer 3=20, Hidden Layer 4=40
# Training model with configuration 1817: Hidden Layer 1=70, Hidden Layer 2=40, Hidden Layer 3=20, Hidden Layer 4=50
# Training model with configuration 1818: Hidden Layer 1=70, Hidden Layer 2=40, Hidden Layer 3=20, Hidden Layer 4=60
# Training model with configuration 1819: Hidden Layer 1=70, Hidden Layer 2=40, Hidden Layer 3=20, Hidden Layer 4=70
# Training model with configuration 1820: Hidden Layer 1=70, Hidden Layer 2=40, Hidden Layer 3=20, Hidden Layer 4=80
# Training model with configuration 1821: Hidden Layer 1=70, Hidden Layer 2=40, Hidden Layer 3=30, Hidden Layer 4=20
# Training model with configuration 1822: Hidden Layer 1=70, Hidden Layer 2=40, Hidden Layer 3=30, Hidden Layer 4=30
# Training model with configuration 1823: Hidden Layer 1=70, Hidden Layer 2=40, Hidden Layer 3=30, Hidden Layer 4=40
# Training model with configuration 1824: Hidden Layer 1=70, Hidden Layer 2=40, Hidden Layer 3=30, Hidden Layer 4=50
# Training model with configuration 1825: Hidden Layer 1=70, Hidden Layer 2=40, Hidden Layer 3=30, Hidden Layer 4=60
# Training model with configuration 1826: Hidden Layer 1=70, Hidden Layer 2=40, Hidden Layer 3=30, Hidden Layer 4=70
# Training model with configuration 1827: Hidden Layer 1=70, Hidden Layer 2=40, Hidden Layer 3=30, Hidden Layer 4=80
# Training model with configuration 1828: Hidden Layer 1=70, Hidden Layer 2=40, Hidden Layer 3=40, Hidden Layer 4=20
# Training model with configuration 1829: Hidden Layer 1=70, Hidden Layer 2=40, Hidden Layer 3=40, Hidden Layer 4=30
# Training model with configuration 1830: Hidden Layer 1=70, Hidden Layer 2=40, Hidden Layer 3=40, Hidden Layer 4=40
# Training model with configuration 1831: Hidden Layer 1=70, Hidden Layer 2=40, Hidden Layer 3=40, Hidden Layer 4=50
# Training model with configuration 1832: Hidden Layer 1=70, Hidden Layer 2=40, Hidden Layer 3=40, Hidden Layer 4=60
# Training model with configuration 1833: Hidden Layer 1=70, Hidden Layer 2=40, Hidden Layer 3=40, Hidden Layer 4=70
# Training model with configuration 1834: Hidden Layer 1=70, Hidden Layer 2=40, Hidden Layer 3=40, Hidden Layer 4=80
# Training model with configuration 1835: Hidden Layer 1=70, Hidden Layer 2=40, Hidden Layer 3=50, Hidden Layer 4=20
# Training model with configuration 1836: Hidden Layer 1=70, Hidden Layer 2=40, Hidden Layer 3=50, Hidden Layer 4=30
# Training model with configuration 1837: Hidden Layer 1=70, Hidden Layer 2=40, Hidden Layer 3=50, Hidden Layer 4=40
# Training model with configuration 1838: Hidden Layer 1=70, Hidden Layer 2=40, Hidden Layer 3=50, Hidden Layer 4=50
# Training model with configuration 1839: Hidden Layer 1=70, Hidden Layer 2=40, Hidden Layer 3=50, Hidden Layer 4=60
# Training model with configuration 1840: Hidden Layer 1=70, Hidden Layer 2=40, Hidden Layer 3=50, Hidden Layer 4=70
# Training model with configuration 1841: Hidden Layer 1=70, Hidden Layer 2=40, Hidden Layer 3=50, Hidden Layer 4=80
# Training model with configuration 1842: Hidden Layer 1=70, Hidden Layer 2=40, Hidden Layer 3=60, Hidden Layer 4=20
# Training model with configuration 1843: Hidden Layer 1=70, Hidden Layer 2=40, Hidden Layer 3=60, Hidden Layer 4=30
# Training model with configuration 1844: Hidden Layer 1=70, Hidden Layer 2=40, Hidden Layer 3=60, Hidden Layer 4=40
# Training model with configuration 1845: Hidden Layer 1=70, Hidden Layer 2=40, Hidden Layer 3=60, Hidden Layer 4=50
# Training model with configuration 1846: Hidden Layer 1=70, Hidden Layer 2=40, Hidden Layer 3=60, Hidden Layer 4=60
# Training model with configuration 1847: Hidden Layer 1=70, Hidden Layer 2=40, Hidden Layer 3=60, Hidden Layer 4=70
# Training model with configuration 1848: Hidden Layer 1=70, Hidden Layer 2=40, Hidden Layer 3=60, Hidden Layer 4=80
# Training model with configuration 1849: Hidden Layer 1=70, Hidden Layer 2=40, Hidden Layer 3=70, Hidden Layer 4=20
# Training model with configuration 1850: Hidden Layer 1=70, Hidden Layer 2=40, Hidden Layer 3=70, Hidden Layer 4=30
# Training model with configuration 1851: Hidden Layer 1=70, Hidden Layer 2=40, Hidden Layer 3=70, Hidden Layer 4=40
# Training model with configuration 1852: Hidden Layer 1=70, Hidden Layer 2=40, Hidden Layer 3=70, Hidden Layer 4=50
# Training model with configuration 1853: Hidden Layer 1=70, Hidden Layer 2=40, Hidden Layer 3=70, Hidden Layer 4=60
# Training model with configuration 1854: Hidden Layer 1=70, Hidden Layer 2=40, Hidden Layer 3=70, Hidden Layer 4=70
# Training model with configuration 1855: Hidden Layer 1=70, Hidden Layer 2=40, Hidden Layer 3=70, Hidden Layer 4=80
# Training model with configuration 1856: Hidden Layer 1=70, Hidden Layer 2=40, Hidden Layer 3=80, Hidden Layer 4=20
# Training model with configuration 1857: Hidden Layer 1=70, Hidden Layer 2=40, Hidden Layer 3=80, Hidden Layer 4=30
# Training model with configuration 1858: Hidden Layer 1=70, Hidden Layer 2=40, Hidden Layer 3=80, Hidden Layer 4=40
# Training model with configuration 1859: Hidden Layer 1=70, Hidden Layer 2=40, Hidden Layer 3=80, Hidden Layer 4=50
# Training model with configuration 1860: Hidden Layer 1=70, Hidden Layer 2=40, Hidden Layer 3=80, Hidden Layer 4=60
# Training model with configuration 1861: Hidden Layer 1=70, Hidden Layer 2=40, Hidden Layer 3=80, Hidden Layer 4=70
# Training model with configuration 1862: Hidden Layer 1=70, Hidden Layer 2=40, Hidden Layer 3=80, Hidden Layer 4=80
# Training model with configuration 1863: Hidden Layer 1=70, Hidden Layer 2=50, Hidden Layer 3=20, Hidden Layer 4=20
# Training model with configuration 1864: Hidden Layer 1=70, Hidden Layer 2=50, Hidden Layer 3=20, Hidden Layer 4=30
# Training model with configuration 1865: Hidden Layer 1=70, Hidden Layer 2=50, Hidden Layer 3=20, Hidden Layer 4=40
# Training model with configuration 1866: Hidden Layer 1=70, Hidden Layer 2=50, Hidden Layer 3=20, Hidden Layer 4=50
# Training model with configuration 1867: Hidden Layer 1=70, Hidden Layer 2=50, Hidden Layer 3=20, Hidden Layer 4=60
# Training model with configuration 1868: Hidden Layer 1=70, Hidden Layer 2=50, Hidden Layer 3=20, Hidden Layer 4=70
# Training model with configuration 1869: Hidden Layer 1=70, Hidden Layer 2=50, Hidden Layer 3=20, Hidden Layer 4=80
# Training model with configuration 1870: Hidden Layer 1=70, Hidden Layer 2=50, Hidden Layer 3=30, Hidden Layer 4=20
# Training model with configuration 1871: Hidden Layer 1=70, Hidden Layer 2=50, Hidden Layer 3=30, Hidden Layer 4=30
# Training model with configuration 1872: Hidden Layer 1=70, Hidden Layer 2=50, Hidden Layer 3=30, Hidden Layer 4=40
# Training model with configuration 1873: Hidden Layer 1=70, Hidden Layer 2=50, Hidden Layer 3=30, Hidden Layer 4=50
# Training model with configuration 1874: Hidden Layer 1=70, Hidden Layer 2=50, Hidden Layer 3=30, Hidden Layer 4=60
# Training model with configuration 1875: Hidden Layer 1=70, Hidden Layer 2=50, Hidden Layer 3=30, Hidden Layer 4=70
# Training model with configuration 1876: Hidden Layer 1=70, Hidden Layer 2=50, Hidden Layer 3=30, Hidden Layer 4=80
# Training model with configuration 1877: Hidden Layer 1=70, Hidden Layer 2=50, Hidden Layer 3=40, Hidden Layer 4=20
# Training model with configuration 1878: Hidden Layer 1=70, Hidden Layer 2=50, Hidden Layer 3=40, Hidden Layer 4=30
# Training model with configuration 1879: Hidden Layer 1=70, Hidden Layer 2=50, Hidden Layer 3=40, Hidden Layer 4=40
# Training model with configuration 1880: Hidden Layer 1=70, Hidden Layer 2=50, Hidden Layer 3=40, Hidden Layer 4=50
# Training model with configuration 1881: Hidden Layer 1=70, Hidden Layer 2=50, Hidden Layer 3=40, Hidden Layer 4=60
# Training model with configuration 1882: Hidden Layer 1=70, Hidden Layer 2=50, Hidden Layer 3=40, Hidden Layer 4=70
# Training model with configuration 1883: Hidden Layer 1=70, Hidden Layer 2=50, Hidden Layer 3=40, Hidden Layer 4=80
# Training model with configuration 1884: Hidden Layer 1=70, Hidden Layer 2=50, Hidden Layer 3=50, Hidden Layer 4=20
# Training model with configuration 1885: Hidden Layer 1=70, Hidden Layer 2=50, Hidden Layer 3=50, Hidden Layer 4=30
# Training model with configuration 1886: Hidden Layer 1=70, Hidden Layer 2=50, Hidden Layer 3=50, Hidden Layer 4=40
# Training model with configuration 1887: Hidden Layer 1=70, Hidden Layer 2=50, Hidden Layer 3=50, Hidden Layer 4=50
# Training model with configuration 1888: Hidden Layer 1=70, Hidden Layer 2=50, Hidden Layer 3=50, Hidden Layer 4=60
# Training model with configuration 1889: Hidden Layer 1=70, Hidden Layer 2=50, Hidden Layer 3=50, Hidden Layer 4=70
# Training model with configuration 1890: Hidden Layer 1=70, Hidden Layer 2=50, Hidden Layer 3=50, Hidden Layer 4=80
# Training model with configuration 1891: Hidden Layer 1=70, Hidden Layer 2=50, Hidden Layer 3=60, Hidden Layer 4=20
# Training model with configuration 1892: Hidden Layer 1=70, Hidden Layer 2=50, Hidden Layer 3=60, Hidden Layer 4=30
# Training model with configuration 1893: Hidden Layer 1=70, Hidden Layer 2=50, Hidden Layer 3=60, Hidden Layer 4=40
# Training model with configuration 1894: Hidden Layer 1=70, Hidden Layer 2=50, Hidden Layer 3=60, Hidden Layer 4=50
# Training model with configuration 1895: Hidden Layer 1=70, Hidden Layer 2=50, Hidden Layer 3=60, Hidden Layer 4=60
# Training model with configuration 1896: Hidden Layer 1=70, Hidden Layer 2=50, Hidden Layer 3=60, Hidden Layer 4=70
# Training model with configuration 1897: Hidden Layer 1=70, Hidden Layer 2=50, Hidden Layer 3=60, Hidden Layer 4=80
# Training model with configuration 1898: Hidden Layer 1=70, Hidden Layer 2=50, Hidden Layer 3=70, Hidden Layer 4=20
# Training model with configuration 1899: Hidden Layer 1=70, Hidden Layer 2=50, Hidden Layer 3=70, Hidden Layer 4=30

# %% [markdown]
# ## Plotting Performance Metrics Evaluation Graphs

# %%
# Plot Mean R-squared against neurons
width = 0.8
positions_1hl = np.arange(min_neurons, max_neurons + 1, step) - width/0.5
box1 = plt.boxplot([results_df['Mean R-squared'].loc[results_df['Neurons_1HL'] == neurons] for neurons in range(min_neurons, max_neurons + 1, step)],
                   positions=positions_1hl,
                   widths=width,
                   patch_artist=True,
                   boxprops=dict(color='blue', facecolor='white'),
                   whiskerprops=dict(color='black'))
positions_2hl = np.arange(min_neurons, max_neurons + 1, step) - width/1.5
box2 = plt.boxplot([results_df['Mean R-squared'].loc[results_df['Neurons_2HL'] == neurons] for neurons in range(min_neurons, max_neurons + 1, step)],
                   positions=positions_2hl,
                   widths=width,
                   patch_artist=True,
                   boxprops=dict(color='green', facecolor='white'),
                   whiskerprops=dict(color='black'))
positions_3hl = np.arange(min_neurons, max_neurons + 1, step) + width/1.5
box3 = plt.boxplot([results_df['Mean R-squared'].loc[results_df['Neurons_3HL'] == neurons] for neurons in range(min_neurons, max_neurons + 1, step)],
                   positions=positions_3hl,
                   widths=width,
                   patch_artist=True,
                   boxprops=dict(color='red', facecolor='white'),
                   whiskerprops=dict(color='black'))
positions_4hl = np.arange(min_neurons, max_neurons + 1, step) + width/0.5
box4 = plt.boxplot([results_df['Mean R-squared'].loc[results_df['Neurons_4HL'] == neurons] for neurons in range(min_neurons, max_neurons + 1, step)],
                   positions=positions_4hl,
                   widths=width,
                   patch_artist=True,
                   boxprops=dict(color='yellow', facecolor='white'),
                   whiskerprops=dict(color='black'))
plt.xticks(np.arange(min_neurons, max_neurons + 1, step), [f'{neurons} Neurons' for neurons in range(min_neurons, max_neurons + 1, step)])
plt.ylabel('Mean R-squared')
plt.title('Mean R-squared vs. Number of Neurons', fontsize = 10)
legend_handles = [
    mpatches.Patch(facecolor='white', edgecolor='blue', linewidth=1, label='1st Hidden Layer'),
    mpatches.Patch(facecolor='white', edgecolor='green', linewidth=1, label='2nd Hidden Layer'),
    mpatches.Patch(facecolor='white', edgecolor='red', linewidth=1, label='3rd Hidden Layer'),
    mpatches.Patch(facecolor='white', edgecolor='yellow', linewidth=1, label='4th Hidden Layer')
]
plt.legend(handles=legend_handles)
plt.subplots_adjust(bottom=0.2)
plt.grid(True)
plt.tight_layout()
plt.show()



# Plot Mean MAE against neurons
width = 0.8
positions_1hl = np.arange(min_neurons, max_neurons + 1, step) - width/0.5
box1 = plt.boxplot([results_df['Mean MAE'].loc[results_df['Neurons_1HL'] == neurons] for neurons in range(min_neurons, max_neurons + 1, step)],
                   positions=positions_1hl,
                   widths=width,
                   patch_artist=True,
                   boxprops=dict(color='blue', facecolor='white'),
                   whiskerprops=dict(color='black'))
positions_2hl = np.arange(min_neurons, max_neurons + 1, step) - width/1.5
box2 = plt.boxplot([results_df['Mean MAE'].loc[results_df['Neurons_2HL'] == neurons] for neurons in range(min_neurons, max_neurons + 1, step)],
                   positions=positions_2hl,
                   widths=width,
                   patch_artist=True,
                   boxprops=dict(color='green', facecolor='white'),
                   whiskerprops=dict(color='black'))
positions_3hl = np.arange(min_neurons, max_neurons + 1, step) + width/1.5
box3 = plt.boxplot([results_df['Mean MAE'].loc[results_df['Neurons_3HL'] == neurons] for neurons in range(min_neurons, max_neurons + 1, step)],
                   positions=positions_3hl,
                   widths=width,
                   patch_artist=True,
                   boxprops=dict(color='red', facecolor='white'),
                   whiskerprops=dict(color='black'))
positions_4hl = np.arange(min_neurons, max_neurons + 1, step) + width/0.5
box4 = plt.boxplot([results_df['Mean MAE'].loc[results_df['Neurons_4HL'] == neurons] for neurons in range(min_neurons, max_neurons + 1, step)],
                   positions=positions_4hl,
                   widths=width,
                   patch_artist=True,
                   boxprops=dict(color='yellow', facecolor='white'),
                   whiskerprops=dict(color='black'))
plt.xticks(np.arange(min_neurons, max_neurons + 1, step), [f'{neurons} Neurons' for neurons in range(min_neurons, max_neurons + 1, step)])
plt.ylabel('Mean MAE')
plt.title('Mean MAE vs. Number of Neurons', fontsize = 10)
legend_handles = [
    mpatches.Patch(facecolor='white', edgecolor='blue', linewidth=1, label='1st Hidden Layer'),
    mpatches.Patch(facecolor='white', edgecolor='green', linewidth=1, label='2nd Hidden Layer'),
    mpatches.Patch(facecolor='white', edgecolor='red', linewidth=1, label='3rd Hidden Layer'),
    mpatches.Patch(facecolor='white', edgecolor='yellow', linewidth=1, label='4th Hidden Layer')
]
plt.legend(handles=legend_handles)
plt.subplots_adjust(bottom=0.2)
plt.grid(True)
plt.tight_layout()
plt.show()



# Plot Mean RMSE against neurons
width = 0.8
positions_1hl = np.arange(min_neurons, max_neurons + 1, step) - width/0.5
box1 = plt.boxplot([results_df['Mean RMSE'].loc[results_df['Neurons_1HL'] == neurons] for neurons in range(min_neurons, max_neurons + 1, step)],
                   positions=positions_1hl,
                   widths=width,
                   patch_artist=True,
                   boxprops=dict(color='blue', facecolor='white'),
                   whiskerprops=dict(color='black'))
positions_2hl = np.arange(min_neurons, max_neurons + 1, step) - width/1.5
box2 = plt.boxplot([results_df['Mean RMSE'].loc[results_df['Neurons_2HL'] == neurons] for neurons in range(min_neurons, max_neurons + 1, step)],
                   positions=positions_2hl,
                   widths=width,
                   patch_artist=True,
                   boxprops=dict(color='green', facecolor='white'),
                   whiskerprops=dict(color='black'))
positions_3hl = np.arange(min_neurons, max_neurons + 1, step) + width/1.5
box3 = plt.boxplot([results_df['Mean RMSE'].loc[results_df['Neurons_3HL'] == neurons] for neurons in range(min_neurons, max_neurons + 1, step)],
                   positions=positions_3hl,
                   widths=width,
                   patch_artist=True,
                   boxprops=dict(color='red', facecolor='white'),
                   whiskerprops=dict(color='black'))
positions_4hl = np.arange(min_neurons, max_neurons + 1, step) + width/0.5
box4 = plt.boxplot([results_df['Mean RMSE'].loc[results_df['Neurons_4HL'] == neurons] for neurons in range(min_neurons, max_neurons + 1, step)],
                   positions=positions_4hl,
                   widths=width,
                   patch_artist=True,
                   boxprops=dict(color='yellow', facecolor='white'),
                   whiskerprops=dict(color='black'))
plt.xticks(np.arange(min_neurons, max_neurons + 1, step), [f'{neurons} Neurons' for neurons in range(min_neurons, max_neurons + 1, step)])
plt.ylabel('Mean RMSE')
plt.title('Mean RMSE vs. Number of Neurons', fontsize = 10)
legend_handles = [
    mpatches.Patch(facecolor='white', edgecolor='blue', linewidth=1, label='1st Hidden Layer'),
    mpatches.Patch(facecolor='white', edgecolor='green', linewidth=1, label='2nd Hidden Layer'),
    mpatches.Patch(facecolor='white', edgecolor='red', linewidth=1, label='3rd Hidden Layer'),
    mpatches.Patch(facecolor='white', edgecolor='yellow', linewidth=1, label='4th Hidden Layer')
]
plt.legend(handles=legend_handles)
plt.subplots_adjust(bottom=0.2)
plt.grid(True)
plt.tight_layout()
plt.show()
